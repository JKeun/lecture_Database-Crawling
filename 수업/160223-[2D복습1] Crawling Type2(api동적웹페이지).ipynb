# %% [markdown]
# # Crawling type2(api) & DB(SELECT문)
# * Zigbang 크롤링해보기
# * json사용

# %% [markdown]
# ** 1. 직방 지도api에서 개발자도구 => 네트워크탭 **
#
# ** 2. clear버튼 누르면 지금까지 history초기화**
#
# ** 3. 새로고침(f5) 누르면 웹서버로 받은 초기의 모든 data 전부 가져오게됨**
#
# ** 4. name순으로 보면서 api처럼 보이는 파일을 찾기(header:URL주소, response:결과값(정보))**
#
# * 파일명 : items?detail=true~~
#     * header : Request URL:https://api.zigbang.com/v1/items?detail=true&item_ids=3649128&~~~ 처럼 data가 있을것 같은 주소 보임
#     * response : {"items":[{"title":"서울시 금천구 가산동","header":false,"header_height":0,"item":{"id":3649128,~~ 처럼 정보가 보임

# %%
import requests
import json

# %% [markdown]
# ** 5. URL주소 입력**

# %%
response = requests.get("https://api.zigbang.com/v1/items?detail=true&item_ids=3596008&item_ids=3379714&item_ids=3616656&item_ids=3379438&item_ids=3373685&item_ids=3661814&item_ids=3670176&item_ids=3675619&item_ids=3430114&item_ids=3584676&item_ids=2895993&item_ids=3620208&item_ids=3666380&item_ids=3638164&item_ids=3338714&item_ids=3635890&item_ids=3610307&item_ids=3662110&item_ids=3310408&item_ids=3222744&item_ids=3369354&item_ids=2889759&item_ids=3563712&item_ids=3310430&item_ids=3654957&item_ids=3134913&item_ids=3337988&item_ids=3398056&item_ids=3355613&item_ids=3545068&item_ids=3589792&item_ids=3616020&item_ids=3438604&item_ids=3673443&item_ids=3383516&item_ids=3625468&item_ids=3571769&item_ids=3676257&item_ids=3282237&item_ids=3631733&item_ids=3339151&item_ids=3441036&item_ids=3537086&item_ids=3326951&item_ids=3651909&item_ids=3273200&item_ids=3346748&item_ids=2858973&item_ids=3399801&item_ids=3649711&item_ids=3585227&item_ids=3088803&item_ids=3558838&item_ids=3495174&item_ids=3615043&item_ids=3659400&item_ids=3595821&item_ids=3380987&item_ids=3435731&item_ids=3586029")
response.content
# Out:
# b'{"items":[{"title":"\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c \xec\x96\x91\xec\xb2\x9c\xea\xb5\xac \xec\x8b\xa0\xec\x9b\x94\xeb\x8f\x99","header":false,"header_height":0,"item":{"id":3596008,"images":[{"index":0,"count":1,"url":"http://z1.zigbang.com/items/3596008/42b0d5df0d09e7f3a6daa7d1136cd83d8f1fea41.jpg"},{"index":1,"count":2,"url":"http://z1.zigbang.com/items/3596008/59c52e0f4eefaad9fa8ab529ff54a9a334431016.jpg"},{"index":2,"count":3,"url":"http://z1.zigbang.com/items/3596008/8c6c1b530460876328518edb3dda4993c83fb058.jpg"},{"index":3,"count":4,"url":"http://z1.zigbang.com/items/3596008/098c76ccfbf0c4689ea2f2543ab3d3318e241751.jpg"},{"index":4,"count":5,"url":"http://z1.zigbang.com/items/3596008/645241e5f79c3b33e1f0596066537f951d7abcad.jpg"},{"index":5,"count":6,"url":"http://z1.zigbang.com/items/3596008/c1126ca107afc88768c092850e16a6d61804cc03.jpg"},{"index":6,"count":7,"url":"http://z1.zigbang.com/items/3596008/cc20acd98cc76d8d1a99109efa1956d07a83406d.jpg"},{"index":7,"count":8,"url":"http://z1.zigbang.com/items/3596008/729cff17be1a69be78a5edc70acbe0f5034cc762.jpg"},{"index":8,"count":9,"url":"http://z1.zigbang.com/items/3596008/6138a3c1bbcf378bb38f51697a8b15f84500fd9f.jpg"},{"index":9,"count":10,"url":"http://z1.zigbang.com/items/3596008/eba2d07bf989e901f558d62096870db57c30d8bf.jpg"},{"index":10,"count":11,"url":"http://z1.zigbang.com/items/3596008/c58c46bc4c782b5fd1bb3bea7f4446298a3cd9fc.jpg"},{"index":11,"count":12,"url":"http://z1.zigbang.com/items/3596008/351a009e54d609206e600eee774c39f0cd0bf0b5.jpg"},{"index":12,"count":13,"url":"http://z1.zigbang.com/items/3596008/ac02dadf8e02748c78836f10ab8802ad608fe138.jpg"}],"is_realestate":true,"is_direct":false,"is_room":false,"is_type_room":false,"rent":0,"deposit":13000,"is_deposit_only":true,"floor":"3\xec\xb8\xb5","floor_all":"5\xec\xb8\xb5","local1":"\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c","local2":"\xec\x96\x91\xec\xb2\x9c\xea\xb5\xac","local3":"\xec\x8b\xa0\xec\x9b\x94\xeb\x8f\x99","title":"\xe2\x9d\xa4\xec\x8b\xa0\xed\x98\xbc\xe2\x9d\xa4~\xeb\x8c\x80\xeb\xb0\x95!!~\xec\x98\xac\xec\x88\x98\xeb\xa6\xac\xeb\x90\x98\xec\x96\xb4 \xec\x9e\x88\xeb\x8a\x94 \xec\x8b\xa0\xec\xb6\x95\xeb\xb9\x8c\xeb\x9d\xbc\xea\xb8\x89 \xec\xa0\x84\xec\x84\xb8, \xec\xa0\x84\xec\x84\xb8\xec\x9e\x90\xea\xb8\x88\xeb\x8c\x80\xec\xb6\x9c\xea\xb0\x80\xeb\x8a\xa5 \xec\x97\xad\xec\x84\xb8\xea\xb6\x8c \xec\x8b\xa0\xed\x98\xbc\xeb\xb6\x80\xeb\xb6\x80\xec\xb6\x94\xec\xb2\x9c, \xec\x99\x84\xec\xa0\x84 \xec\xa0\x80\xeb\xa0\xb4\xed\x95\x9c \xec\xa0\x84\xec\x84\xb8\xeb\xb3\xb4\xec\xa6\x9d\xea\xb8\x88\xec\x9c\xbc\xeb\xa1\x9c \xec\x8b\xa0\xed\x98\xbc\xec\x9d\x84 \xec\x8b\x9c\xec\x9e\x91\xed\x95\xb4\xec\x9a\x94\xe2\x9d\xa4\xec\x8b\xa0\xed\x98\xbc\xe2\x9d\xa4~","room_type":"\xed\x88\xac\xeb\xa3\xb8","building_type":"\xeb\x8b\xa4\xec\x84\xb8\xeb\x8c\x80\xea\xb1\xb4\xeb\xac\xbc","room_gubun_code":"01","status":"\xea\xb4\x91\xea\xb3\xa0\xec\xa4\x91","is_status_open":true,"is_status_close":false,"view_count":384,"images_count":13,"updated_at":"\xec\x96\xb4\xec\xa0\x9c","size_m2":"46.28","size":14,"size_m2_contract":"-","size_contract":0,"address1":"\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c \xec\x96\x91\xec\xb2\x9c\xea\xb5\xac \xec\x8b\xa0\xec\x9b\x94\xeb\x8f\x99","near_subways":"\xed\x99\x94\xea\xb3\xa1\xec\x97\xad(5\xed\x98\xb8\xec\x84\xa0), \xec\x9a\xb0\xec\x9e\xa5\xec\x82\xb0\xec\x97\xad(5\xed\x98\xb8\xec\x84\xa0), \xea\xb9\x8c\xec\xb9\x98\xec\x82\xb0\xec\x97\xad(2\xed\x98\xb8\xec\x84\xa0,5\xed\x98\xb8\xec\x84\xa0)","random_location":"37.5380669151943,126.831496353804","options":"\xea\xb0\x80\xec\x8a\xa4\xeb\xa0\x88\xec\x9d\xb8\xec\xa7\x80, \xec\x8b\xa0\xeb\xb0\x9c\xec\x9e\xa5, \xec\x8b\xb1\xed\x81\xac\xeb\x8c\x80","manage_cost":"\xec\x97\x86\xec\x9d\x8c","manage_cost_inc":"-","parking":"\xea\xb0\x80\xeb\x8a\xa5","elevator":"\xec\x97\x86\xec\x9d\x8c","movein_date":"\xec\xa6\x89\xec\x8b\x9c\xec\x9e\x85\xec\xa3\xbc","description":"\xe2\x9d\xa4\xec\x8b\xa0\xed\x98\xbc\xe2\x9d\xa4~\xeb\x8c\x80\xeb\xb0\x95!!~\xec\x98\xac\xec\x88\ ...

# %% [markdown]
# ** 6. json으로 parshing**

# %%
#json : dict으로 바꿔줌
zigbang_dict = json.loads(response.text)
zigbang_dict
# Out:
# {'count_agent': 59,
#  'count_direct': 0,
#  'items': [{'header': False,
#    'header_height': 0,
#    'item': {'address1': '서울시 양천구 신월동',
#     'address2': '72-1',
#     'address3': None,
#     'agent_address1': '서울특별시 강서구 화곡동 353-91번지',
#     'agent_email': 'kali3222@naver.com',
#     'agent_local1': '서울시',
#     'agent_local2': '강서구',
#     'agent_mobile': '0507-1280-7070',
#     'agent_name': '희망공인중개사(조수빈)',
#     'agent_phone': '010-4089-3222',
#     'bjd_code': '1147010300',
#     'bonbun_code': '72',
#     'bubun_code': '1',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '서울특별시',
#     'deposit': 13000,
#     'description': '❤신혼❤~대박!!~올수리되어 있는 신축빌라급 전세, 전세자금대출가능 역세권 신혼부부추천, 완전 저렴한 전세보증금으로 신혼을 시작해요❤신혼❤<br />완전 저렴하죠^^ 꼭 구경하시기 바랍니다. 공실이라 즉시 입주가능합니다.<br /><br />◆ 강서,양천 신혼집(신축빌라)전문 부동산입니다. 좋은인연 만들어봐요!!<br />◆ 1억원짜리 중개업보험에 가입한 정회원업소로 구청에 등록된 담당자입니다.<br />◆ 100% 현장답사가서 제가 직접본 물건만 올리겠습니다!!<br />◆ 작은 문의라도 친절히 답변 드릴께요.^^*  24시간 상담가능합니다~<br /><br />▶전세금액◀<br />전세 13000만원이구요~  전세자금대출 환영합니다.<br /><br />▶위치◀<br />5호선 화곡역에서  도보 약 8분거리 주택가에 있는집이라<br />밤늦게 귀가하시는 여성분들도 안전한 집이예요^^<br /><br />▶크기◀<br />실평수 약 13평으로 신혼집으로 시작하기에 안성맞춤이예요<br />tv랑 작은 쇼파자리가 나오는 거실크기에 작은방 하나는 옷방으로 좋을듯해요~<br /><br />▶엘리베이터◀<br />없어요^^ 그래도 3층이니까 힘들지 않아요.<br /><br /><br />▶옵션◀<br />씽크대,가스렌지,신발장<br /><br />▶주차◀<br />100% 가능합니다 이중주차가 아니라서 차빼주는 번거로움이 없어서 좋아요.<br /><br /><br />',
#     'description_og': '❤신혼❤~대박!!~올수리되어 있는 신축빌라급 전세, 전세자금대출가능 역세권 신혼부부추천, 완전 저렴한 전세보증금으로 신혼을 시작해요❤신혼❤\n완전 저렴하죠^^ 꼭 구경하시기 바랍니다. 공실이라 즉시 입주가능합니다.\n\n◆ 강서,양천 신혼집(신축빌라)전문 부동산입니다. 좋은인연 만들어봐요!!\n◆ 1억원짜리 중개업보험에 가입한 정회원업소로 구청에 등록된 담당자입니다.\n◆ 100% 현장답사가서 제가 직접본 물건만 올리겠습니다!!\n◆ 작은 문의라도 친절히 답변 드릴께요.^^*  24시간 상담가능합니다~\n\n▶전세금액◀\n전세 13000만원이구요~  전세자금대출 환영합니다.\n\n▶위치◀\n5호선 화곡역에서  도보 약 8분거리 주택가에 있는집이라\n밤늦게 귀가하시는 여성분들도 안전한 집이예요^^\n\n▶크기◀\n실평수 약 13평으로 신혼집으로 시작하기에 안성맞춤이예요\ntv랑 작은 쇼파자리가 나오는 거실크기에 작은방 하나는 옷방으로 좋을듯해요~\n\n▶엘리베이터◀\n없어요^^ 그래도 3층이니까 힘들지 않아요.\n\n\n▶옵션◀\n씽크대,가스렌지,신발장\n\n▶주차◀\n100% 가능합니다 이중주차가 아니라서 차빼주는 번거로움이 없어서 좋아요.\n\n\n',
#     'elevator': '없음',
#     'floor': '3층',
#     'floor_all': '5층',
#     'id': 3596008,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3596008/42b0d5df0d09e7f3a6daa7d1136cd83d8f1fea41.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3596008/59c52e0f4eefaad9fa8ab529ff54a9a334431016.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3596008/8c6c1b530460876328518edb3dda4993c83fb058.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3596008/098c76ccfbf0c4689ea2f2543ab3d3318e241751.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3596008/645241e5f79c3b33e1f0596066537f951d7abcad.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3596008/c1126ca107afc88768c092850e16a6d61804cc03.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3596008/cc20acd98cc76d8d1a99109efa1956d07a83406d.jpg'},
#      {'count': 8,
#       'index': 7,
#       'url': 'http://z1.zigbang.com/items/3596008/729cff17be1a69be78a5edc70acbe0f5034cc762.jpg'},
#      {'count': 9,
#       'index': 8,
#       'url': 'http://z1.zigbang.com/items/3596008/6138a3c1bbcf378bb38f51697a8b15f84500fd9f.jpg'},
#      {'count': 10,
#       'index': 9,
#       'url': 'http://z1.zigbang.com/items/3596008/eba2d07bf989e901f558d62096870db57c30d8bf.jpg'},
#      {'count': 11,
#       'index': 10,
#       'url': 'http://z1.zigbang.com/items/3596008/c58c46bc4c782b5fd1bb3bea7f4446298a3cd9fc.jpg'},
#      {'count': 12,
#       'index': 11,
#       'url': 'http://z1.zigbang.com/items/3596008/351a009e54d609206e600eee774c39f0cd0bf0b5.jpg'},
#      {'count': 13,
#       'index': 12,
#       'url': 'http://z1.zigbang.com/items/3596008/ac02dadf8e02748c78836f10ab8802ad608fe138.jpg'}],
#     'images_count': 13,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3596008/42b0d5df0d09e7f3a6daa7d1136cd83d8f1fea41.jpg',
#     'is_deposit_only': True,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '서울시',
#     'local2': '양천구',
#     'local3': '신월동',
#     'manage_cost': '없음',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시입주',
#     'near_subways': '화곡역(5호선), 우장산역(5호선), 까치산역(2호선,5호선)',
#     'options': '가스레인지, 신발장, 싱크대',
#     'original_user_phone': '010-4089-3222',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#     'random_location': '37.5380669151943,126.831496353804',
#     'rent': 0,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '투룸',
#     'secret_memo': None,
#     'size': 14,
#     'size_contract': 0,
#     'size_m2': '46.28',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '❤신혼❤~대박!!~올수리되어 있는 신축빌라급 전세, 전세자금대출가능 역세권 신혼부부추천, 완전 저렴한 전세보증금으로 신혼을 시작해요❤신혼❤~',
#     'updated_at': '어제',
#     'user_email': 'kali3222@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-7070',
#     'user_name': '대표공인중개사(조수빈)',
#     'user_no': 321735,
#     'user_phone': '0507-1280-7070',
#     'view_count': 384},
#    'title': '서울시 양천구 신월동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 서구 석남동',
#     'address2': '556-45',
#     'address3': None,
#     'agent_address1': '인천광역시 서구 길주로88번길 34',
#     'agent_email': 'choibuja1460@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '서구',
#     'agent_mobile': '0507-1280-1140',
#     'agent_name': '부자공인중개사(최은미)',
#     'agent_phone': '032-581-6000',
#     'bjd_code': '2826011000',
#     'bonbun_code': '556',
#     'bubun_code': '45',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '인천광역시',
#     'deposit': 500,
#     'description': '- 현재 공실이므로 편하실 때 입주 가능합니다<br />- 내부가 깔끔합니다<br />-  교통편이 편리합니다',
#     'description_og': '- 현재 공실이므로 편하실 때 입주 가능합니다\n- 내부가 깔끔합니다\n-  교통편이 편리합니다',
#     'elevator': '없음',
#     'floor': '3층',
#     'floor_all': '4층',
#     'id': 3379714,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3379714/07a9b7d25a19dbd0e579be4ea88d20965f50dbdf.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3379714/62de4f7ba941065ca81f3c48f5ce51e9ee980416.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3379714/7fa32ebb00457b107821a3294d869560e8fdf210.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3379714/1a48e5a5bac8b009022c9f5c1001e228133f84e7.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3379714/c0c98c6790ee858a109d557b20b805d3845ddd7c.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3379714/fded3cc12687e9d2866fb1725a64915ed8f659f9.jpg'}],
#     'images_count': 6,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3379714/07a9b7d25a19dbd0e579be4ea88d20965f50dbdf.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '서구',
#     'local3': '석남동',
#     'manage_cost': '없음',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시입주 가능',
#     'near_subways': '-',
#     'options': '신발장, 싱크대',
#     'original_user_phone': '010-3366-1460',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#     'random_location': '37.5040620076845,126.676573609038',
#     'rent': 25,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '투룸',
#     'secret_memo': None,
#     'size': 12,
#     'size_contract': 0,
#     'size_m2': '39.67',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '깔끔하고 저렴한 빌라 월세',
#     'updated_at': '22일 전',
#     'user_email': 'choibuja1460@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-1140',
#     'user_name': '대표공인중개사(최은미)',
#     'user_no': 780299,
#     'user_phone': '0507-1280-1140',
#     'view_count': 1585},
#    'title': '인천시 서구 석남동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 남동구 간석동',
#     'address2': '214-15',
#     'address3': None,
#     'agent_address1': '인천광역시 남동구 백범로 381 , 109호(간석동,웰스하임)',
#     'agent_email': 'sanyokn@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '남동구',
#     'agent_mobile': '0507-1280-5215',
#     'agent_name': '웰스공인중개사(이정아)',
#     'agent_phone': '032-421-4220',
#     'bjd_code': '2820010200',
#     'bonbun_code': '214',
#     'bubun_code': '15',
#     'building': {'address': '인천시 남동구 간석동 214-15',
#      'address2': '214-15',
#      'building_id': 18250,
#      'count': 9,
#      'elevator': '1',
#      'established': '2014.05',
#      'floor': '19층',
#      'lat': 37.4665,
#      'lng': 126.7084,
#      'local1': '인천시',
#      'local2': '남동구',
#      'local3': '간석동',
#      'name': '웰스하임',
#      'rooms': '240세대'},
#     'building_type': '오피스텔·도생',
#     'contract': '인천광역시',
#     'deposit': 70,
#     'description': '           (・´з`・)♥<br /><br /><br />안녕하세요~^^ 방구하실려고 클릭하셨죠?<br /><br /><br /><br />저희는 무보증부터 시작해서 다양한 매물 보유하고있는 웰스부동산입니다<br /><br />친절하고 책임감있는 중개를 약속드리겠습니다.<br /><br /><br /><br />▶방 소개◀<br /><br />간석오거리역 초역세권에 위치한 웰스하임 희귀 B타입 매물입니다.<br /><br />현재 즉시입주가능한 공실이며, 입주청소까지 완료되어있습니다.<br /><br />풀옵션 + 주변교통편리하고, 편의시설까지 완비되어있는 매물입니다. 乃<br /><br /><br />▶상 담◀<br /><br />24시간 언제든 편한시간에 연락주시면 친절하고 확실한 상담을 도와드리겠습니다.<br /><br />해당 매물이 마음에 안드셔도 내집을 구하는 마음으로 찾으시는 매물 책임지고 구해드리겠습니다.<br /><br /><br />언제든 연락주세요~<br /><br />',
#     'description_og': '           (・´з`・)♥\n\n\n안녕하세요~^^ 방구하실려고 클릭하셨죠?\n\n\n\n저희는 무보증부터 시작해서 다양한 매물 보유하고있는 웰스부동산입니다\n\n친절하고 책임감있는 중개를 약속드리겠습니다.\n\n\n\n▶방 소개◀\n\n간석오거리역 초역세권에 위치한 웰스하임 희귀 B타입 매물입니다.\n\n현재 즉시입주가능한 공실이며, 입주청소까지 완료되어있습니다.\n\n풀옵션 + 주변교통편리하고, 편의시설까지 완비되어있는 매물입니다. 乃\n\n\n▶상 담◀\n\n24시간 언제든 편한시간에 연락주시면 친절하고 확실한 상담을 도와드리겠습니다.\n\n해당 매물이 마음에 안드셔도 내집을 구하는 마음으로 찾으시는 매물 책임지고 구해드리겠습니다.\n\n\n언제든 연락주세요~\n\n',
#     'elevator': '있음',
#     'floor': '고층/19층',
#     'floor_all': '19층',
#     'id': 3616656,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3616656/a3b1280c68edb02c72234011a7f6470f50faa5a2.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3616656/4a9c27a9dfa22e58793383005f3f1b3b0a2dff82.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3616656/ce071cd98bfc2274cd717dfc5243e3214b4c2154.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3616656/cd380e240ab4f2c84f6015df7880becbee7b4706.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3616656/e4e9a95e2a8eedd10bd1ede058572337d8b83848.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3616656/4871797867df3dfa86cb820eb75aa7a921f95bc6.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3616656/e99fb6806011bc3b15e31eead5ba9fd9cacee476.jpg'},
#      {'count': 8,
#       'index': 7,
#       'url': 'http://z1.zigbang.com/items/3616656/de9094b04c9814d436b64d12d097f4cb61151e40.jpg'},
#      {'count': 9,
#       'index': 8,
#       'url': 'http://z1.zigbang.com/items/3616656/a3d2c9fbf87314a505f7e979cd160bbe1999ea83.jpg'},
#      {'count': 10,
#       'index': 9,
#       'url': 'http://z1.zigbang.com/items/3616656/72689fc0cbe78b585952d225685f635a7972dd72.jpg'}],
#     'images_count': 10,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3616656/a3b1280c68edb02c72234011a7f6470f50faa5a2.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '남동구',
#     'local3': '간석동',
#     'manage_cost': '6만원',
#     'manage_cost_inc': '인터넷, TV',
#     'movein_date': '즉시입주',
#     'near_subways': '간석오거리역(인천1호선), 동암역(1호선), 인천시청역(인천1호선)',
#     'options': '에어컨, 냉장고, 인덕션, 침대, 옷장, 신발장',
#     'original_user_phone': '010-3815-1670',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/107480.jpg',
#     'random_location': '37.4662485465527,126.708076106715',
#     'rent': 69,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '02',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 11,
#     'size_contract': 21,
#     'size_m2': '36.36',
#     'size_m2_contract': '69.42',
#     'status': '광고중',
#     'title': '간석오거리 웰스하임B타입 희귀매물 즉시입주',
#     'updated_at': '5일 전',
#     'user_email': 'dlwlgbf@nate.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-5471',
#     'user_name': '이지훈',
#     'user_no': 107480,
#     'user_phone': '0507-1280-5471',
#     'view_count': 503},
#    'title': '인천시 남동구 간석동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 서구 석남동',
#     'address2': '499',
#     'address3': None,
#     'agent_address1': '인천광역시 서구 길주로88번길 34',
#     'agent_email': 'choibuja1460@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '서구',
#     'agent_mobile': '0507-1280-1140',
#     'agent_name': '부자공인중개사(최은미)',
#     'agent_phone': '032-581-6000',
#     'bjd_code': '2826011000',
#     'bonbun_code': '499',
#     'bubun_code': '',
#     'building': None,
#     'building_type': '아파트',
#     'contract': '인천광역시',
#     'deposit': 500,
#     'description': '- 올수리 되어  최고의 인테리어입니다.<br />- 조용하고 아늑한 주택가 안에 있습니다<br />- 관리실이 있어 유지 보수가 잘되어 깨끗한 단지입니다.',
#     'description_og': '- 올수리 되어  최고의 인테리어입니다.\n- 조용하고 아늑한 주택가 안에 있습니다\n- 관리실이 있어 유지 보수가 잘되어 깨끗한 단지입니다.',
#     'elevator': '없음',
#     'floor': '5층',
#     'floor_all': '6층',
#     'id': 3379438,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3379438/866ce38c974d8ba8f5df9584c15351027cec4cd3.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3379438/bccdc920522d817454db06872a782a63d9d28488.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3379438/cb21a4e3316f82c866dafe7db74e9425b591d2ec.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3379438/6216a533fed971a8b8ba9863672c21d5e5465dcb.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3379438/aed53d4163dc3289224f9455ac7ee4c44d3e515c.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3379438/00cbca931476a9b9bc562352ec4b0cd3c59904f2.jpg'}],
#     'images_count': 6,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3379438/866ce38c974d8ba8f5df9584c15351027cec4cd3.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '서구',
#     'local3': '석남동',
#     'manage_cost': '2만원',
#     'manage_cost_inc': '수도',
#     'movein_date': '즉시입주 가능',
#     'near_subways': '-',
#     'options': '신발장, 싱크대',
#     'original_user_phone': '010-3366-1460',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#     'random_location': '37.5086095430456,126.674322543101',
#     'rent': 35,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '03',
#     'room_type': '투룸',
#     'secret_memo': None,
#     'size': 11,
#     'size_contract': 14,
#     'size_m2': '36.36',
#     'size_m2_contract': '46.28',
#     'status': '광고중',
#     'title': '올수리 태산아파트 월세',
#     'updated_at': '7일 전',
#     'user_email': 'choibuja1460@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-1140',
#     'user_name': '대표공인중개사(최은미)',
#     'user_no': 780299,
#     'user_phone': '0507-1280-1140',
#     'view_count': 1828},
#    'title': '인천시 서구 석남동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '경기도 부천시 원미구 상동',
#     'address2': '545-17',
#     'address3': None,
#     'agent_address1': '경기도 부천시 원미구 소향로13번길 14-23 , 101호 (상동, 삼성프라자)',
#     'agent_email': 'nakji1@naver.com',
#     'agent_local1': '경기도',
#     'agent_local2': '부천시 원미구',
#     'agent_mobile': '0507-1280-0888',
#     'agent_name': '한백공인중개사(이대진)',
#     'agent_phone': '032-321-8089',
#     'bjd_code': '4119510900',
#     'bonbun_code': '545',
#     'bubun_code': '17',
#     'building': {'address': '경기도 부천시 원미구 상동 545-17',
#      'address2': '545-17',
#      'building_id': 1646,
#      'count': 6,
#      'elevator': '1',
#      'established': '2003.06',
#      'floor': '8층',
#      'lat': 37.5045051574707,
#      'lng': 126.75009155273438,
#      'local1': '경기도',
#      'local2': '부천시 원미구',
#      'local3': '상동',
#      'name': '대야하이빌III',
#      'rooms': '84세대'},
#     'building_type': '오피스텔·도생',
#     'contract': '경기도',
#     'deposit': 3500,
#     'description': '상동역 5분거리의 오피스텔형의 원룸전세<br />아주 깨끗하고<br />아담해서 1,2인이 거주하기에 딱 좋아요<br />보증금 월세 조정가능하구요 무보증도 가능함',
#     'description_og': '상동역 5분거리의 오피스텔형의 원룸전세\n아주 깨끗하고\n아담해서 1,2인이 거주하기에 딱 좋아요\n보증금 월세 조정가능하구요 무보증도 가능함',
#     'elevator': '있음',
#     'floor': '저층/8층',
#     'floor_all': '8층',
#     'id': 3373685,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3373685/fcbec13985475cf96e91a3209d381e096738e024.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3373685/01b35b8bc2abd9923f8559e6d7ae61c8cbdcfe74.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3373685/89e4f50988f20b4ab136a261749b501031e278fa.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3373685/0079a16d152f533bce91ecf71c97fb737c199a58.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3373685/b6ec821d733cf4e63cffb8940276e8aec9229269.jpg'}],
#     'images_count': 5,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3373685/fcbec13985475cf96e91a3209d381e096738e024.jpg',
#     'is_deposit_only': True,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '경기도',
#     'local2': '부천시 원미구',
#     'local3': '상동',
#     'manage_cost': '5~8만원',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시입주',
#     'near_subways': '상동역(7호선), 삼산체육관역(7호선), 부천시청역(7호선)',
#     'options': '에어컨, 냉장고, 세탁기, 인덕션, 신발장, 싱크대',
#     'original_user_phone': '010-9611-8089',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#     'random_location': '37.5042729310807,126.749779967551',
#     'rent': 0,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '02',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 5,
#     'size_contract': 11,
#     'size_m2': '16.53',
#     'size_m2_contract': '36.36',
#     'status': '광고중',
#     'title': '오피스텔형 원룸 전세',
#     'updated_at': '22일 전',
#     'user_email': 'nakji1@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-0888',
#     'user_name': '대표공인중개사(이대진)',
#     'user_no': 932294,
#     'user_phone': '0507-1280-0888',
#     'view_count': 2708},
#    'title': '경기도 부천시 원미구 상동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 남구 문학동',
#     'address2': '355-27',
#     'address3': None,
#     'agent_address1': '인천광역시 남구 문학동 342-6번지',
#     'agent_email': 'aaaa403@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '남구',
#     'agent_mobile': '0507-1280-8811',
#     'agent_name': '포스트공인중개사(김동면)',
#     'agent_phone': '032-431-4488',
#     'bjd_code': '2817010900',
#     'bonbun_code': '355',
#     'bubun_code': '27',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '인천광역시',
#     'deposit': 30,
#     'description': '1. 신축같이 올수리 풀옵션<br />2.모든 옵션 새것으로 처음 사용<br />3.문학동 방을 전문으로하는 부동산으로 모든방 직방으로 구해드립니다.<br />4.방은 항상 볼수 있습니다<br />===============================================<br />** 문학동 대로변 문학초등학교옆 포스트부동산으로 오시면 모든방 직방으로 구해 드립니다.**',
#     'description_og': '1. 신축같이 올수리 풀옵션\n2.모든 옵션 새것으로 처음 사용\n3.문학동 방을 전문으로하는 부동산으로 모든방 직방으로 구해드립니다.\n4.방은 항상 볼수 있습니다\n===============================================\n** 문학동 대로변 문학초등학교옆 포스트부동산으로 오시면 모든방 직방으로 구해 드립니다.**',
#     'elevator': '없음',
#     'floor': '3층',
#     'floor_all': '4층',
#     'id': 3661814,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3661814/cbf2e4ede180fa0c91e7fdd4384b1b4bc242641f.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3661814/b1ed616e7e6a7c91fdf5a8938f1d6ae8dc07c9b4.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3661814/b9cfe9ee4f2bcc29225efb2e699932799d7fcb67.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3661814/dbc8967d3ffa4fe90f7d5098a817ec9ce68c1ac3.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3661814/8106b7214816cdeb3f47229f5f07b2b03cb1ee82.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3661814/8526625cb8ab0350f0c5a8959fb5072dbec14b7d.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3661814/e9fa6d18af3598f4d4f0a4b52d93071a6e5226e3.jpg'},
#      {'count': 8,
#       'index': 7,
#       'url': 'http://z1.zigbang.com/items/3661814/ae64c1fbcafc96cda18a4ef670869d3347f5d1c2.jpg'},
#      {'count': 9,
#       'index': 8,
#       'url': 'http://z1.zigbang.com/items/3661814/ec76a2924a6ca05bca7369700473ad7953a23749.jpg'}],
#     'images_count': 9,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3661814/cbf2e4ede180fa0c91e7fdd4384b1b4bc242641f.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '남구',
#     'local3': '문학동',
#     'manage_cost': '5만원',
#     'manage_cost_inc': '인터넷, TV',
#     'movein_date': '즉시입주',
#     'near_subways': '-',
#     'options': '에어컨, 냉장고, 세탁기, 가스레인지, 침대, 옷장, 신발장, 싱크대',
#     'original_user_phone': '010-9024-8996',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/465552/8cef55d370f8239e7cca4682655f1782bcfd15bf.jpg',
#     'random_location': '37.4391175941361,126.679673317133',
#     'rent': 33,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '원룸(분리형)',
#     'secret_memo': None,
#     'size': 9,
#     'size_contract': 0,
#     'size_m2': '29.75',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '★★ 신축같이 리모델링 모든옵션 새것 공실 즉시입주 ...  보증금 가능★★',
#     'updated_at': '어제',
#     'user_email': 'aaaa403@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-8811',
#     'user_name': '대표공인중개사(김동면)',
#     'user_no': 465552,
#     'user_phone': '0507-1280-8811',
#     'view_count': 53},
#    'title': '인천시 남구 문학동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 남동구 구월동',
#     'address2': '1210-10',
#     'address3': None,
#     'agent_address1': '인천광역시 남동구 인주대로 604번길 12, 102호(구월동)',
#     'agent_email': 'wldms0195@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '남동구',
#     'agent_mobile': '0507-1280-8049',
#     'agent_name': '부동산정보공인중개사(김진영)',
#     'agent_phone': '032-425-5130',
#     'bjd_code': '2820010100',
#     'bonbun_code': '1210',
#     'bubun_code': '10',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '인천광역시',
#     'deposit': 200,
#     'description': '듬직하게 중개 하겠습니다. 믿고 문의주세요<br /><br />- 이방은 요 ?<br /><br />* 풀옵션 겸비한 지상층 원룸<br /><br />* 인터넷 되는 원룸<br /><br />* 역세권<br /><br />* 조금더 궁금한 사항은 편하게 문의주세요',
#     'description_og': '듬직하게 중개 하겠습니다. 믿고 문의주세요\n\n- 이방은 요 ?\n\n* 풀옵션 겸비한 지상층 원룸\n\n* 인터넷 되는 원룸\n\n* 역세권\n\n* 조금더 궁금한 사항은 편하게 문의주세요',
#     'elevator': '없음',
#     'floor': '1층',
#     'floor_all': '4층',
#     'id': 3675619,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3675619/579aaa9408a3cd889b28656ebad4ab6778329bff.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3675619/ad282baedc68741b9f6c50593f042e25a176ed89.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3675619/b19be416b5f0914a54fde74fa7f2e032a5da35bc.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3675619/22eff0e2caa4333c4b9408990063185467681667.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3675619/91f0074f142937fd2877ca052501d529f038ca27.jpg'}],
#     'images_count': 5,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3675619/579aaa9408a3cd889b28656ebad4ab6778329bff.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': False,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '남동구',
#     'local3': '구월동',
#     'manage_cost': '5만원',
#     'manage_cost_inc': '수도, 인터넷, TV',
#     'movein_date': '즉시',
#     'near_subways': '예술회관역(인천1호선), 인천시청역(인천1호선)',
#     'options': '에어컨, 냉장고, 세탁기, 가스레인지, 침대, 옷장, 싱크대',
#     'original_user_phone': '010-4904-5833',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#     'random_location': '37.4509443971089,126.712239688854',
#     'rent': 17,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 7,
#     'size_contract': 0,
#     'size_m2': '23.14',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '★★이방어때?★컥컥 !! 이렇게 저렴하다니..',
#     'updated_at': '20시간 전',
#     'user_email': 'prosst2@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-8305',
#     'user_name': '중개보조원(김선수)',
#     'user_no': 702503,
#     'user_phone': '0507-1280-8305',
#     'view_count': 90},
#    'title': '인천시 남동구 구월동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 남구 주안동',
#     'address2': '25-34',
#     'address3': None,
#     'agent_address1': '인천광역시 남구 주안동 219-4 네오빌주상복합 101호',
#     'agent_email': 'dlspsnsnem@hanmail.net',
#     'agent_local1': '인천시',
#     'agent_local2': '남구',
#     'agent_mobile': '0507-1280-2147',
#     'agent_name': '네오빌공인중개사(라한현)',
#     'agent_phone': '010-3269-6971',
#     'bjd_code': '2817010600',
#     'bonbun_code': '25',
#     'bubun_code': '34',
#     'building': {'address': '인천시 남구 주안동 25-34',
#      'address2': '25-34',
#      'building_id': 1163,
#      'count': 8,
#      'elevator': '1',
#      'established': '2012.10',
#      'floor': '15층',
#      'lat': 37.46622085571289,
#      'lng': 126.67790222167969,
#      'local1': '인천시',
#      'local2': '남구',
#      'local3': '주안동',
#      'name': '베스티움',
#      'rooms': '353세대'},
#     'building_type': '오피스텔·도생',
#     'contract': '인천광역시',
#     'deposit': 50,
#     'description': '서울까지 한번에 갈수 있는 주안역이 있어<br />교통편이 우수한 주안원룸 입니다.<br /><br />먹자거리 cgv 대형할인마트 재래시장 병원 은행등<br />주변생활시설이 너무 좋은 주안원룸 이에요<br /><br />햇살이 좋아 습하거나 곰팡이 걱정이 없으며,<br />2명이 생활하여도 충분한 크기인 주안원룸 입니다.',
#     'description_og': '서울까지 한번에 갈수 있는 주안역이 있어\n교통편이 우수한 주안원룸 입니다.\n\n먹자거리 cgv 대형할인마트 재래시장 병원 은행등\n주변생활시설이 너무 좋은 주안원룸 이에요\n\n햇살이 좋아 습하거나 곰팡이 걱정이 없으며,\n2명이 생활하여도 충분한 크기인 주안원룸 입니다.',
#     'elevator': '있음',
#     'floor': '고층/15층',
#     'floor_all': '15층',
#     'id': 3430114,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3430114/ab293d824c165170a785e24e5cb2368831da382a.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3430114/9853ed52ead7ab8b270af57eef2af8a9cd77f16e.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3430114/3138845cfbe19c5455023af042ce90d794c2de50.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3430114/0a134221d55f3b684e13f0a485165ecfeb517812.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3430114/017452c04ef31d7c499aef36465b73c7f3002149.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3430114/d9feb6927a8ff150d15bc9ffcd0b45bbe1261e50.jpg'}],
#     'images_count': 6,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3430114/ab293d824c165170a785e24e5cb2368831da382a.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '남구',
#     'local3': '주안동',
#     'manage_cost': '4만원',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시입주',
#     'near_subways': '주안역(1호선), 도화역(1호선), 간석역(1호선)',
#     'options': '싱크대, 에어컨, 인덕션, 냉장고, 세탁기, 신발장',
#     'original_user_phone': '010-5623-2224',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/223224.jpg',
#     'random_location': '37.466460439796,126.678228540948',
#     'rent': 40,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '02',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 6,
#     'size_contract': 7,
#     'size_m2': '19.83',
#     'size_m2_contract': '23.14',
#     'status': '광고중',
#     'title': '주안 깔끔한 오피스텔 - 보증금 저렴 월세 저렴',
#     'updated_at': '21일 전',
#     'user_email': 'kkccan@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-2403',
#     'user_name': '중개보조원(박영상)',
#     'user_no': 223224,
#     'user_phone': '0507-1280-2403',
#     'view_count': 1238},
#    'title': '인천시 남구 주안동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 부평구 부평동',
#     'address2': '496-8',
#     'address3': None,
#     'agent_address1': '인천광역시 부평구 부평문화로 127 (부평동)',
#     'agent_email': 'alfo5080@hanmail.net',
#     'agent_local1': '인천시',
#     'agent_local2': '부평구',
#     'agent_mobile': '0507-1280-6524',
#     'agent_name': '미래공인중개사(오성택)',
#     'agent_phone': '032-516-0045',
#     'bjd_code': '2823710100',
#     'bonbun_code': '496',
#     'bubun_code': '8',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '인천광역시',
#     'deposit': 17000,
#     'description': '*부평역 근접해 있는 최고의 집입니다<br />  <br />   방4개 넓은 왕테라스  베란다 3개  창고 1개 <br /><br />*주의!!  사진은 실사 아닙니다  현 거주중이어서  사진 촬영불가  그렇치만 집 너무~~~~좋아요',
#     'description_og': '*부평역 근접해 있는 최고의 집입니다\n  \n   방4개 넓은 왕테라스  베란다 3개  창고 1개 \n\n*주의!!  사진은 실사 아닙니다  현 거주중이어서  사진 촬영불가  그렇치만 집 너무~~~~좋아요',
#     'elevator': '있음',
#     'floor': '7층',
#     'floor_all': '7층',
#     'id': 3584676,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3584676/e0fd87eec93b2a7c597c47ce15d89223294fa876.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3584676/c07b3bd42e92b7dacc3f8053208042ad06527bf2.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3584676/3c613385a637a92b991ae536c0dc610879d25276.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3584676/4ee52980b3238dad0c0418f4debb8141ee8c47aa.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3584676/26507d1099b43b47061ddeba4733facf748c33ff.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3584676/01ecbd954bd89e02dc46c43886e996e1912038cf.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3584676/6fa11398c3908363a2911da5f667851ffbaae76c.jpg'},
#      {'count': 8,
#       'index': 7,
#       'url': 'http://z1.zigbang.com/items/3584676/4ee52980b3238dad0c0418f4debb8141ee8c47aa.jpg'},
#      {'count': 9,
#       'index': 8,
#       'url': 'http://z1.zigbang.com/items/3584676/2b40d15114f7fae309480bf59962a4fe9c07f105.jpg'},
#      {'count': 10,
#       'index': 9,
#       'url': 'http://z1.zigbang.com/items/3584676/9a4340d7bd1c69970ad6d736e476464a120f186f.jpg'},
#      {'count': 11,
#       'index': 10,
#       'url': 'http://z1.zigbang.com/items/3584676/369af0c42d160044146b9c7c99453860c3a292de.jpg'},
#      {'count': 12,
#       'index': 11,
#       'url': 'http://z1.zigbang.com/items/3584676/6fa11398c3908363a2911da5f667851ffbaae76c.jpg'},
#      {'count': 13,
#       'index': 12,
#       'url': 'http://z1.zigbang.com/items/3584676/2377848ce7d417f3b94e36027923524a24a456d0.jpg'},
#      {'count': 14,
#       'index': 13,
#       'url': 'http://z1.zigbang.com/items/3584676/3be57ea99b00ae5c60cc1a088119827595511fac.jpg'}],
#     'images_count': 14,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3584676/e0fd87eec93b2a7c597c47ce15d89223294fa876.jpg',
#     'is_deposit_only': True,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '부평구',
#     'local3': '부평동',
#     'manage_cost': '3만원',
#     'manage_cost_inc': '-',
#     'movein_date': '4월25일 이후',
#     'near_subways': '부평역(1호선,인천1호선), 부개역(1호선), 동수역(인천1호선)',
#     'options': '가스레인지, 신발장, 싱크대',
#     'original_user_phone': '010-8299-1297',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': None,
#     'random_location': '37.4903189102002,126.731553473247',
#     'rent': 0,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '쓰리룸+',
#     'secret_memo': None,
#     'size': 28,
#     'size_contract': 0,
#     'size_m2': '92.56',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '왕테라스에 방4개 전세.................',
#     'updated_at': '7일 전',
#     'user_email': 'alfo5080@hanmail.net',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-6524',
#     'user_name': '대표공인중개사(오성택)',
#     'user_no': 1103591,
#     'user_phone': '0507-1280-6524',
#     'view_count': 824},
#    'title': '인천시 부평구 부평동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 부평구 삼산동',
#     'address2': '260-12',
#     'address3': None,
#     'agent_address1': '인천광역시 계양구 계산새로 71 , A동 110호',
#     'agent_email': 'cdj_us@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '계양구',
#     'agent_mobile': '0507-1280-3687',
#     'agent_name': '엘리트공인중개사(조동진)',
#     'agent_phone': '010-6899-5585',
#     'bjd_code': '2823710500',
#     'bonbun_code': '260',
#     'bubun_code': '12',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '인천광역시',
#     'deposit': 6500,
#     'description': '교통좋은 삼산동 빌라 전세 입니다~<br /><br />도보로 갈산역 8분 , 버스로 1분 <br /><br />7호선 부평구청역 버스로 5분   입니다. ',
#     'description_og': '교통좋은 삼산동 빌라 전세 입니다~\n\n도보로 갈산역 8분 , 버스로 1분 \n\n7호선 부평구청역 버스로 5분   입니다. ',
#     'elevator': '없음',
#     'floor': '4층',
#     'floor_all': '4층',
#     'id': 2895993,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/2895993/f440145c9b6648913746d4ebddeab88a3accdec6.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/2895993/3fd29111db6a34ac6fc113528de9589419c9b5a5.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/2895993/c4b8762d645fba40334ce438853b61db90d5dc56.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/2895993/37aea0a7608ba32ad108036eb9574ee09c6fa700.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/2895993/841470f3988f8a238655517e5233b060d60b7659.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/2895993/0a7002a8089afe0abe662042d7a9fa078639adca.jpg'}],
#     'images_count': 6,
#     'images_thumbnail': 'http://z1.zigbang.com/items/2895993/f440145c9b6648913746d4ebddeab88a3accdec6.jpg',
#     'is_deposit_only': True,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '부평구',
#     'local3': '삼산동',
#     'manage_cost': '없음',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시입주',
#     'near_subways': '갈산역(인천1호선), 삼산체육관역(7호선), 굴포천역(7호선)',
#     'options': '싱크대',
#     'original_user_phone': '032-548-5585',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/342157/b8a3948d910303ee1ae681cae1427d4a1ae96cb0.jpg',
#     'random_location': '37.5187732628016,126.733325444267',
#     'rent': 0,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '투룸',
#     'secret_memo': None,
#     'size': 9,
#     'size_contract': 0,
#     'size_m2': '29.75',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '교통좋은 삼산동 빌라 전세 입니다~',
#     'updated_at': '10일 전',
#     'user_email': 'cdj_us@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-3687',
#     'user_name': '대표공인중개사(조동진)',
#     'user_no': 342157,
#     'user_phone': '0507-1280-3687',
#     'view_count': 6925},
#    'title': '인천시 부평구 삼산동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 남구 주안동',
#     'address2': '928-8',
#     'address3': None,
#     'agent_address1': '인천광역시 남구 주안동 928-8 더 펠리체 102호',
#     'agent_email': 'jw9711@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '남구',
#     'agent_mobile': '0507-1281-4021',
#     'agent_name': '해마루공인중개사(김진영)',
#     'agent_phone': '032-432-6200',
#     'bjd_code': '2817010600',
#     'bonbun_code': '928',
#     'bubun_code': '8',
#     'building': {'address': '인천시 남구 주안동 928-8',
#      'address2': '928-8',
#      'building_id': 18840,
#      'count': 29,
#      'elevator': '1',
#      'established': '2015.12',
#      'floor': '15층',
#      'lat': 37.4632,
#      'lng': 126.6902,
#      'local1': '인천시',
#      'local2': '남구',
#      'local3': '주안동',
#      'name': '해마루더펠리체',
#      'rooms': '280세대'},
#     'building_type': '오피스텔·도생',
#     'contract': '인천광역시',
#     'deposit': 500,
#     'description': '말이 필요없는 엑기스 물건이에용^^~~<br />실사 사진이고요, 직접 눈으로 보심 뿅~~~~~~~~~갑니다.<br />거기다 신규 첫입주라는 뽀~~~~너스<br />보증금 300만원으로도 가능하답니다<br />얼릉 ☎주세용 (친절 확실한 상담)',
#     'description_og': '말이 필요없는 엑기스 물건이에용^^~~\n실사 사진이고요, 직접 눈으로 보심 뿅~~~~~~~~~갑니다.\n거기다 신규 첫입주라는 뽀~~~~너스\n보증금 300만원으로도 가능하답니다\n얼릉 ☎주세용 (친절 확실한 상담)',
#     'elevator': '있음',
#     'floor': '고층/15층',
#     'floor_all': '15층',
#     'id': 3620208,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3620208/c70f5a7156022ba113f83c89e6156fef35c0185d.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3620208/559e3e941df951a4c8fe23ac1ec2ae57f0678cde.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3620208/ed3aa253240c45d827c648b28162b0f8788c2f56.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3620208/e45cf8350b67762034db99bc25d1f938dc25230a.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3620208/cc0b1a65ffec5f7253471d7c85bc6919fcc3fff1.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3620208/eb732aa4dec0fb1f5173a61fdcd288a341264450.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3620208/7caff847bb7c0f111ff97b4212472b736a0174c4.jpg'},
#      {'count': 8,
#       'index': 7,
#       'url': 'http://z1.zigbang.com/items/3620208/2bcbd576cfa62aed3caa7438ab2f1f5c39c543a8.jpg'},
#      {'count': 9,
#       'index': 8,
#       'url': 'http://z1.zigbang.com/items/3620208/f43b44a11f3bad6c002a24658c6b9e4c144f7c4f.jpg'},
#      {'count': 10,
#       'index': 9,
#       'url': 'http://z1.zigbang.com/items/3620208/42aa313e92efb608674ebaaba469be486844618c.jpg'},
#      {'count': 11,
#       'index': 10,
#       'url': 'http://z1.zigbang.com/items/3620208/eb732aa4dec0fb1f5173a61fdcd288a341264450.jpg'},
#      {'count': 12,
#       'index': 11,
#       'url': 'http://z1.zigbang.com/items/3620208/142a2112d447e33de1dad57a606cdec5014f5a2d.jpg'},
#      {'count': 13,
#       'index': 12,
#       'url': 'http://z1.zigbang.com/items/3620208/3fbce2880a8db8cdbea03189a6df9e37859ec702.jpg'},
#      {'count': 14,
#       'index': 13,
#       'url': 'http://z1.zigbang.com/items/3620208/235c3feced8581149ad1761801398381c6587c9b.jpg'},
#      {'count': 15,
#       'index': 14,
#       'url': 'http://z1.zigbang.com/items/3620208/2dbd444e9c7b21cfc42569d711517bed49764fc5.jpg'},
#      {'count': 16,
#       'index': 15,
#       'url': 'http://z1.zigbang.com/items/3620208/90a1841297bf01ec0c16d5d30fc3df0d1dc83d17.jpg'},
#      {'count': 17,
#       'index': 16,
#       'url': 'http://z1.zigbang.com/items/3620208/464172b9cee8d4152511dd1d7fc33aa8c94e2727.jpg'},
#      {'count': 18,
#       'index': 17,
#       'url': 'http://z1.zigbang.com/items/3620208/8c664bb9c133860e711d9576742e45425cd7e596.jpg'},
#      {'count': 19,
#       'index': 18,
#       'url': 'http://z1.zigbang.com/items/3620208/548aa5dc6948440fc9a23dfd9cc4584e05455b14.jpg'},
#      {'count': 20,
#       'index': 19,
#       'url': 'http://z1.zigbang.com/items/3620208/4753f93b765d7a69302082c3b8fa2ffd655d1e14.jpg'}],
#     'images_count': 20,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3620208/c70f5a7156022ba113f83c89e6156fef35c0185d.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '남구',
#     'local3': '주안동',
#     'manage_cost': '3.3만원',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시입주',
#     'near_subways': '간석역(1호선), 주안역(1호선), 인천시청역(인천1호선)',
#     'options': '에어컨, 냉장고, 세탁기, 인덕션, 전자레인지, 책상, 책장, 침대, 옷장, 신발장, 싱크대',
#     'original_user_phone': '010-9018-6432',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#     'random_location': '37.4629446928786,126.690507907912',
#     'rent': 52,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '02',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 8,
#     'size_contract': 14,
#     'size_m2': '26.45',
#     'size_m2_contract': '46.28',
#     'status': '광고중',
#     'title': '★★★이보다 좋쿠~싼집있음 복비 안받음~★★★',
#     'updated_at': '5일 전',
#     'user_email': 'jw9711@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-6779',
#     'user_name': '중개보조원(김진우)',
#     'user_no': 1068535,
#     'user_phone': '0507-1280-6779',
#     'view_count': 330},
#    'title': '인천시 남구 주안동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 남동구 구월동',
#     'address2': '1131-14',
#     'address3': None,
#     'agent_address1': '인천광역시 연수구 학나래로 96 (선학동)',
#     'agent_email': 'ahrami_@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '연수구',
#     'agent_mobile': '0507-1280-0380',
#     'agent_name': '조은공인중개사(장아람)',
#     'agent_phone': '032-812-1600',
#     'bjd_code': '2820010100',
#     'bonbun_code': '1131',
#     'bubun_code': '14',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '인천광역시',
#     'deposit': 100,
#     'description': '#예술회관역7분, 인천시청역8분거리 더블역세권에 위치한 오피스텔입니다.<br /><br />#실평수가 8평정도 나오는 아주 넓은집입니다/.<br /><br />#넓은방에 인테리어도 심플해서 내마음대로 집꾸미기 아주 좋아요~<br /><br />#옷장과 신발장이 각각 2개씩 설치돼있어서 수납하기 아주 편리합니다.<br /><br />#현재 구월동인근에 나와있는 같은금액대 매물중에 방이 가장 넓습니다.<br /><br />#요즘 새학기가 시작되면서 매물 찾기가 아주 힘든시기입니다~  남이 채가기전에 빨리 전화주세요!<br /><br />#가격을 낮춰 광고하는 저질스러운 영업은 하지 않습니다 ^ㅡ^',
#     'description_og': '#예술회관역7분, 인천시청역8분거리 더블역세권에 위치한 오피스텔입니다.\n\n#실평수가 8평정도 나오는 아주 넓은집입니다/.\n\n#넓은방에 인테리어도 심플해서 내마음대로 집꾸미기 아주 좋아요~\n\n#옷장과 신발장이 각각 2개씩 설치돼있어서 수납하기 아주 편리합니다.\n\n#현재 구월동인근에 나와있는 같은금액대 매물중에 방이 가장 넓습니다.\n\n#요즘 새학기가 시작되면서 매물 찾기가 아주 힘든시기입니다~  남이 채가기전에 빨리 전화주세요!\n\n#가격을 낮춰 광고하는 저질스러운 영업은 하지 않습니다 ^ㅡ^',
#     'elevator': '있음',
#     'floor': '7층',
#     'floor_all': '12층',
#     'id': 3666380,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3666380/81f24caaa439e4ff19b5ac28099ca490dba348dd.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3666380/e4ed1d4d905d48f8679b3d5f9bfe867f553e59e0.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3666380/bbcb899f8cb5624e20c36d4c0c470225d0bb35f3.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3666380/ded45e927779e86e88bf33e95ece38faff349989.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3666380/10c99bc274fb9edafd026b422e5628c3f27da7e5.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3666380/8476abea4f99a7049a34863dad9ef0545215dacf.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3666380/f75f6ce4957cfb22adaa9275276321073f23006d.jpg'},
#      {'count': 8,
#       'index': 7,
#       'url': 'http://z1.zigbang.com/items/3666380/1dc9b053e5813729362fd5427a24856781ff91c8.jpg'},
#      {'count': 9,
#       'index': 8,
#       'url': 'http://z1.zigbang.com/items/3666380/79d02f2785541f9e3dc2776c7bfaa76907bef7da.jpg'}],
#     'images_count': 9,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3666380/81f24caaa439e4ff19b5ac28099ca490dba348dd.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '남동구',
#     'local3': '구월동',
#     'manage_cost': '55000만원',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시입주가능합니다 ^^',
#     'near_subways': '예술회관역(인천1호선), 인천시청역(인천1호선), 인천터미널역(인천1호선)',
#     'options': '에어컨, 냉장고, 세탁기, 가스레인지, 옷장, 신발장, 싱크대',
#     'original_user_phone': '010-4943-8897',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/1089740/dff24410433c1419d0e2885f54aa6d5037380930.jpg',
#     'random_location': '37.453147945627,126.702427180824',
#     'rent': 40,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 8,
#     'size_contract': 0,
#     'size_m2': '26.45',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '예술회관역7분 가성비 최고넓은 오피스텔',
#     'updated_at': '어제',
#     'user_email': 'pjh12349@hanmail.net',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-0636',
#     'user_name': '중개보조원(박지하)',
#     'user_no': 1089740,
#     'user_phone': '0507-1280-0636',
#     'view_count': 96},
#    'title': '인천시 남동구 구월동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '서울시 양천구 신월5동',
#     'address2': '77-9',
#     'address3': None,
#     'agent_address1': '서울특별시 강서구 화곡동 1076-21',
#     'agent_email': 'chd9434@naver.com',
#     'agent_local1': '서울시',
#     'agent_local2': '강서구',
# ...
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '경기도',
#     'local2': '부천시 원미구',
#     'local3': '소사동',
#     'manage_cost': '없음',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시 가능',
#     'near_subways': '소사역(1호선), 부천역(1호선)',
#     'options': '에어컨, 냉장고, 세탁기, 신발장, 싱크대',
#     'original_user_phone': '010-2515-4106',
#     'parking': '불가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/193963/b8b2a386b3e9eaa0083f13d941934ca171fa842b.jpg',
#     'random_location': '37.4866569684131,126.794150822601',
#     'rent': 25,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 6,
#     'size_contract': 0,
#     'size_m2': '19.83',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '❤ 깔끔(관리비X) ❤ 카대7분 ❤',
#     'updated_at': '어제',
#     'user_email': 'iuserd@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-4450',
#     'user_name': '대표공인중개사(김상국)',
#     'user_no': 193963,
#     'user_phone': '0507-1280-4450',
#     'view_count': 377},
#    'title': '경기도 부천시 원미구 소사동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '경기도 부천시 원미구 중동',
#     'address2': '1160-1',
#     'address3': None,
#     'agent_address1': '경기도 부천시 원미구 중동 1160-1번지 대우마이빌센트럴파크 108호',
#     'agent_email': 'imyun5113@hanmail.net',
#     'agent_local1': '경기도',
#     'agent_local2': '부천시 원미구',
#     'agent_mobile': '0507-1281-2727',
#     'agent_name': '대우공인중개사(임은희)',
#     'agent_phone': '032-325-8899',
#     'bjd_code': '4119510800',
#     'bonbun_code': '1160',
#     'bubun_code': '1',
#     'building': {'address': '경기도 부천시 원미구 중동 1160-1',
#      'address2': '1160-1',
#      'building_id': 1716,
#      'count': 12,
#      'elevator': '1',
#      'established': '2004.06',
#      'floor': '15층',
#      'lat': 37.50227737426758,
#      'lng': 126.76339721679688,
#      'local1': '경기도',
#      'local2': '부천시 원미구',
#      'local3': '중동',
#      'name': '대우마이빌센트럴파크',
#      'rooms': '260세대'},
#     'building_type': '오피스텔·도생',
#     'contract': '경기도',
#     'deposit': 1000,
#     'description': '전철7호선 부천시청역 3분거리<br />현대백화점,이마트<br />순천향대학병원<br />모두 도보 5분이내로 이용 가능<br /><br />복층형 구조로 수납시설이 아주 많고<br />화장실 샤워부스 넓고 좋아요',
#     'description_og': '전철7호선 부천시청역 3분거리\n현대백화점,이마트\n순천향대학병원\n모두 도보 5분이내로 이용 가능\n\n복층형 구조로 수납시설이 아주 많고\n화장실 샤워부스 넓고 좋아요',
#     'elevator': '있음',
#     'floor': '고층/15층',
#     'floor_all': '15층',
#     'id': 3595821,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3595821/8fd1f8d57c86413be13565ded2793377e683ba2e.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3595821/1840ded1bff3a7ae89cf58e629fd424c6fa950ca.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3595821/c114507e914b1c5b73b236d7712b43e4345f52b4.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3595821/eeede069a9e804a4b063cf289d7c8155c074508d.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3595821/1a1c34abf79e933d6cfb056b6382e34159817d23.jpg'}],
#     'images_count': 5,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3595821/8fd1f8d57c86413be13565ded2793377e683ba2e.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '경기도',
#     'local2': '부천시 원미구',
#     'local3': '중동',
#     'manage_cost': '5만원',
#     'manage_cost_inc': '전기세, 수도',
#     'movein_date': '2월 말',
#     'near_subways': '부천시청역(7호선), 상동역(7호선), 신중동역(7호선)',
#     'options': '냉장고, 세탁기, 가스레인지, 옷장, 싱크대',
#     'original_user_phone': '010-3337-1009',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#     'random_location': '37.5025303847175,126.76371366407',
#     'rent': 45,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '02',
#     'room_type': '원룸(복층형)',
#     'secret_memo': None,
#     'size': 8,
#     'size_contract': 8,
#     'size_m2': '26.45',
#     'size_m2_contract': '26.45',
#     'status': '광고중',
#     'title': '대우16평 복층',
#     'updated_at': '7일 전',
#     'user_email': 'imyun5113@hanmail.net',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1281-2727',
#     'user_name': '대표공인중개사(임은희)',
#     'user_no': 287916,
#     'user_phone': '0507-1281-2727',
#     'view_count': 213},
#    'title': '경기도 부천시 원미구 중동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 남구 주안동',
#     'address2': '115-6',
#     'address3': None,
#     'agent_address1': '인천광역시 남동구 간석동 179-2 1층 OK 부동산',
#     'agent_email': 'bbb53780@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '남동구',
#     'agent_mobile': '0507-1280-2914',
#     'agent_name': 'OK공인중개사(윤소연)',
#     'agent_phone': '032-429-9898',
#     'bjd_code': '2817010600',
#     'bonbun_code': '115',
#     'bubun_code': '6',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '인천광역시',
#     'deposit': 30,
#     'description': '전기요금만 따로 내시고 나머지 공과금은 <br />모두 포함되어 있는 경제적인 원룸입니다^^<br />1층에 주차장이 있는 건물로 1층 및 세대별로<br />도어락이 있고 입구 및 층별로 CCTV가 설치되어 있어요<br />저렴하지만 채광도 좋고 깨끗해서 인기있는 원룸입니다<br />벽걸이TV가 옵션으로 되어 있어서 빨래 널기에도<br />충분한 여유공간이 나와요^^<br /><br /><br />★원하시는 가격.날짜.위치 등을 말씀해주시면 100%맞춤중개<br />   항상 내가족이 구하는 집이라고 생각하며 성심.성의껏 중개하겠습니다',
#     'description_og': '전기요금만 따로 내시고 나머지 공과금은 \n모두 포함되어 있는 경제적인 원룸입니다^^\n1층에 주차장이 있는 건물로 1층 및 세대별로\n도어락이 있고 입구 및 층별로 CCTV가 설치되어 있어요\n저렴하지만 채광도 좋고 깨끗해서 인기있는 원룸입니다\n벽걸이TV가 옵션으로 되어 있어서 빨래 널기에도\n충분한 여유공간이 나와요^^\n\n\n★원하시는 가격.날짜.위치 등을 말씀해주시면 100%맞춤중개\n   항상 내가족이 구하는 집이라고 생각하며 성심.성의껏 중개하겠습니다',
#     'elevator': '없음',
#     'floor': '3층',
#     'floor_all': '5층',
#     'id': 3380987,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3380987/d14cac9e7081e622229c96984bb7b45bd6980d62.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3380987/aeed5df22595d9ad2fc79c4b6dc7a16c92ca84c1.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3380987/50d689c04dbd74eb5fc64b5985669e8f216e574b.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3380987/b281909cfb9ef480328f51baf528eed88eb12c01.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3380987/05a1021efe4a52dd9992cee34b45ad11b82317fa.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3380987/f029ad89b7baa6e4725b6f88e2f73e46bb5fdc07.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3380987/eb92fc662438399c0f02645da0b233b90d83ea03.jpg'}],
#     'images_count': 7,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3380987/d14cac9e7081e622229c96984bb7b45bd6980d62.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '남구',
#     'local3': '주안동',
#     'manage_cost': '5만원',
#     'manage_cost_inc': '가스, 수도, 인터넷, TV',
#     'movein_date': '즉시',
#     'near_subways': '주안역(1호선), 간석역(1호선), 도화역(1호선)',
#     'options': '싱크대, 에어컨, 인덕션, 냉장고, 옷장, 세탁기, 신발장',
#     'original_user_phone': '010-5038-8644',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/178182.jpg',
#     'random_location': '37.4634039695672,126.685019268812',
#     'rent': 25,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 5,
#     'size_contract': 0,
#     'size_m2': '16.53',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '▶▶▶말도안되는 가격!!찾는 분들 많아용◀◀◀',
#     'updated_at': '어제',
#     'user_email': 'bbb53780@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-2914',
#     'user_name': '대표공인중개사(윤소연)',
#     'user_no': 178182,
#     'user_phone': '0507-1280-2914',
#     'view_count': 1429},
#    'title': '인천시 남구 주안동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 남동구 구월동',
#     'address2': '1299-16',
#     'address3': None,
#     'agent_address1': '인천광역시 남동구 구월말로 18 1층 2호(구월동)',
#     'agent_email': 'kimnayun365@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '남동구',
#     'agent_mobile': '0507-1280-8825',
#     'agent_name': '선두공인중개사(김나윤)',
#     'agent_phone': '032-465-7200',
#     'bjd_code': '2820010100',
#     'bonbun_code': '1299',
#     'bubun_code': '16',
#     'building': None,
#     'building_type': '다세대건물',
#     'contract': '인천광역시',
#     'deposit': 10000,
#     'description': '큰방1 작은방1 베란다1 부엌겸 거실 구조입니다.<br />해가 잘 들어 따듯하고 깨끗해요.<br />엘리베이터가 있어 편리하고 주차가 가능한 필로티구조의 빌라입니다.<br />',
#     'description_og': '큰방1 작은방1 베란다1 부엌겸 거실 구조입니다.\n해가 잘 들어 따듯하고 깨끗해요.\n엘리베이터가 있어 편리하고 주차가 가능한 필로티구조의 빌라입니다.\n',
#     'elevator': '있음',
#     'floor': '4층',
#     'floor_all': '5층',
#     'id': 3435731,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3435731/dbe71fd5aa5634152828337b6e6c6e316b080371.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3435731/8a1e1d48dad79c7664c8dcbfe65d185871baf2f5.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3435731/ba9c22b8c8de9d9b6a916f87c2c6c57130b30d3c.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3435731/e90104be691ac507c92fe7ce50cd45a4429dc1c8.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3435731/970131fd8a4c3a5049940aa7de8c2872dadf149b.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3435731/203d773157900cf253aedce0659701e33f55eac9.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3435731/0ab376cf86f10c2d4612d28873f9e4066c14bbda.jpg'},
#      {'count': 8,
#       'index': 7,
#       'url': 'http://z1.zigbang.com/items/3435731/d0794e1207b624f32265b5f62bfe38dede0e1a32.jpg'},
#      {'count': 9,
#       'index': 8,
#       'url': 'http://z1.zigbang.com/items/3435731/d8d7977b79eb3c584c50ab565692dad7696b6543.jpg'}],
#     'images_count': 9,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3435731/dbe71fd5aa5634152828337b6e6c6e316b080371.jpg',
#     'is_deposit_only': True,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '남동구',
#     'local3': '구월동',
#     'manage_cost': '3만원',
#     'manage_cost_inc': '-',
#     'movein_date': '즉시입주가능',
#     'near_subways': '-',
#     'options': '가스레인지, 싱크대',
#     'original_user_phone': '010-6689-9981',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/998884/261b3f65f0a10d132641332f3c7dbebaf1c69980.jpg',
#     'random_location': '37.4511913454373,126.722266385653',
#     'rent': 0,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '01',
#     'room_type': '투룸',
#     'secret_memo': None,
#     'size': 11,
#     'size_contract': 0,
#     'size_m2': '36.36',
#     'size_m2_contract': '-',
#     'status': '광고중',
#     'title': '전세) 방2개 예쁜빌라 인근에서 가장 깨끗하고 주차도 잘 되는 집이에요',
#     'updated_at': '21일 전',
#     'user_email': 'kimnayun365@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-8825',
#     'user_name': '대표공인중개사(김나윤)',
#     'user_no': 998884,
#     'user_phone': '0507-1280-8825',
#     'view_count': 2322},
#    'title': '인천시 남동구 구월동'},
#   {'header': False,
#    'header_height': 0,
#    'item': {'address1': '인천시 부평구 부평동',
#     'address2': '161-12',
#     'address3': None,
#     'agent_address1': '인천광역시 부평구 부평동 536-2 현대더로프트 144호 ',
#     'agent_email': 'leader-rea@naver.com',
#     'agent_local1': '인천시',
#     'agent_local2': '부평구',
#     'agent_mobile': '0507-1280-3958',
#     'agent_name': '리더공인중개사(정두환)',
#     'agent_phone': '032-502-4444',
#     'bjd_code': '2823710100',
#     'bonbun_code': '161',
#     'bubun_code': '12',
#     'building': {'address': '인천시 부평구 부평동 161-12',
#      'address2': '161-12',
#      'building_id': 1418,
#      'count': 21,
#      'elevator': '1',
#      'established': '2013.01',
#      'floor': '14층',
#      'lat': 37.4895477294922,
#      'lng': 126.729904174805,
#      'local1': '인천시',
#      'local2': '부평구',
#      'local3': '부평동',
#      'name': '현대렉스힐',
#      'rooms': '79세대'},
#     'building_type': '오피스텔·도생',
#     'contract': '인천광역시',
#     'deposit': 60,
#     'description': '★ 부평역인근 대로변 건물입니다!!<br /><br />★ 막힌곳 없이 시원한 뷰"<br /><br />★ 정남향!!<br /><br />★ 관리인 상주<br /><br />★ 한번 입주하시면 이사를 안하시네요^^ 빠르게 진행되는 집이오니, 서둘러 주세요~<br /><br />★ 카톡ID : smart032<br /><br />★ 문자, 유선상담 : 부평원룸전문 정두환 소장 ( 010 - 4085 - 8249 ) ',
#     'description_og': '★ 부평역인근 대로변 건물입니다!!\n\n★ 막힌곳 없이 시원한 뷰"\n\n★ 정남향!!\n\n★ 관리인 상주\n\n★ 한번 입주하시면 이사를 안하시네요^^ 빠르게 진행되는 집이오니, 서둘러 주세요~\n\n★ 카톡ID : smart032\n\n★ 문자, 유선상담 : 부평원룸전문 정두환 소장 ( 010 - 4085 - 8249 ) ',
#     'elevator': '있음',
#     'floor': '중층/14층',
#     'floor_all': '14층',
#     'id': 3586029,
#     'images': [{'count': 1,
#       'index': 0,
#       'url': 'http://z1.zigbang.com/items/3586029/9fd764500e26d30ab1f6cd52b07db1e3daa0aabb.jpg'},
#      {'count': 2,
#       'index': 1,
#       'url': 'http://z1.zigbang.com/items/3586029/765857cccb66085e95a8958d8fcf47e2e128b9ef.jpg'},
#      {'count': 3,
#       'index': 2,
#       'url': 'http://z1.zigbang.com/items/3586029/7b7bd9994858852d7947ee7d3157e640241a80d6.jpg'},
#      {'count': 4,
#       'index': 3,
#       'url': 'http://z1.zigbang.com/items/3586029/d60fef4bc302f5fb19f5022eff55e1cc57de19bf.jpg'},
#      {'count': 5,
#       'index': 4,
#       'url': 'http://z1.zigbang.com/items/3586029/71bbf14456acb6462ac4e49c28fd1d23dadd6dc9.jpg'},
#      {'count': 6,
#       'index': 5,
#       'url': 'http://z1.zigbang.com/items/3586029/1b7d3891fbb887486f9d0b726a7f7ee9b5d6a8b1.jpg'},
#      {'count': 7,
#       'index': 6,
#       'url': 'http://z1.zigbang.com/items/3586029/3b16f07e9156e3a1c42e2c11034a0ff677f9e6f6.jpg'}],
#     'images_count': 7,
#     'images_thumbnail': 'http://z1.zigbang.com/items/3586029/9fd764500e26d30ab1f6cd52b07db1e3daa0aabb.jpg',
#     'is_deposit_only': False,
#     'is_direct': False,
#     'is_owner': None,
#     'is_premium': True,
#     'is_premium2': True,
#     'is_realestate': True,
#     'is_room': False,
#     'is_status_close': False,
#     'is_status_open': True,
#     'is_type_room': False,
#     'is_zzim': False,
#     'loan_text': '확인필요',
#     'local1': '인천시',
#     'local2': '부평구',
#     'local3': '부평동',
#     'manage_cost': '5만원',
#     'manage_cost_inc': '인터넷, TV',
#     'movein_date': '즉시입주가능',
#     'near_subways': '부평역(1호선,인천1호선), 부개역(1호선), 동수역(인천1호선)',
#     'options': '에어컨, 냉장고, 세탁기, 가스레인지, 옷장, 신발장, 싱크대',
#     'original_user_phone': '010-4085-8249',
#     'parking': '가능',
#     'pets_text': '확인필요',
#     'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#     'random_location': '37.4892962601067,126.730230239553',
#     'rent': 52,
#     'room_direction_text': '확인필요',
#     'room_gubun_code': '02',
#     'room_type': '원룸(오픈형)',
#     'secret_memo': None,
#     'size': 7,
#     'size_contract': 12,
#     'size_m2': '23.14',
#     'size_m2_contract': '39.67',
#     'status': '광고중',
#     'title': '★신축!! 막힌곳 없이 시원한집★',
#     'updated_at': '7일 전',
#     'user_email': 'leader-rea@naver.com',
#     'user_has_no_penalty': True,
#     'user_has_penalty': False,
#     'user_mobile': '0507-1280-3958',
#     'user_name': '대표공인중개사(정두환)',
#     'user_no': 865247,
#     'user_phone': '0507-1280-3958',
#     'view_count': 448},
#    'title': '인천시 부평구 부평동'}]}

# %%
zigbang_dict.keys()
# 크게 3개의 keys로 이루어짐
# Out:
# dict_keys(['items', 'count_direct', 'count_agent'])

# %%
# zigbang_dict('items')라고 해도 되나 get을 쓰면 데이터가 없는경우도 없다 표시해줌
items_list = zigbang_dict.get('items')
items_list
# Out:
# [{'header': False,
#   'header_height': 0,
#   'item': {'address1': '서울시 양천구 신월동',
#    'address2': '72-1',
#    'address3': None,
#    'agent_address1': '서울특별시 강서구 화곡동 353-91번지',
#    'agent_email': 'kali3222@naver.com',
#    'agent_local1': '서울시',
#    'agent_local2': '강서구',
#    'agent_mobile': '0507-1280-7070',
#    'agent_name': '희망공인중개사(조수빈)',
#    'agent_phone': '010-4089-3222',
#    'bjd_code': '1147010300',
#    'bonbun_code': '72',
#    'bubun_code': '1',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '서울특별시',
#    'deposit': 13000,
#    'description': '❤신혼❤~대박!!~올수리되어 있는 신축빌라급 전세, 전세자금대출가능 역세권 신혼부부추천, 완전 저렴한 전세보증금으로 신혼을 시작해요❤신혼❤<br />완전 저렴하죠^^ 꼭 구경하시기 바랍니다. 공실이라 즉시 입주가능합니다.<br /><br />◆ 강서,양천 신혼집(신축빌라)전문 부동산입니다. 좋은인연 만들어봐요!!<br />◆ 1억원짜리 중개업보험에 가입한 정회원업소로 구청에 등록된 담당자입니다.<br />◆ 100% 현장답사가서 제가 직접본 물건만 올리겠습니다!!<br />◆ 작은 문의라도 친절히 답변 드릴께요.^^*  24시간 상담가능합니다~<br /><br />▶전세금액◀<br />전세 13000만원이구요~  전세자금대출 환영합니다.<br /><br />▶위치◀<br />5호선 화곡역에서  도보 약 8분거리 주택가에 있는집이라<br />밤늦게 귀가하시는 여성분들도 안전한 집이예요^^<br /><br />▶크기◀<br />실평수 약 13평으로 신혼집으로 시작하기에 안성맞춤이예요<br />tv랑 작은 쇼파자리가 나오는 거실크기에 작은방 하나는 옷방으로 좋을듯해요~<br /><br />▶엘리베이터◀<br />없어요^^ 그래도 3층이니까 힘들지 않아요.<br /><br /><br />▶옵션◀<br />씽크대,가스렌지,신발장<br /><br />▶주차◀<br />100% 가능합니다 이중주차가 아니라서 차빼주는 번거로움이 없어서 좋아요.<br /><br /><br />',
#    'description_og': '❤신혼❤~대박!!~올수리되어 있는 신축빌라급 전세, 전세자금대출가능 역세권 신혼부부추천, 완전 저렴한 전세보증금으로 신혼을 시작해요❤신혼❤\n완전 저렴하죠^^ 꼭 구경하시기 바랍니다. 공실이라 즉시 입주가능합니다.\n\n◆ 강서,양천 신혼집(신축빌라)전문 부동산입니다. 좋은인연 만들어봐요!!\n◆ 1억원짜리 중개업보험에 가입한 정회원업소로 구청에 등록된 담당자입니다.\n◆ 100% 현장답사가서 제가 직접본 물건만 올리겠습니다!!\n◆ 작은 문의라도 친절히 답변 드릴께요.^^*  24시간 상담가능합니다~\n\n▶전세금액◀\n전세 13000만원이구요~  전세자금대출 환영합니다.\n\n▶위치◀\n5호선 화곡역에서  도보 약 8분거리 주택가에 있는집이라\n밤늦게 귀가하시는 여성분들도 안전한 집이예요^^\n\n▶크기◀\n실평수 약 13평으로 신혼집으로 시작하기에 안성맞춤이예요\ntv랑 작은 쇼파자리가 나오는 거실크기에 작은방 하나는 옷방으로 좋을듯해요~\n\n▶엘리베이터◀\n없어요^^ 그래도 3층이니까 힘들지 않아요.\n\n\n▶옵션◀\n씽크대,가스렌지,신발장\n\n▶주차◀\n100% 가능합니다 이중주차가 아니라서 차빼주는 번거로움이 없어서 좋아요.\n\n\n',
#    'elevator': '없음',
#    'floor': '3층',
#    'floor_all': '5층',
#    'id': 3596008,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3596008/42b0d5df0d09e7f3a6daa7d1136cd83d8f1fea41.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3596008/59c52e0f4eefaad9fa8ab529ff54a9a334431016.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3596008/8c6c1b530460876328518edb3dda4993c83fb058.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3596008/098c76ccfbf0c4689ea2f2543ab3d3318e241751.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3596008/645241e5f79c3b33e1f0596066537f951d7abcad.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3596008/c1126ca107afc88768c092850e16a6d61804cc03.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3596008/cc20acd98cc76d8d1a99109efa1956d07a83406d.jpg'},
#     {'count': 8,
#      'index': 7,
#      'url': 'http://z1.zigbang.com/items/3596008/729cff17be1a69be78a5edc70acbe0f5034cc762.jpg'},
#     {'count': 9,
#      'index': 8,
#      'url': 'http://z1.zigbang.com/items/3596008/6138a3c1bbcf378bb38f51697a8b15f84500fd9f.jpg'},
#     {'count': 10,
#      'index': 9,
#      'url': 'http://z1.zigbang.com/items/3596008/eba2d07bf989e901f558d62096870db57c30d8bf.jpg'},
#     {'count': 11,
#      'index': 10,
#      'url': 'http://z1.zigbang.com/items/3596008/c58c46bc4c782b5fd1bb3bea7f4446298a3cd9fc.jpg'},
#     {'count': 12,
#      'index': 11,
#      'url': 'http://z1.zigbang.com/items/3596008/351a009e54d609206e600eee774c39f0cd0bf0b5.jpg'},
#     {'count': 13,
#      'index': 12,
#      'url': 'http://z1.zigbang.com/items/3596008/ac02dadf8e02748c78836f10ab8802ad608fe138.jpg'}],
#    'images_count': 13,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3596008/42b0d5df0d09e7f3a6daa7d1136cd83d8f1fea41.jpg',
#    'is_deposit_only': True,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '서울시',
#    'local2': '양천구',
#    'local3': '신월동',
#    'manage_cost': '없음',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시입주',
#    'near_subways': '화곡역(5호선), 우장산역(5호선), 까치산역(2호선,5호선)',
#    'options': '가스레인지, 신발장, 싱크대',
#    'original_user_phone': '010-4089-3222',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#    'random_location': '37.5380669151943,126.831496353804',
#    'rent': 0,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '투룸',
#    'secret_memo': None,
#    'size': 14,
#    'size_contract': 0,
#    'size_m2': '46.28',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '❤신혼❤~대박!!~올수리되어 있는 신축빌라급 전세, 전세자금대출가능 역세권 신혼부부추천, 완전 저렴한 전세보증금으로 신혼을 시작해요❤신혼❤~',
#    'updated_at': '어제',
#    'user_email': 'kali3222@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-7070',
#    'user_name': '대표공인중개사(조수빈)',
#    'user_no': 321735,
#    'user_phone': '0507-1280-7070',
#    'view_count': 384},
#   'title': '서울시 양천구 신월동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 서구 석남동',
#    'address2': '556-45',
#    'address3': None,
#    'agent_address1': '인천광역시 서구 길주로88번길 34',
#    'agent_email': 'choibuja1460@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '서구',
#    'agent_mobile': '0507-1280-1140',
#    'agent_name': '부자공인중개사(최은미)',
#    'agent_phone': '032-581-6000',
#    'bjd_code': '2826011000',
#    'bonbun_code': '556',
#    'bubun_code': '45',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '인천광역시',
#    'deposit': 500,
#    'description': '- 현재 공실이므로 편하실 때 입주 가능합니다<br />- 내부가 깔끔합니다<br />-  교통편이 편리합니다',
#    'description_og': '- 현재 공실이므로 편하실 때 입주 가능합니다\n- 내부가 깔끔합니다\n-  교통편이 편리합니다',
#    'elevator': '없음',
#    'floor': '3층',
#    'floor_all': '4층',
#    'id': 3379714,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3379714/07a9b7d25a19dbd0e579be4ea88d20965f50dbdf.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3379714/62de4f7ba941065ca81f3c48f5ce51e9ee980416.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3379714/7fa32ebb00457b107821a3294d869560e8fdf210.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3379714/1a48e5a5bac8b009022c9f5c1001e228133f84e7.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3379714/c0c98c6790ee858a109d557b20b805d3845ddd7c.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3379714/fded3cc12687e9d2866fb1725a64915ed8f659f9.jpg'}],
#    'images_count': 6,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3379714/07a9b7d25a19dbd0e579be4ea88d20965f50dbdf.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '서구',
#    'local3': '석남동',
#    'manage_cost': '없음',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시입주 가능',
#    'near_subways': '-',
#    'options': '신발장, 싱크대',
#    'original_user_phone': '010-3366-1460',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#    'random_location': '37.5040620076845,126.676573609038',
#    'rent': 25,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '투룸',
#    'secret_memo': None,
#    'size': 12,
#    'size_contract': 0,
#    'size_m2': '39.67',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '깔끔하고 저렴한 빌라 월세',
#    'updated_at': '22일 전',
#    'user_email': 'choibuja1460@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-1140',
#    'user_name': '대표공인중개사(최은미)',
#    'user_no': 780299,
#    'user_phone': '0507-1280-1140',
#    'view_count': 1585},
#   'title': '인천시 서구 석남동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 남동구 간석동',
#    'address2': '214-15',
#    'address3': None,
#    'agent_address1': '인천광역시 남동구 백범로 381 , 109호(간석동,웰스하임)',
#    'agent_email': 'sanyokn@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '남동구',
#    'agent_mobile': '0507-1280-5215',
#    'agent_name': '웰스공인중개사(이정아)',
#    'agent_phone': '032-421-4220',
#    'bjd_code': '2820010200',
#    'bonbun_code': '214',
#    'bubun_code': '15',
#    'building': {'address': '인천시 남동구 간석동 214-15',
#     'address2': '214-15',
#     'building_id': 18250,
#     'count': 9,
#     'elevator': '1',
#     'established': '2014.05',
#     'floor': '19층',
#     'lat': 37.4665,
#     'lng': 126.7084,
#     'local1': '인천시',
#     'local2': '남동구',
#     'local3': '간석동',
#     'name': '웰스하임',
#     'rooms': '240세대'},
#    'building_type': '오피스텔·도생',
#    'contract': '인천광역시',
#    'deposit': 70,
#    'description': '           (・´з`・)♥<br /><br /><br />안녕하세요~^^ 방구하실려고 클릭하셨죠?<br /><br /><br /><br />저희는 무보증부터 시작해서 다양한 매물 보유하고있는 웰스부동산입니다<br /><br />친절하고 책임감있는 중개를 약속드리겠습니다.<br /><br /><br /><br />▶방 소개◀<br /><br />간석오거리역 초역세권에 위치한 웰스하임 희귀 B타입 매물입니다.<br /><br />현재 즉시입주가능한 공실이며, 입주청소까지 완료되어있습니다.<br /><br />풀옵션 + 주변교통편리하고, 편의시설까지 완비되어있는 매물입니다. 乃<br /><br /><br />▶상 담◀<br /><br />24시간 언제든 편한시간에 연락주시면 친절하고 확실한 상담을 도와드리겠습니다.<br /><br />해당 매물이 마음에 안드셔도 내집을 구하는 마음으로 찾으시는 매물 책임지고 구해드리겠습니다.<br /><br /><br />언제든 연락주세요~<br /><br />',
#    'description_og': '           (・´з`・)♥\n\n\n안녕하세요~^^ 방구하실려고 클릭하셨죠?\n\n\n\n저희는 무보증부터 시작해서 다양한 매물 보유하고있는 웰스부동산입니다\n\n친절하고 책임감있는 중개를 약속드리겠습니다.\n\n\n\n▶방 소개◀\n\n간석오거리역 초역세권에 위치한 웰스하임 희귀 B타입 매물입니다.\n\n현재 즉시입주가능한 공실이며, 입주청소까지 완료되어있습니다.\n\n풀옵션 + 주변교통편리하고, 편의시설까지 완비되어있는 매물입니다. 乃\n\n\n▶상 담◀\n\n24시간 언제든 편한시간에 연락주시면 친절하고 확실한 상담을 도와드리겠습니다.\n\n해당 매물이 마음에 안드셔도 내집을 구하는 마음으로 찾으시는 매물 책임지고 구해드리겠습니다.\n\n\n언제든 연락주세요~\n\n',
#    'elevator': '있음',
#    'floor': '고층/19층',
#    'floor_all': '19층',
#    'id': 3616656,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3616656/a3b1280c68edb02c72234011a7f6470f50faa5a2.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3616656/4a9c27a9dfa22e58793383005f3f1b3b0a2dff82.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3616656/ce071cd98bfc2274cd717dfc5243e3214b4c2154.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3616656/cd380e240ab4f2c84f6015df7880becbee7b4706.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3616656/e4e9a95e2a8eedd10bd1ede058572337d8b83848.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3616656/4871797867df3dfa86cb820eb75aa7a921f95bc6.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3616656/e99fb6806011bc3b15e31eead5ba9fd9cacee476.jpg'},
#     {'count': 8,
#      'index': 7,
#      'url': 'http://z1.zigbang.com/items/3616656/de9094b04c9814d436b64d12d097f4cb61151e40.jpg'},
#     {'count': 9,
#      'index': 8,
#      'url': 'http://z1.zigbang.com/items/3616656/a3d2c9fbf87314a505f7e979cd160bbe1999ea83.jpg'},
#     {'count': 10,
#      'index': 9,
#      'url': 'http://z1.zigbang.com/items/3616656/72689fc0cbe78b585952d225685f635a7972dd72.jpg'}],
#    'images_count': 10,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3616656/a3b1280c68edb02c72234011a7f6470f50faa5a2.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '남동구',
#    'local3': '간석동',
#    'manage_cost': '6만원',
#    'manage_cost_inc': '인터넷, TV',
#    'movein_date': '즉시입주',
#    'near_subways': '간석오거리역(인천1호선), 동암역(1호선), 인천시청역(인천1호선)',
#    'options': '에어컨, 냉장고, 인덕션, 침대, 옷장, 신발장',
#    'original_user_phone': '010-3815-1670',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/107480.jpg',
#    'random_location': '37.4662485465527,126.708076106715',
#    'rent': 69,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '02',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 11,
#    'size_contract': 21,
#    'size_m2': '36.36',
#    'size_m2_contract': '69.42',
#    'status': '광고중',
#    'title': '간석오거리 웰스하임B타입 희귀매물 즉시입주',
#    'updated_at': '5일 전',
#    'user_email': 'dlwlgbf@nate.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-5471',
#    'user_name': '이지훈',
#    'user_no': 107480,
#    'user_phone': '0507-1280-5471',
#    'view_count': 503},
#   'title': '인천시 남동구 간석동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 서구 석남동',
#    'address2': '499',
#    'address3': None,
#    'agent_address1': '인천광역시 서구 길주로88번길 34',
#    'agent_email': 'choibuja1460@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '서구',
#    'agent_mobile': '0507-1280-1140',
#    'agent_name': '부자공인중개사(최은미)',
#    'agent_phone': '032-581-6000',
#    'bjd_code': '2826011000',
#    'bonbun_code': '499',
#    'bubun_code': '',
#    'building': None,
#    'building_type': '아파트',
#    'contract': '인천광역시',
#    'deposit': 500,
#    'description': '- 올수리 되어  최고의 인테리어입니다.<br />- 조용하고 아늑한 주택가 안에 있습니다<br />- 관리실이 있어 유지 보수가 잘되어 깨끗한 단지입니다.',
#    'description_og': '- 올수리 되어  최고의 인테리어입니다.\n- 조용하고 아늑한 주택가 안에 있습니다\n- 관리실이 있어 유지 보수가 잘되어 깨끗한 단지입니다.',
#    'elevator': '없음',
#    'floor': '5층',
#    'floor_all': '6층',
#    'id': 3379438,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3379438/866ce38c974d8ba8f5df9584c15351027cec4cd3.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3379438/bccdc920522d817454db06872a782a63d9d28488.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3379438/cb21a4e3316f82c866dafe7db74e9425b591d2ec.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3379438/6216a533fed971a8b8ba9863672c21d5e5465dcb.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3379438/aed53d4163dc3289224f9455ac7ee4c44d3e515c.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3379438/00cbca931476a9b9bc562352ec4b0cd3c59904f2.jpg'}],
#    'images_count': 6,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3379438/866ce38c974d8ba8f5df9584c15351027cec4cd3.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '서구',
#    'local3': '석남동',
#    'manage_cost': '2만원',
#    'manage_cost_inc': '수도',
#    'movein_date': '즉시입주 가능',
#    'near_subways': '-',
#    'options': '신발장, 싱크대',
#    'original_user_phone': '010-3366-1460',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#    'random_location': '37.5086095430456,126.674322543101',
#    'rent': 35,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '03',
#    'room_type': '투룸',
#    'secret_memo': None,
#    'size': 11,
#    'size_contract': 14,
#    'size_m2': '36.36',
#    'size_m2_contract': '46.28',
#    'status': '광고중',
#    'title': '올수리 태산아파트 월세',
#    'updated_at': '7일 전',
#    'user_email': 'choibuja1460@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-1140',
#    'user_name': '대표공인중개사(최은미)',
#    'user_no': 780299,
#    'user_phone': '0507-1280-1140',
#    'view_count': 1828},
#   'title': '인천시 서구 석남동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '경기도 부천시 원미구 상동',
#    'address2': '545-17',
#    'address3': None,
#    'agent_address1': '경기도 부천시 원미구 소향로13번길 14-23 , 101호 (상동, 삼성프라자)',
#    'agent_email': 'nakji1@naver.com',
#    'agent_local1': '경기도',
#    'agent_local2': '부천시 원미구',
#    'agent_mobile': '0507-1280-0888',
#    'agent_name': '한백공인중개사(이대진)',
#    'agent_phone': '032-321-8089',
#    'bjd_code': '4119510900',
#    'bonbun_code': '545',
#    'bubun_code': '17',
#    'building': {'address': '경기도 부천시 원미구 상동 545-17',
#     'address2': '545-17',
#     'building_id': 1646,
#     'count': 6,
#     'elevator': '1',
#     'established': '2003.06',
#     'floor': '8층',
#     'lat': 37.5045051574707,
#     'lng': 126.75009155273438,
#     'local1': '경기도',
#     'local2': '부천시 원미구',
#     'local3': '상동',
#     'name': '대야하이빌III',
#     'rooms': '84세대'},
#    'building_type': '오피스텔·도생',
#    'contract': '경기도',
#    'deposit': 3500,
#    'description': '상동역 5분거리의 오피스텔형의 원룸전세<br />아주 깨끗하고<br />아담해서 1,2인이 거주하기에 딱 좋아요<br />보증금 월세 조정가능하구요 무보증도 가능함',
#    'description_og': '상동역 5분거리의 오피스텔형의 원룸전세\n아주 깨끗하고\n아담해서 1,2인이 거주하기에 딱 좋아요\n보증금 월세 조정가능하구요 무보증도 가능함',
#    'elevator': '있음',
#    'floor': '저층/8층',
#    'floor_all': '8층',
#    'id': 3373685,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3373685/fcbec13985475cf96e91a3209d381e096738e024.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3373685/01b35b8bc2abd9923f8559e6d7ae61c8cbdcfe74.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3373685/89e4f50988f20b4ab136a261749b501031e278fa.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3373685/0079a16d152f533bce91ecf71c97fb737c199a58.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3373685/b6ec821d733cf4e63cffb8940276e8aec9229269.jpg'}],
#    'images_count': 5,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3373685/fcbec13985475cf96e91a3209d381e096738e024.jpg',
#    'is_deposit_only': True,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '경기도',
#    'local2': '부천시 원미구',
#    'local3': '상동',
#    'manage_cost': '5~8만원',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시입주',
#    'near_subways': '상동역(7호선), 삼산체육관역(7호선), 부천시청역(7호선)',
#    'options': '에어컨, 냉장고, 세탁기, 인덕션, 신발장, 싱크대',
#    'original_user_phone': '010-9611-8089',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#    'random_location': '37.5042729310807,126.749779967551',
#    'rent': 0,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '02',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 5,
#    'size_contract': 11,
#    'size_m2': '16.53',
#    'size_m2_contract': '36.36',
#    'status': '광고중',
#    'title': '오피스텔형 원룸 전세',
#    'updated_at': '22일 전',
#    'user_email': 'nakji1@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-0888',
#    'user_name': '대표공인중개사(이대진)',
#    'user_no': 932294,
#    'user_phone': '0507-1280-0888',
#    'view_count': 2708},
#   'title': '경기도 부천시 원미구 상동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 남구 문학동',
#    'address2': '355-27',
#    'address3': None,
#    'agent_address1': '인천광역시 남구 문학동 342-6번지',
#    'agent_email': 'aaaa403@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '남구',
#    'agent_mobile': '0507-1280-8811',
#    'agent_name': '포스트공인중개사(김동면)',
#    'agent_phone': '032-431-4488',
#    'bjd_code': '2817010900',
#    'bonbun_code': '355',
#    'bubun_code': '27',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '인천광역시',
#    'deposit': 30,
#    'description': '1. 신축같이 올수리 풀옵션<br />2.모든 옵션 새것으로 처음 사용<br />3.문학동 방을 전문으로하는 부동산으로 모든방 직방으로 구해드립니다.<br />4.방은 항상 볼수 있습니다<br />===============================================<br />** 문학동 대로변 문학초등학교옆 포스트부동산으로 오시면 모든방 직방으로 구해 드립니다.**',
#    'description_og': '1. 신축같이 올수리 풀옵션\n2.모든 옵션 새것으로 처음 사용\n3.문학동 방을 전문으로하는 부동산으로 모든방 직방으로 구해드립니다.\n4.방은 항상 볼수 있습니다\n===============================================\n** 문학동 대로변 문학초등학교옆 포스트부동산으로 오시면 모든방 직방으로 구해 드립니다.**',
#    'elevator': '없음',
#    'floor': '3층',
#    'floor_all': '4층',
#    'id': 3661814,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3661814/cbf2e4ede180fa0c91e7fdd4384b1b4bc242641f.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3661814/b1ed616e7e6a7c91fdf5a8938f1d6ae8dc07c9b4.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3661814/b9cfe9ee4f2bcc29225efb2e699932799d7fcb67.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3661814/dbc8967d3ffa4fe90f7d5098a817ec9ce68c1ac3.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3661814/8106b7214816cdeb3f47229f5f07b2b03cb1ee82.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3661814/8526625cb8ab0350f0c5a8959fb5072dbec14b7d.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3661814/e9fa6d18af3598f4d4f0a4b52d93071a6e5226e3.jpg'},
#     {'count': 8,
#      'index': 7,
#      'url': 'http://z1.zigbang.com/items/3661814/ae64c1fbcafc96cda18a4ef670869d3347f5d1c2.jpg'},
#     {'count': 9,
#      'index': 8,
#      'url': 'http://z1.zigbang.com/items/3661814/ec76a2924a6ca05bca7369700473ad7953a23749.jpg'}],
#    'images_count': 9,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3661814/cbf2e4ede180fa0c91e7fdd4384b1b4bc242641f.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '남구',
#    'local3': '문학동',
#    'manage_cost': '5만원',
#    'manage_cost_inc': '인터넷, TV',
#    'movein_date': '즉시입주',
#    'near_subways': '-',
#    'options': '에어컨, 냉장고, 세탁기, 가스레인지, 침대, 옷장, 신발장, 싱크대',
#    'original_user_phone': '010-9024-8996',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/465552/8cef55d370f8239e7cca4682655f1782bcfd15bf.jpg',
#    'random_location': '37.4391175941361,126.679673317133',
#    'rent': 33,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '원룸(분리형)',
#    'secret_memo': None,
#    'size': 9,
#    'size_contract': 0,
#    'size_m2': '29.75',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '★★ 신축같이 리모델링 모든옵션 새것 공실 즉시입주 ...  보증금 가능★★',
#    'updated_at': '어제',
#    'user_email': 'aaaa403@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-8811',
#    'user_name': '대표공인중개사(김동면)',
#    'user_no': 465552,
#    'user_phone': '0507-1280-8811',
#    'view_count': 53},
#   'title': '인천시 남구 문학동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 남동구 구월동',
#    'address2': '1210-10',
#    'address3': None,
#    'agent_address1': '인천광역시 남동구 인주대로 604번길 12, 102호(구월동)',
#    'agent_email': 'wldms0195@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '남동구',
#    'agent_mobile': '0507-1280-8049',
#    'agent_name': '부동산정보공인중개사(김진영)',
#    'agent_phone': '032-425-5130',
#    'bjd_code': '2820010100',
#    'bonbun_code': '1210',
#    'bubun_code': '10',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '인천광역시',
#    'deposit': 200,
#    'description': '듬직하게 중개 하겠습니다. 믿고 문의주세요<br /><br />- 이방은 요 ?<br /><br />* 풀옵션 겸비한 지상층 원룸<br /><br />* 인터넷 되는 원룸<br /><br />* 역세권<br /><br />* 조금더 궁금한 사항은 편하게 문의주세요',
#    'description_og': '듬직하게 중개 하겠습니다. 믿고 문의주세요\n\n- 이방은 요 ?\n\n* 풀옵션 겸비한 지상층 원룸\n\n* 인터넷 되는 원룸\n\n* 역세권\n\n* 조금더 궁금한 사항은 편하게 문의주세요',
#    'elevator': '없음',
#    'floor': '1층',
#    'floor_all': '4층',
#    'id': 3675619,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3675619/579aaa9408a3cd889b28656ebad4ab6778329bff.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3675619/ad282baedc68741b9f6c50593f042e25a176ed89.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3675619/b19be416b5f0914a54fde74fa7f2e032a5da35bc.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3675619/22eff0e2caa4333c4b9408990063185467681667.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3675619/91f0074f142937fd2877ca052501d529f038ca27.jpg'}],
#    'images_count': 5,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3675619/579aaa9408a3cd889b28656ebad4ab6778329bff.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': False,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '남동구',
#    'local3': '구월동',
#    'manage_cost': '5만원',
#    'manage_cost_inc': '수도, 인터넷, TV',
#    'movein_date': '즉시',
#    'near_subways': '예술회관역(인천1호선), 인천시청역(인천1호선)',
#    'options': '에어컨, 냉장고, 세탁기, 가스레인지, 침대, 옷장, 싱크대',
#    'original_user_phone': '010-4904-5833',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#    'random_location': '37.4509443971089,126.712239688854',
#    'rent': 17,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 7,
#    'size_contract': 0,
#    'size_m2': '23.14',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '★★이방어때?★컥컥 !! 이렇게 저렴하다니..',
#    'updated_at': '20시간 전',
#    'user_email': 'prosst2@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-8305',
#    'user_name': '중개보조원(김선수)',
#    'user_no': 702503,
#    'user_phone': '0507-1280-8305',
#    'view_count': 90},
#   'title': '인천시 남동구 구월동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 남구 주안동',
#    'address2': '25-34',
#    'address3': None,
#    'agent_address1': '인천광역시 남구 주안동 219-4 네오빌주상복합 101호',
#    'agent_email': 'dlspsnsnem@hanmail.net',
#    'agent_local1': '인천시',
#    'agent_local2': '남구',
#    'agent_mobile': '0507-1280-2147',
#    'agent_name': '네오빌공인중개사(라한현)',
#    'agent_phone': '010-3269-6971',
#    'bjd_code': '2817010600',
#    'bonbun_code': '25',
#    'bubun_code': '34',
#    'building': {'address': '인천시 남구 주안동 25-34',
#     'address2': '25-34',
#     'building_id': 1163,
#     'count': 8,
#     'elevator': '1',
#     'established': '2012.10',
#     'floor': '15층',
#     'lat': 37.46622085571289,
#     'lng': 126.67790222167969,
#     'local1': '인천시',
#     'local2': '남구',
#     'local3': '주안동',
#     'name': '베스티움',
#     'rooms': '353세대'},
#    'building_type': '오피스텔·도생',
#    'contract': '인천광역시',
#    'deposit': 50,
#    'description': '서울까지 한번에 갈수 있는 주안역이 있어<br />교통편이 우수한 주안원룸 입니다.<br /><br />먹자거리 cgv 대형할인마트 재래시장 병원 은행등<br />주변생활시설이 너무 좋은 주안원룸 이에요<br /><br />햇살이 좋아 습하거나 곰팡이 걱정이 없으며,<br />2명이 생활하여도 충분한 크기인 주안원룸 입니다.',
#    'description_og': '서울까지 한번에 갈수 있는 주안역이 있어\n교통편이 우수한 주안원룸 입니다.\n\n먹자거리 cgv 대형할인마트 재래시장 병원 은행등\n주변생활시설이 너무 좋은 주안원룸 이에요\n\n햇살이 좋아 습하거나 곰팡이 걱정이 없으며,\n2명이 생활하여도 충분한 크기인 주안원룸 입니다.',
#    'elevator': '있음',
#    'floor': '고층/15층',
#    'floor_all': '15층',
#    'id': 3430114,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3430114/ab293d824c165170a785e24e5cb2368831da382a.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3430114/9853ed52ead7ab8b270af57eef2af8a9cd77f16e.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3430114/3138845cfbe19c5455023af042ce90d794c2de50.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3430114/0a134221d55f3b684e13f0a485165ecfeb517812.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3430114/017452c04ef31d7c499aef36465b73c7f3002149.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3430114/d9feb6927a8ff150d15bc9ffcd0b45bbe1261e50.jpg'}],
#    'images_count': 6,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3430114/ab293d824c165170a785e24e5cb2368831da382a.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '남구',
#    'local3': '주안동',
#    'manage_cost': '4만원',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시입주',
#    'near_subways': '주안역(1호선), 도화역(1호선), 간석역(1호선)',
#    'options': '싱크대, 에어컨, 인덕션, 냉장고, 세탁기, 신발장',
#    'original_user_phone': '010-5623-2224',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/223224.jpg',
#    'random_location': '37.466460439796,126.678228540948',
#    'rent': 40,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '02',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 6,
#    'size_contract': 7,
#    'size_m2': '19.83',
#    'size_m2_contract': '23.14',
#    'status': '광고중',
#    'title': '주안 깔끔한 오피스텔 - 보증금 저렴 월세 저렴',
#    'updated_at': '21일 전',
#    'user_email': 'kkccan@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-2403',
#    'user_name': '중개보조원(박영상)',
#    'user_no': 223224,
#    'user_phone': '0507-1280-2403',
#    'view_count': 1238},
#   'title': '인천시 남구 주안동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 부평구 부평동',
#    'address2': '496-8',
#    'address3': None,
#    'agent_address1': '인천광역시 부평구 부평문화로 127 (부평동)',
#    'agent_email': 'alfo5080@hanmail.net',
#    'agent_local1': '인천시',
#    'agent_local2': '부평구',
#    'agent_mobile': '0507-1280-6524',
#    'agent_name': '미래공인중개사(오성택)',
#    'agent_phone': '032-516-0045',
#    'bjd_code': '2823710100',
#    'bonbun_code': '496',
#    'bubun_code': '8',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '인천광역시',
#    'deposit': 17000,
#    'description': '*부평역 근접해 있는 최고의 집입니다<br />  <br />   방4개 넓은 왕테라스  베란다 3개  창고 1개 <br /><br />*주의!!  사진은 실사 아닙니다  현 거주중이어서  사진 촬영불가  그렇치만 집 너무~~~~좋아요',
#    'description_og': '*부평역 근접해 있는 최고의 집입니다\n  \n   방4개 넓은 왕테라스  베란다 3개  창고 1개 \n\n*주의!!  사진은 실사 아닙니다  현 거주중이어서  사진 촬영불가  그렇치만 집 너무~~~~좋아요',
#    'elevator': '있음',
#    'floor': '7층',
#    'floor_all': '7층',
#    'id': 3584676,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3584676/e0fd87eec93b2a7c597c47ce15d89223294fa876.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3584676/c07b3bd42e92b7dacc3f8053208042ad06527bf2.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3584676/3c613385a637a92b991ae536c0dc610879d25276.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3584676/4ee52980b3238dad0c0418f4debb8141ee8c47aa.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3584676/26507d1099b43b47061ddeba4733facf748c33ff.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3584676/01ecbd954bd89e02dc46c43886e996e1912038cf.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3584676/6fa11398c3908363a2911da5f667851ffbaae76c.jpg'},
#     {'count': 8,
#      'index': 7,
#      'url': 'http://z1.zigbang.com/items/3584676/4ee52980b3238dad0c0418f4debb8141ee8c47aa.jpg'},
#     {'count': 9,
#      'index': 8,
#      'url': 'http://z1.zigbang.com/items/3584676/2b40d15114f7fae309480bf59962a4fe9c07f105.jpg'},
#     {'count': 10,
#      'index': 9,
#      'url': 'http://z1.zigbang.com/items/3584676/9a4340d7bd1c69970ad6d736e476464a120f186f.jpg'},
#     {'count': 11,
#      'index': 10,
#      'url': 'http://z1.zigbang.com/items/3584676/369af0c42d160044146b9c7c99453860c3a292de.jpg'},
#     {'count': 12,
#      'index': 11,
#      'url': 'http://z1.zigbang.com/items/3584676/6fa11398c3908363a2911da5f667851ffbaae76c.jpg'},
#     {'count': 13,
#      'index': 12,
#      'url': 'http://z1.zigbang.com/items/3584676/2377848ce7d417f3b94e36027923524a24a456d0.jpg'},
#     {'count': 14,
#      'index': 13,
#      'url': 'http://z1.zigbang.com/items/3584676/3be57ea99b00ae5c60cc1a088119827595511fac.jpg'}],
#    'images_count': 14,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3584676/e0fd87eec93b2a7c597c47ce15d89223294fa876.jpg',
#    'is_deposit_only': True,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '부평구',
#    'local3': '부평동',
#    'manage_cost': '3만원',
#    'manage_cost_inc': '-',
#    'movein_date': '4월25일 이후',
#    'near_subways': '부평역(1호선,인천1호선), 부개역(1호선), 동수역(인천1호선)',
#    'options': '가스레인지, 신발장, 싱크대',
#    'original_user_phone': '010-8299-1297',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': None,
#    'random_location': '37.4903189102002,126.731553473247',
#    'rent': 0,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '쓰리룸+',
#    'secret_memo': None,
#    'size': 28,
#    'size_contract': 0,
#    'size_m2': '92.56',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '왕테라스에 방4개 전세.................',
#    'updated_at': '7일 전',
#    'user_email': 'alfo5080@hanmail.net',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-6524',
#    'user_name': '대표공인중개사(오성택)',
#    'user_no': 1103591,
#    'user_phone': '0507-1280-6524',
#    'view_count': 824},
#   'title': '인천시 부평구 부평동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 부평구 삼산동',
#    'address2': '260-12',
#    'address3': None,
#    'agent_address1': '인천광역시 계양구 계산새로 71 , A동 110호',
#    'agent_email': 'cdj_us@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '계양구',
#    'agent_mobile': '0507-1280-3687',
#    'agent_name': '엘리트공인중개사(조동진)',
#    'agent_phone': '010-6899-5585',
#    'bjd_code': '2823710500',
#    'bonbun_code': '260',
#    'bubun_code': '12',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '인천광역시',
#    'deposit': 6500,
#    'description': '교통좋은 삼산동 빌라 전세 입니다~<br /><br />도보로 갈산역 8분 , 버스로 1분 <br /><br />7호선 부평구청역 버스로 5분   입니다. ',
#    'description_og': '교통좋은 삼산동 빌라 전세 입니다~\n\n도보로 갈산역 8분 , 버스로 1분 \n\n7호선 부평구청역 버스로 5분   입니다. ',
#    'elevator': '없음',
#    'floor': '4층',
#    'floor_all': '4층',
#    'id': 2895993,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/2895993/f440145c9b6648913746d4ebddeab88a3accdec6.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/2895993/3fd29111db6a34ac6fc113528de9589419c9b5a5.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/2895993/c4b8762d645fba40334ce438853b61db90d5dc56.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/2895993/37aea0a7608ba32ad108036eb9574ee09c6fa700.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/2895993/841470f3988f8a238655517e5233b060d60b7659.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/2895993/0a7002a8089afe0abe662042d7a9fa078639adca.jpg'}],
#    'images_count': 6,
#    'images_thumbnail': 'http://z1.zigbang.com/items/2895993/f440145c9b6648913746d4ebddeab88a3accdec6.jpg',
#    'is_deposit_only': True,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '부평구',
#    'local3': '삼산동',
#    'manage_cost': '없음',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시입주',
#    'near_subways': '갈산역(인천1호선), 삼산체육관역(7호선), 굴포천역(7호선)',
#    'options': '싱크대',
#    'original_user_phone': '032-548-5585',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/342157/b8a3948d910303ee1ae681cae1427d4a1ae96cb0.jpg',
#    'random_location': '37.5187732628016,126.733325444267',
#    'rent': 0,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '투룸',
#    'secret_memo': None,
#    'size': 9,
#    'size_contract': 0,
#    'size_m2': '29.75',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '교통좋은 삼산동 빌라 전세 입니다~',
#    'updated_at': '10일 전',
#    'user_email': 'cdj_us@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-3687',
#    'user_name': '대표공인중개사(조동진)',
#    'user_no': 342157,
#    'user_phone': '0507-1280-3687',
#    'view_count': 6925},
#   'title': '인천시 부평구 삼산동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 남구 주안동',
#    'address2': '928-8',
#    'address3': None,
#    'agent_address1': '인천광역시 남구 주안동 928-8 더 펠리체 102호',
#    'agent_email': 'jw9711@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '남구',
#    'agent_mobile': '0507-1281-4021',
#    'agent_name': '해마루공인중개사(김진영)',
#    'agent_phone': '032-432-6200',
#    'bjd_code': '2817010600',
#    'bonbun_code': '928',
#    'bubun_code': '8',
#    'building': {'address': '인천시 남구 주안동 928-8',
#     'address2': '928-8',
#     'building_id': 18840,
#     'count': 29,
#     'elevator': '1',
#     'established': '2015.12',
#     'floor': '15층',
#     'lat': 37.4632,
#     'lng': 126.6902,
#     'local1': '인천시',
#     'local2': '남구',
#     'local3': '주안동',
#     'name': '해마루더펠리체',
#     'rooms': '280세대'},
#    'building_type': '오피스텔·도생',
#    'contract': '인천광역시',
#    'deposit': 500,
#    'description': '말이 필요없는 엑기스 물건이에용^^~~<br />실사 사진이고요, 직접 눈으로 보심 뿅~~~~~~~~~갑니다.<br />거기다 신규 첫입주라는 뽀~~~~너스<br />보증금 300만원으로도 가능하답니다<br />얼릉 ☎주세용 (친절 확실한 상담)',
#    'description_og': '말이 필요없는 엑기스 물건이에용^^~~\n실사 사진이고요, 직접 눈으로 보심 뿅~~~~~~~~~갑니다.\n거기다 신규 첫입주라는 뽀~~~~너스\n보증금 300만원으로도 가능하답니다\n얼릉 ☎주세용 (친절 확실한 상담)',
#    'elevator': '있음',
#    'floor': '고층/15층',
#    'floor_all': '15층',
#    'id': 3620208,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3620208/c70f5a7156022ba113f83c89e6156fef35c0185d.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3620208/559e3e941df951a4c8fe23ac1ec2ae57f0678cde.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3620208/ed3aa253240c45d827c648b28162b0f8788c2f56.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3620208/e45cf8350b67762034db99bc25d1f938dc25230a.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3620208/cc0b1a65ffec5f7253471d7c85bc6919fcc3fff1.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3620208/eb732aa4dec0fb1f5173a61fdcd288a341264450.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3620208/7caff847bb7c0f111ff97b4212472b736a0174c4.jpg'},
#     {'count': 8,
#      'index': 7,
#      'url': 'http://z1.zigbang.com/items/3620208/2bcbd576cfa62aed3caa7438ab2f1f5c39c543a8.jpg'},
#     {'count': 9,
#      'index': 8,
#      'url': 'http://z1.zigbang.com/items/3620208/f43b44a11f3bad6c002a24658c6b9e4c144f7c4f.jpg'},
#     {'count': 10,
#      'index': 9,
#      'url': 'http://z1.zigbang.com/items/3620208/42aa313e92efb608674ebaaba469be486844618c.jpg'},
#     {'count': 11,
#      'index': 10,
#      'url': 'http://z1.zigbang.com/items/3620208/eb732aa4dec0fb1f5173a61fdcd288a341264450.jpg'},
#     {'count': 12,
#      'index': 11,
#      'url': 'http://z1.zigbang.com/items/3620208/142a2112d447e33de1dad57a606cdec5014f5a2d.jpg'},
#     {'count': 13,
#      'index': 12,
#      'url': 'http://z1.zigbang.com/items/3620208/3fbce2880a8db8cdbea03189a6df9e37859ec702.jpg'},
#     {'count': 14,
#      'index': 13,
#      'url': 'http://z1.zigbang.com/items/3620208/235c3feced8581149ad1761801398381c6587c9b.jpg'},
#     {'count': 15,
#      'index': 14,
#      'url': 'http://z1.zigbang.com/items/3620208/2dbd444e9c7b21cfc42569d711517bed49764fc5.jpg'},
#     {'count': 16,
#      'index': 15,
#      'url': 'http://z1.zigbang.com/items/3620208/90a1841297bf01ec0c16d5d30fc3df0d1dc83d17.jpg'},
#     {'count': 17,
#      'index': 16,
#      'url': 'http://z1.zigbang.com/items/3620208/464172b9cee8d4152511dd1d7fc33aa8c94e2727.jpg'},
#     {'count': 18,
#      'index': 17,
#      'url': 'http://z1.zigbang.com/items/3620208/8c664bb9c133860e711d9576742e45425cd7e596.jpg'},
#     {'count': 19,
#      'index': 18,
#      'url': 'http://z1.zigbang.com/items/3620208/548aa5dc6948440fc9a23dfd9cc4584e05455b14.jpg'},
#     {'count': 20,
#      'index': 19,
#      'url': 'http://z1.zigbang.com/items/3620208/4753f93b765d7a69302082c3b8fa2ffd655d1e14.jpg'}],
#    'images_count': 20,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3620208/c70f5a7156022ba113f83c89e6156fef35c0185d.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '남구',
#    'local3': '주안동',
#    'manage_cost': '3.3만원',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시입주',
#    'near_subways': '간석역(1호선), 주안역(1호선), 인천시청역(인천1호선)',
#    'options': '에어컨, 냉장고, 세탁기, 인덕션, 전자레인지, 책상, 책장, 침대, 옷장, 신발장, 싱크대',
#    'original_user_phone': '010-9018-6432',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#    'random_location': '37.4629446928786,126.690507907912',
#    'rent': 52,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '02',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 8,
#    'size_contract': 14,
#    'size_m2': '26.45',
#    'size_m2_contract': '46.28',
#    'status': '광고중',
#    'title': '★★★이보다 좋쿠~싼집있음 복비 안받음~★★★',
#    'updated_at': '5일 전',
#    'user_email': 'jw9711@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-6779',
#    'user_name': '중개보조원(김진우)',
#    'user_no': 1068535,
#    'user_phone': '0507-1280-6779',
#    'view_count': 330},
#   'title': '인천시 남구 주안동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 남동구 구월동',
#    'address2': '1131-14',
#    'address3': None,
#    'agent_address1': '인천광역시 연수구 학나래로 96 (선학동)',
#    'agent_email': 'ahrami_@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '연수구',
#    'agent_mobile': '0507-1280-0380',
#    'agent_name': '조은공인중개사(장아람)',
#    'agent_phone': '032-812-1600',
#    'bjd_code': '2820010100',
#    'bonbun_code': '1131',
#    'bubun_code': '14',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '인천광역시',
#    'deposit': 100,
#    'description': '#예술회관역7분, 인천시청역8분거리 더블역세권에 위치한 오피스텔입니다.<br /><br />#실평수가 8평정도 나오는 아주 넓은집입니다/.<br /><br />#넓은방에 인테리어도 심플해서 내마음대로 집꾸미기 아주 좋아요~<br /><br />#옷장과 신발장이 각각 2개씩 설치돼있어서 수납하기 아주 편리합니다.<br /><br />#현재 구월동인근에 나와있는 같은금액대 매물중에 방이 가장 넓습니다.<br /><br />#요즘 새학기가 시작되면서 매물 찾기가 아주 힘든시기입니다~  남이 채가기전에 빨리 전화주세요!<br /><br />#가격을 낮춰 광고하는 저질스러운 영업은 하지 않습니다 ^ㅡ^',
#    'description_og': '#예술회관역7분, 인천시청역8분거리 더블역세권에 위치한 오피스텔입니다.\n\n#실평수가 8평정도 나오는 아주 넓은집입니다/.\n\n#넓은방에 인테리어도 심플해서 내마음대로 집꾸미기 아주 좋아요~\n\n#옷장과 신발장이 각각 2개씩 설치돼있어서 수납하기 아주 편리합니다.\n\n#현재 구월동인근에 나와있는 같은금액대 매물중에 방이 가장 넓습니다.\n\n#요즘 새학기가 시작되면서 매물 찾기가 아주 힘든시기입니다~  남이 채가기전에 빨리 전화주세요!\n\n#가격을 낮춰 광고하는 저질스러운 영업은 하지 않습니다 ^ㅡ^',
#    'elevator': '있음',
#    'floor': '7층',
#    'floor_all': '12층',
#    'id': 3666380,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3666380/81f24caaa439e4ff19b5ac28099ca490dba348dd.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3666380/e4ed1d4d905d48f8679b3d5f9bfe867f553e59e0.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3666380/bbcb899f8cb5624e20c36d4c0c470225d0bb35f3.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3666380/ded45e927779e86e88bf33e95ece38faff349989.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3666380/10c99bc274fb9edafd026b422e5628c3f27da7e5.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3666380/8476abea4f99a7049a34863dad9ef0545215dacf.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3666380/f75f6ce4957cfb22adaa9275276321073f23006d.jpg'},
#     {'count': 8,
#      'index': 7,
#      'url': 'http://z1.zigbang.com/items/3666380/1dc9b053e5813729362fd5427a24856781ff91c8.jpg'},
#     {'count': 9,
#      'index': 8,
#      'url': 'http://z1.zigbang.com/items/3666380/79d02f2785541f9e3dc2776c7bfaa76907bef7da.jpg'}],
#    'images_count': 9,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3666380/81f24caaa439e4ff19b5ac28099ca490dba348dd.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '남동구',
#    'local3': '구월동',
#    'manage_cost': '55000만원',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시입주가능합니다 ^^',
#    'near_subways': '예술회관역(인천1호선), 인천시청역(인천1호선), 인천터미널역(인천1호선)',
#    'options': '에어컨, 냉장고, 세탁기, 가스레인지, 옷장, 신발장, 싱크대',
#    'original_user_phone': '010-4943-8897',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/1089740/dff24410433c1419d0e2885f54aa6d5037380930.jpg',
#    'random_location': '37.453147945627,126.702427180824',
#    'rent': 40,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 8,
#    'size_contract': 0,
#    'size_m2': '26.45',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '예술회관역7분 가성비 최고넓은 오피스텔',
#    'updated_at': '어제',
#    'user_email': 'pjh12349@hanmail.net',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-0636',
#    'user_name': '중개보조원(박지하)',
#    'user_no': 1089740,
#    'user_phone': '0507-1280-0636',
#    'view_count': 96},
#   'title': '인천시 남동구 구월동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '서울시 양천구 신월5동',
#    'address2': '77-9',
#    'address3': None,
#    'agent_address1': '서울특별시 강서구 화곡동 1076-21',
#    'agent_email': 'chd9434@naver.com',
#    'agent_local1': '서울시',
#    'agent_local2': '강서구',
#    'agent_mobile': '0507-1280-0100',
#    'agent_name': '화곡공인중개사(최현달)',
#    'agent_phone': '02-2691-1313',
#    'bjd_code': '',
#    'bonbun_code': '77',
#    'bubun_code': '9',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '서울특별시',
#    'deposit': 16500,
#    'description': '☆물건내용☆<br /><br />★위치: 화곡역 6번출구 도보10분거리<br /><br />★보증금: 16500만원<br /><br />★준공년: 2015년<br /><br />★층수: 전체6층 중 6층 (승강기 있음)<br /><br />★크기 및 구조: 전용면적 17평, 방3 욕실1 거실별도에 세탁기가 들어가는 다용도실2개<br /><br />★입주가능일: 현재 거주인이 있어서 이사일은 협의합니다.<br /><br />★상세내용: <br />2015년 준공 신축수준 쓰리룸 전세 입니다. 최근년 준공이기도 하지만 현 거주인이 내부를 곱게 사용하셔서 청소만하고 바로 입주해도 될 정도 입니다. 6층인데다가 거실 창문 밖이 탁 트인 점이 인상적인 집 입니다.(승강기 있습니다.) 화장실이 넓은 것도 장점입니다. 화곡역 도보10분거리로 도보이용에 부담없고, 인근에 버스전용차선으로 다니는 버스정거장이 있어서 대중교통 이용에 불편함은 없습니다.',
#    'description_og': '☆물건내용☆\n\n★위치: 화곡역 6번출구 도보10분거리\n\n★보증금: 16500만원\n\n★준공년: 2015년\n\n★층수: 전체6층 중 6층 (승강기 있음)\n\n★크기 및 구조: 전용면적 17평, 방3 욕실1 거실별도에 세탁기가 들어가는 다용도실2개\n\n★입주가능일: 현재 거주인이 있어서 이사일은 협의합니다.\n\n★상세내용: \n2015년 준공 신축수준 쓰리룸 전세 입니다. 최근년 준공이기도 하지만 현 거주인이 내부를 곱게 사용하셔서 청소만하고 바로 입주해도 될 정도 입니다. 6층인데다가 거실 창문 밖이 탁 트인 점이 인상적인 집 입니다.(승강기 있습니다.) 화장실이 넓은 것도 장점입니다. 화곡역 도보10분거리로 도보이용에 부담없고, 인근에 버스전용차선으로 다니는 버스정거장이 있어서 대중교통 이용에 불편함은 없습니다.',
#    'elevator': '있음',
#    'floor': '6층',
#    'floor_all': '6층',
#    'id': 3638164,
#    'images': [{'count': 1,
#      'index': 0,
# ...
#      'url': 'http://z1.zigbang.com/items/3659400/e091fc87338319216c5bd3011a4e0268fcd93cc8.jpg'}],
#    'images_count': 10,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3659400/6c0c5026f377693f256e0d19a456ff483d54d76c.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '경기도',
#    'local2': '부천시 원미구',
#    'local3': '소사동',
#    'manage_cost': '없음',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시 가능',
#    'near_subways': '소사역(1호선), 부천역(1호선)',
#    'options': '에어컨, 냉장고, 세탁기, 신발장, 싱크대',
#    'original_user_phone': '010-2515-4106',
#    'parking': '불가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/193963/b8b2a386b3e9eaa0083f13d941934ca171fa842b.jpg',
#    'random_location': '37.4866569684131,126.794150822601',
#    'rent': 25,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 6,
#    'size_contract': 0,
#    'size_m2': '19.83',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '❤ 깔끔(관리비X) ❤ 카대7분 ❤',
#    'updated_at': '어제',
#    'user_email': 'iuserd@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-4450',
#    'user_name': '대표공인중개사(김상국)',
#    'user_no': 193963,
#    'user_phone': '0507-1280-4450',
#    'view_count': 377},
#   'title': '경기도 부천시 원미구 소사동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '경기도 부천시 원미구 중동',
#    'address2': '1160-1',
#    'address3': None,
#    'agent_address1': '경기도 부천시 원미구 중동 1160-1번지 대우마이빌센트럴파크 108호',
#    'agent_email': 'imyun5113@hanmail.net',
#    'agent_local1': '경기도',
#    'agent_local2': '부천시 원미구',
#    'agent_mobile': '0507-1281-2727',
#    'agent_name': '대우공인중개사(임은희)',
#    'agent_phone': '032-325-8899',
#    'bjd_code': '4119510800',
#    'bonbun_code': '1160',
#    'bubun_code': '1',
#    'building': {'address': '경기도 부천시 원미구 중동 1160-1',
#     'address2': '1160-1',
#     'building_id': 1716,
#     'count': 12,
#     'elevator': '1',
#     'established': '2004.06',
#     'floor': '15층',
#     'lat': 37.50227737426758,
#     'lng': 126.76339721679688,
#     'local1': '경기도',
#     'local2': '부천시 원미구',
#     'local3': '중동',
#     'name': '대우마이빌센트럴파크',
#     'rooms': '260세대'},
#    'building_type': '오피스텔·도생',
#    'contract': '경기도',
#    'deposit': 1000,
#    'description': '전철7호선 부천시청역 3분거리<br />현대백화점,이마트<br />순천향대학병원<br />모두 도보 5분이내로 이용 가능<br /><br />복층형 구조로 수납시설이 아주 많고<br />화장실 샤워부스 넓고 좋아요',
#    'description_og': '전철7호선 부천시청역 3분거리\n현대백화점,이마트\n순천향대학병원\n모두 도보 5분이내로 이용 가능\n\n복층형 구조로 수납시설이 아주 많고\n화장실 샤워부스 넓고 좋아요',
#    'elevator': '있음',
#    'floor': '고층/15층',
#    'floor_all': '15층',
#    'id': 3595821,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3595821/8fd1f8d57c86413be13565ded2793377e683ba2e.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3595821/1840ded1bff3a7ae89cf58e629fd424c6fa950ca.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3595821/c114507e914b1c5b73b236d7712b43e4345f52b4.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3595821/eeede069a9e804a4b063cf289d7c8155c074508d.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3595821/1a1c34abf79e933d6cfb056b6382e34159817d23.jpg'}],
#    'images_count': 5,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3595821/8fd1f8d57c86413be13565ded2793377e683ba2e.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '경기도',
#    'local2': '부천시 원미구',
#    'local3': '중동',
#    'manage_cost': '5만원',
#    'manage_cost_inc': '전기세, 수도',
#    'movein_date': '2월 말',
#    'near_subways': '부천시청역(7호선), 상동역(7호선), 신중동역(7호선)',
#    'options': '냉장고, 세탁기, 가스레인지, 옷장, 싱크대',
#    'original_user_phone': '010-3337-1009',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#    'random_location': '37.5025303847175,126.76371366407',
#    'rent': 45,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '02',
#    'room_type': '원룸(복층형)',
#    'secret_memo': None,
#    'size': 8,
#    'size_contract': 8,
#    'size_m2': '26.45',
#    'size_m2_contract': '26.45',
#    'status': '광고중',
#    'title': '대우16평 복층',
#    'updated_at': '7일 전',
#    'user_email': 'imyun5113@hanmail.net',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1281-2727',
#    'user_name': '대표공인중개사(임은희)',
#    'user_no': 287916,
#    'user_phone': '0507-1281-2727',
#    'view_count': 213},
#   'title': '경기도 부천시 원미구 중동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 남구 주안동',
#    'address2': '115-6',
#    'address3': None,
#    'agent_address1': '인천광역시 남동구 간석동 179-2 1층 OK 부동산',
#    'agent_email': 'bbb53780@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '남동구',
#    'agent_mobile': '0507-1280-2914',
#    'agent_name': 'OK공인중개사(윤소연)',
#    'agent_phone': '032-429-9898',
#    'bjd_code': '2817010600',
#    'bonbun_code': '115',
#    'bubun_code': '6',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '인천광역시',
#    'deposit': 30,
#    'description': '전기요금만 따로 내시고 나머지 공과금은 <br />모두 포함되어 있는 경제적인 원룸입니다^^<br />1층에 주차장이 있는 건물로 1층 및 세대별로<br />도어락이 있고 입구 및 층별로 CCTV가 설치되어 있어요<br />저렴하지만 채광도 좋고 깨끗해서 인기있는 원룸입니다<br />벽걸이TV가 옵션으로 되어 있어서 빨래 널기에도<br />충분한 여유공간이 나와요^^<br /><br /><br />★원하시는 가격.날짜.위치 등을 말씀해주시면 100%맞춤중개<br />   항상 내가족이 구하는 집이라고 생각하며 성심.성의껏 중개하겠습니다',
#    'description_og': '전기요금만 따로 내시고 나머지 공과금은 \n모두 포함되어 있는 경제적인 원룸입니다^^\n1층에 주차장이 있는 건물로 1층 및 세대별로\n도어락이 있고 입구 및 층별로 CCTV가 설치되어 있어요\n저렴하지만 채광도 좋고 깨끗해서 인기있는 원룸입니다\n벽걸이TV가 옵션으로 되어 있어서 빨래 널기에도\n충분한 여유공간이 나와요^^\n\n\n★원하시는 가격.날짜.위치 등을 말씀해주시면 100%맞춤중개\n   항상 내가족이 구하는 집이라고 생각하며 성심.성의껏 중개하겠습니다',
#    'elevator': '없음',
#    'floor': '3층',
#    'floor_all': '5층',
#    'id': 3380987,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3380987/d14cac9e7081e622229c96984bb7b45bd6980d62.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3380987/aeed5df22595d9ad2fc79c4b6dc7a16c92ca84c1.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3380987/50d689c04dbd74eb5fc64b5985669e8f216e574b.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3380987/b281909cfb9ef480328f51baf528eed88eb12c01.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3380987/05a1021efe4a52dd9992cee34b45ad11b82317fa.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3380987/f029ad89b7baa6e4725b6f88e2f73e46bb5fdc07.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3380987/eb92fc662438399c0f02645da0b233b90d83ea03.jpg'}],
#    'images_count': 7,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3380987/d14cac9e7081e622229c96984bb7b45bd6980d62.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '남구',
#    'local3': '주안동',
#    'manage_cost': '5만원',
#    'manage_cost_inc': '가스, 수도, 인터넷, TV',
#    'movein_date': '즉시',
#    'near_subways': '주안역(1호선), 간석역(1호선), 도화역(1호선)',
#    'options': '싱크대, 에어컨, 인덕션, 냉장고, 옷장, 세탁기, 신발장',
#    'original_user_phone': '010-5038-8644',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/178182.jpg',
#    'random_location': '37.4634039695672,126.685019268812',
#    'rent': 25,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 5,
#    'size_contract': 0,
#    'size_m2': '16.53',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '▶▶▶말도안되는 가격!!찾는 분들 많아용◀◀◀',
#    'updated_at': '어제',
#    'user_email': 'bbb53780@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-2914',
#    'user_name': '대표공인중개사(윤소연)',
#    'user_no': 178182,
#    'user_phone': '0507-1280-2914',
#    'view_count': 1429},
#   'title': '인천시 남구 주안동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 남동구 구월동',
#    'address2': '1299-16',
#    'address3': None,
#    'agent_address1': '인천광역시 남동구 구월말로 18 1층 2호(구월동)',
#    'agent_email': 'kimnayun365@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '남동구',
#    'agent_mobile': '0507-1280-8825',
#    'agent_name': '선두공인중개사(김나윤)',
#    'agent_phone': '032-465-7200',
#    'bjd_code': '2820010100',
#    'bonbun_code': '1299',
#    'bubun_code': '16',
#    'building': None,
#    'building_type': '다세대건물',
#    'contract': '인천광역시',
#    'deposit': 10000,
#    'description': '큰방1 작은방1 베란다1 부엌겸 거실 구조입니다.<br />해가 잘 들어 따듯하고 깨끗해요.<br />엘리베이터가 있어 편리하고 주차가 가능한 필로티구조의 빌라입니다.<br />',
#    'description_og': '큰방1 작은방1 베란다1 부엌겸 거실 구조입니다.\n해가 잘 들어 따듯하고 깨끗해요.\n엘리베이터가 있어 편리하고 주차가 가능한 필로티구조의 빌라입니다.\n',
#    'elevator': '있음',
#    'floor': '4층',
#    'floor_all': '5층',
#    'id': 3435731,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3435731/dbe71fd5aa5634152828337b6e6c6e316b080371.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3435731/8a1e1d48dad79c7664c8dcbfe65d185871baf2f5.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3435731/ba9c22b8c8de9d9b6a916f87c2c6c57130b30d3c.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3435731/e90104be691ac507c92fe7ce50cd45a4429dc1c8.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3435731/970131fd8a4c3a5049940aa7de8c2872dadf149b.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3435731/203d773157900cf253aedce0659701e33f55eac9.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3435731/0ab376cf86f10c2d4612d28873f9e4066c14bbda.jpg'},
#     {'count': 8,
#      'index': 7,
#      'url': 'http://z1.zigbang.com/items/3435731/d0794e1207b624f32265b5f62bfe38dede0e1a32.jpg'},
#     {'count': 9,
#      'index': 8,
#      'url': 'http://z1.zigbang.com/items/3435731/d8d7977b79eb3c584c50ab565692dad7696b6543.jpg'}],
#    'images_count': 9,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3435731/dbe71fd5aa5634152828337b6e6c6e316b080371.jpg',
#    'is_deposit_only': True,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '남동구',
#    'local3': '구월동',
#    'manage_cost': '3만원',
#    'manage_cost_inc': '-',
#    'movein_date': '즉시입주가능',
#    'near_subways': '-',
#    'options': '가스레인지, 싱크대',
#    'original_user_phone': '010-6689-9981',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/998884/261b3f65f0a10d132641332f3c7dbebaf1c69980.jpg',
#    'random_location': '37.4511913454373,126.722266385653',
#    'rent': 0,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '01',
#    'room_type': '투룸',
#    'secret_memo': None,
#    'size': 11,
#    'size_contract': 0,
#    'size_m2': '36.36',
#    'size_m2_contract': '-',
#    'status': '광고중',
#    'title': '전세) 방2개 예쁜빌라 인근에서 가장 깨끗하고 주차도 잘 되는 집이에요',
#    'updated_at': '21일 전',
#    'user_email': 'kimnayun365@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-8825',
#    'user_name': '대표공인중개사(김나윤)',
#    'user_no': 998884,
#    'user_phone': '0507-1280-8825',
#    'view_count': 2322},
#   'title': '인천시 남동구 구월동'},
#  {'header': False,
#   'header_height': 0,
#   'item': {'address1': '인천시 부평구 부평동',
#    'address2': '161-12',
#    'address3': None,
#    'agent_address1': '인천광역시 부평구 부평동 536-2 현대더로프트 144호 ',
#    'agent_email': 'leader-rea@naver.com',
#    'agent_local1': '인천시',
#    'agent_local2': '부평구',
#    'agent_mobile': '0507-1280-3958',
#    'agent_name': '리더공인중개사(정두환)',
#    'agent_phone': '032-502-4444',
#    'bjd_code': '2823710100',
#    'bonbun_code': '161',
#    'bubun_code': '12',
#    'building': {'address': '인천시 부평구 부평동 161-12',
#     'address2': '161-12',
#     'building_id': 1418,
#     'count': 21,
#     'elevator': '1',
#     'established': '2013.01',
#     'floor': '14층',
#     'lat': 37.4895477294922,
#     'lng': 126.729904174805,
#     'local1': '인천시',
#     'local2': '부평구',
#     'local3': '부평동',
#     'name': '현대렉스힐',
#     'rooms': '79세대'},
#    'building_type': '오피스텔·도생',
#    'contract': '인천광역시',
#    'deposit': 60,
#    'description': '★ 부평역인근 대로변 건물입니다!!<br /><br />★ 막힌곳 없이 시원한 뷰"<br /><br />★ 정남향!!<br /><br />★ 관리인 상주<br /><br />★ 한번 입주하시면 이사를 안하시네요^^ 빠르게 진행되는 집이오니, 서둘러 주세요~<br /><br />★ 카톡ID : smart032<br /><br />★ 문자, 유선상담 : 부평원룸전문 정두환 소장 ( 010 - 4085 - 8249 ) ',
#    'description_og': '★ 부평역인근 대로변 건물입니다!!\n\n★ 막힌곳 없이 시원한 뷰"\n\n★ 정남향!!\n\n★ 관리인 상주\n\n★ 한번 입주하시면 이사를 안하시네요^^ 빠르게 진행되는 집이오니, 서둘러 주세요~\n\n★ 카톡ID : smart032\n\n★ 문자, 유선상담 : 부평원룸전문 정두환 소장 ( 010 - 4085 - 8249 ) ',
#    'elevator': '있음',
#    'floor': '중층/14층',
#    'floor_all': '14층',
#    'id': 3586029,
#    'images': [{'count': 1,
#      'index': 0,
#      'url': 'http://z1.zigbang.com/items/3586029/9fd764500e26d30ab1f6cd52b07db1e3daa0aabb.jpg'},
#     {'count': 2,
#      'index': 1,
#      'url': 'http://z1.zigbang.com/items/3586029/765857cccb66085e95a8958d8fcf47e2e128b9ef.jpg'},
#     {'count': 3,
#      'index': 2,
#      'url': 'http://z1.zigbang.com/items/3586029/7b7bd9994858852d7947ee7d3157e640241a80d6.jpg'},
#     {'count': 4,
#      'index': 3,
#      'url': 'http://z1.zigbang.com/items/3586029/d60fef4bc302f5fb19f5022eff55e1cc57de19bf.jpg'},
#     {'count': 5,
#      'index': 4,
#      'url': 'http://z1.zigbang.com/items/3586029/71bbf14456acb6462ac4e49c28fd1d23dadd6dc9.jpg'},
#     {'count': 6,
#      'index': 5,
#      'url': 'http://z1.zigbang.com/items/3586029/1b7d3891fbb887486f9d0b726a7f7ee9b5d6a8b1.jpg'},
#     {'count': 7,
#      'index': 6,
#      'url': 'http://z1.zigbang.com/items/3586029/3b16f07e9156e3a1c42e2c11034a0ff677f9e6f6.jpg'}],
#    'images_count': 7,
#    'images_thumbnail': 'http://z1.zigbang.com/items/3586029/9fd764500e26d30ab1f6cd52b07db1e3daa0aabb.jpg',
#    'is_deposit_only': False,
#    'is_direct': False,
#    'is_owner': None,
#    'is_premium': True,
#    'is_premium2': True,
#    'is_realestate': True,
#    'is_room': False,
#    'is_status_close': False,
#    'is_status_open': True,
#    'is_type_room': False,
#    'is_zzim': False,
#    'loan_text': '확인필요',
#    'local1': '인천시',
#    'local2': '부평구',
#    'local3': '부평동',
#    'manage_cost': '5만원',
#    'manage_cost_inc': '인터넷, TV',
#    'movein_date': '즉시입주가능',
#    'near_subways': '부평역(1호선,인천1호선), 부개역(1호선), 동수역(인천1호선)',
#    'options': '에어컨, 냉장고, 세탁기, 가스레인지, 옷장, 신발장, 싱크대',
#    'original_user_phone': '010-4085-8249',
#    'parking': '가능',
#    'pets_text': '확인필요',
#    'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#    'random_location': '37.4892962601067,126.730230239553',
#    'rent': 52,
#    'room_direction_text': '확인필요',
#    'room_gubun_code': '02',
#    'room_type': '원룸(오픈형)',
#    'secret_memo': None,
#    'size': 7,
#    'size_contract': 12,
#    'size_m2': '23.14',
#    'size_m2_contract': '39.67',
#    'status': '광고중',
#    'title': '★신축!! 막힌곳 없이 시원한집★',
#    'updated_at': '7일 전',
#    'user_email': 'leader-rea@naver.com',
#    'user_has_no_penalty': True,
#    'user_has_penalty': False,
#    'user_mobile': '0507-1280-3958',
#    'user_name': '대표공인중개사(정두환)',
#    'user_no': 865247,
#    'user_phone': '0507-1280-3958',
#    'view_count': 448},
#   'title': '인천시 부평구 부평동'}]

# %%
for item in items_list:
    print(item.keys())
# items는 다시 4개의 keys들로 구성됨
# Out:
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])
# dict_keys(['item', 'header', 'header_height', 'title'])

# %%
for item in items_list:
    item_dict = item.get('item')
    phonenumber = item_dict.get('agent_mobile')
    print(phonenumber)
    # zigbang_dict.keys안의 items안의 item에있는 agent_mobile을 뽑음
# Out:
# 0507-1280-7070
# 0507-1280-1140
# 0507-1280-5215
# 0507-1280-1140
# 0507-1280-0888
# 0507-1280-8811
# 0507-1280-8049
# 0507-1280-2147
# 0507-1280-6524
# 0507-1280-3687
# 0507-1281-4021
# 0507-1280-0380
# 0507-1280-0100
# 0507-1280-4191
# 0507-1280-2397
# 0507-1280-7268
# 0507-1280-0623
# 0507-1280-5217
# 0507-1280-2931
# 0507-1280-7011
# 0507-1280-0503
# 0507-1280-2143
# 0507-1280-5217
# 0507-1280-7023
# 0507-1280-1382
# 0507-1280-0623
# 0507-1280-4471
# 0507-1280-3319
# 0507-1280-0885
# 0507-1280-7535
# 0507-1280-4194
# 0507-1280-2913
# 0507-1280-4703
# 0507-1280-8303
# 0507-1280-1375
# 0507-1280-2425
# 0507-1280-5725
# 0507-1280-0879
# 0507-1280-4205
# 0507-1280-5744
# 0507-1280-5733
# 0507-1280-7285
# 0507-1280-1144
# 0507-1281-0448
# 0507-1280-4955
# 0507-1280-8289
# 0507-1280-7538
# 0507-1280-8801
# 0507-1281-0448
# 0507-1280-6524
# 0507-1280-2404
# 0507-1280-7020
# 0507-1280-1398
# 0507-1280-1133
# 0507-1280-4450
# 0507-1281-2727
# 0507-1280-2914
# 0507-1280-8825
# 0507-1280-3958

# %%
item_dict
# Out:
# {'address1': '인천시 부평구 부평동',
#  'address2': '161-12',
#  'address3': None,
#  'agent_address1': '인천광역시 부평구 부평동 536-2 현대더로프트 144호 ',
#  'agent_email': 'leader-rea@naver.com',
#  'agent_local1': '인천시',
#  'agent_local2': '부평구',
#  'agent_mobile': '0507-1280-3958',
#  'agent_name': '리더공인중개사(정두환)',
#  'agent_phone': '032-502-4444',
#  'bjd_code': '2823710100',
#  'bonbun_code': '161',
#  'bubun_code': '12',
#  'building': {'address': '인천시 부평구 부평동 161-12',
#   'address2': '161-12',
#   'building_id': 1418,
#   'count': 21,
#   'elevator': '1',
#   'established': '2013.01',
#   'floor': '14층',
#   'lat': 37.4895477294922,
#   'lng': 126.729904174805,
#   'local1': '인천시',
#   'local2': '부평구',
#   'local3': '부평동',
#   'name': '현대렉스힐',
#   'rooms': '79세대'},
#  'building_type': '오피스텔·도생',
#  'contract': '인천광역시',
#  'deposit': 60,
#  'description': '★ 부평역인근 대로변 건물입니다!!<br /><br />★ 막힌곳 없이 시원한 뷰"<br /><br />★ 정남향!!<br /><br />★ 관리인 상주<br /><br />★ 한번 입주하시면 이사를 안하시네요^^ 빠르게 진행되는 집이오니, 서둘러 주세요~<br /><br />★ 카톡ID : smart032<br /><br />★ 문자, 유선상담 : 부평원룸전문 정두환 소장 ( 010 - 4085 - 8249 ) ',
#  'description_og': '★ 부평역인근 대로변 건물입니다!!\n\n★ 막힌곳 없이 시원한 뷰"\n\n★ 정남향!!\n\n★ 관리인 상주\n\n★ 한번 입주하시면 이사를 안하시네요^^ 빠르게 진행되는 집이오니, 서둘러 주세요~\n\n★ 카톡ID : smart032\n\n★ 문자, 유선상담 : 부평원룸전문 정두환 소장 ( 010 - 4085 - 8249 ) ',
#  'elevator': '있음',
#  'floor': '중층/14층',
#  'floor_all': '14층',
#  'id': 3586029,
#  'images': [{'count': 1,
#    'index': 0,
#    'url': 'http://z1.zigbang.com/items/3586029/9fd764500e26d30ab1f6cd52b07db1e3daa0aabb.jpg'},
#   {'count': 2,
#    'index': 1,
#    'url': 'http://z1.zigbang.com/items/3586029/765857cccb66085e95a8958d8fcf47e2e128b9ef.jpg'},
#   {'count': 3,
#    'index': 2,
#    'url': 'http://z1.zigbang.com/items/3586029/7b7bd9994858852d7947ee7d3157e640241a80d6.jpg'},
#   {'count': 4,
#    'index': 3,
#    'url': 'http://z1.zigbang.com/items/3586029/d60fef4bc302f5fb19f5022eff55e1cc57de19bf.jpg'},
#   {'count': 5,
#    'index': 4,
#    'url': 'http://z1.zigbang.com/items/3586029/71bbf14456acb6462ac4e49c28fd1d23dadd6dc9.jpg'},
#   {'count': 6,
#    'index': 5,
#    'url': 'http://z1.zigbang.com/items/3586029/1b7d3891fbb887486f9d0b726a7f7ee9b5d6a8b1.jpg'},
#   {'count': 7,
#    'index': 6,
#    'url': 'http://z1.zigbang.com/items/3586029/3b16f07e9156e3a1c42e2c11034a0ff677f9e6f6.jpg'}],
#  'images_count': 7,
#  'images_thumbnail': 'http://z1.zigbang.com/items/3586029/9fd764500e26d30ab1f6cd52b07db1e3daa0aabb.jpg',
#  'is_deposit_only': False,
#  'is_direct': False,
#  'is_owner': None,
#  'is_premium': True,
#  'is_premium2': True,
#  'is_realestate': True,
#  'is_room': False,
#  'is_status_close': False,
#  'is_status_open': True,
#  'is_type_room': False,
#  'is_zzim': False,
#  'loan_text': '확인필요',
#  'local1': '인천시',
#  'local2': '부평구',
#  'local3': '부평동',
#  'manage_cost': '5만원',
#  'manage_cost_inc': '인터넷, TV',
#  'movein_date': '즉시입주가능',
#  'near_subways': '부평역(1호선,인천1호선), 부개역(1호선), 동수역(인천1호선)',
#  'options': '에어컨, 냉장고, 세탁기, 가스레인지, 옷장, 신발장, 싱크대',
#  'original_user_phone': '010-4085-8249',
#  'parking': '가능',
#  'pets_text': '확인필요',
#  'profile_url': 'http://api.zigbang.com/ic/profile/608478/21957e47747dc8ab11965f85fa24bcb710f8f2ce.jpg',
#  'random_location': '37.4892962601067,126.730230239553',
#  'rent': 52,
#  'room_direction_text': '확인필요',
#  'room_gubun_code': '02',
#  'room_type': '원룸(오픈형)',
#  'secret_memo': None,
#  'size': 7,
#  'size_contract': 12,
#  'size_m2': '23.14',
#  'size_m2_contract': '39.67',
#  'status': '광고중',
#  'title': '★신축!! 막힌곳 없이 시원한집★',
#  'updated_at': '7일 전',
#  'user_email': 'leader-rea@naver.com',
#  'user_has_no_penalty': True,
#  'user_has_penalty': False,
#  'user_mobile': '0507-1280-3958',
#  'user_name': '대표공인중개사(정두환)',
#  'user_no': 865247,
#  'user_phone': '0507-1280-3958',
#  'view_count': 448}

# %%
item_dict.keys()
# Out:
# dict_keys(['images', 'original_user_phone', 'size_m2', 'profile_url', 'view_count', 'is_status_close', 'is_premium', 'agent_email', 'near_subways', 'user_no', 'is_zzim', 'deposit', 'room_type', 'building', 'is_realestate', 'user_phone', 'user_has_penalty', 'user_has_no_penalty', 'random_location', 'user_mobile', 'agent_mobile', 'user_name', 'agent_local2', 'agent_local1', 'images_thumbnail', 'is_owner', 'bubun_code', 'room_direction_text', 'parking', 'address1', 'bjd_code', 'status', 'size', 'floor_all', 'updated_at', 'local2', 'bonbun_code', 'local1', 'id', 'address2', 'description', 'contract', 'is_type_room', 'address3', 'building_type', 'is_status_open', 'agent_address1', 'is_direct', 'images_count', 'description_og', 'agent_phone', 'elevator', 'room_gubun_code', 'pets_text', 'manage_cost', 'loan_text', 'movein_date', 'local3', 'size_contract', 'title', 'user_email', 'options', 'size_m2_contract', 'is_premium2', 'is_room', 'manage_cost_inc', 'is_deposit_only', 'rent', 'floor', 'agent_name', 'secret_memo'])

# %%
import pandas as pd
df = pd.DataFrame(columns=[list(item_dict.keys())])
df
# Out:
# Empty DataFrame
# Columns: [images, original_user_phone, size_m2, profile_url, view_count, is_status_close, is_premium, agent_email, near_subways, user_no, is_zzim, deposit, room_type, building, is_realestate, user_phone, user_has_penalty, user_has_no_penalty, random_location, user_mobile, agent_mobile, user_name, agent_local2, agent_local1, images_thumbnail, is_owner, bubun_code, room_direction_text, parking, address1, bjd_code, status, size, floor_all, updated_at, local2, bonbun_code, local1, id, address2, description, contract, is_type_room, address3, building_type, is_status_open, agent_address1, is_direct, images_count, description_og, agent_phone, elevator, room_gubun_code, pets_text, manage_cost, loan_text, movein_date, local3, size_contract, title, user_email, options, size_m2_contract, is_premium2, is_room, manage_cost_inc, is_deposit_only, rent, floor, agent_name, secret_memo]
# Index: []
#
# [0 rows x 71 columns]

# %%
pd.DataFrame(item_dict)
# 이방법 말고
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a976fa280862> in <module>()
# ----> 1 pd.DataFrame(item_dict)
#       2 # 이방법 말고
#
# /home/ubuntu/.pyenv/versions/3.5.1/envs/play/lib/python3.5/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     224                                  dtype=dtype, copy=copy)
#     225         elif isinstance(data, dict):
# --> 226             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     227         elif isinstance(data, ma.MaskedArray):
#     228             import numpy.ma.mrecords as mrecords
#
# /home/ubuntu/.pyenv/versions/3.5.1/envs/play/lib/python3.5/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     361
#     362         return _arrays_to_mgr(arrays, data_names, index, columns,
# --> 363                               dtype=dtype)
#     364
#     365     def _init_ndarray(self, values, index, columns, dtype=None,
#
# /home/ubuntu/.pyenv/versions/3.5.1/envs/play/lib/python3.5/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5156     # figure out the index, if necessary
#    5157     if index is None:
# -> 5158         index = extract_index(arrays)
#    5159     else:
#    5160         index = _ensure_index(index)
#
# /home/ubuntu/.pyenv/versions/3.5.1/envs/play/lib/python3.5/site-packages/pandas/core/frame.py in extract_index(data)
#    5207
#    5208             if have_dicts:
# -> 5209                 raise ValueError('Mixing dicts with non-Series may lead to '
#    5210                                  'ambiguous ordering.')
#    5211
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
# 오류뜨기 때문에 item_dict.keys()를 list로 바꿈
for item in items_list:
    item_dict = item.get('item')
    keys = list(item_dict.keys())
    for key in keys:
        value = getattr(item_dict, key)
    phonenumber = item_dict.get('agent_mobile')
    
item_dict.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-37d68106549e> in <module>()
#       4     keys = list(item_dict.keys())
#       5     for key in keys:
# ----> 6         value = getattr(item_dict, key)
#       7     phonenumber = item_dict.get('agent_mobile')
#       8
#
# AttributeError: 'dict' object has no attribute 'images'
