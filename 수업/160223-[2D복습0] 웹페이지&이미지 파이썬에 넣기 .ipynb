# %% [markdown]
# ## 웹페이지 & 이미지 넣기
# * IPyhon.display.IFrame
# * IPyhon.display.Image

# %%
from IPython.display import IFrame

# %%
IFrame("http://fastcampus.co.kr/", '800', '400')
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="http://fastcampus.co.kr/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import Image
Image("http://pds9.egloos.com/pds/200804/19/74/b0033774_4809697f40f58.jpg")
