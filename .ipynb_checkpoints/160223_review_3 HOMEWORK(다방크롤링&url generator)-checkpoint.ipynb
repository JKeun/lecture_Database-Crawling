# %% [markdown]
# # hw. 다방 크롤링하기

# %%
import requests
import json
import pandas as pd

# %%
response = requests.get("http://www.dabangapp.com/api/2/room/list/search?page=1&filters=%7B%22deposit-range%22%3A%5B0%2C999999%5D%2C%22price-range%22%3A%5B0%2C999999%5D%2C%22room-type%22%3A%5B0%2C1%2C2%2C3%2C4%2C5%5D%2C%22deal-type%22%3A%5B0%2C1%5D%2C%22location%22%3A%5B%5B126.65657267485665%2C37.505146062104686%5D%2C%5B126.90719828520821%2C37.560414154305995%5D%5D%7D&_=1456933164419")
dabang_dict = json.loads(response.text)
dabang_dict
# Out:
# {'ad-banner': None,
#  'features': [{'agent': {'_id': '5450a4d2e4b022a314f574da',
#     'active-room-count': 39,
#     'address': '서울특별시 강서구 화곡1동 346-1',
#     'completed-room-count': 82,
#     'count-title': '거래중인방: 39개 | 거래완료방: 82개',
#     'description': '화곡역 전문 공인중개사',
#     'email': 'minandgun@nate.com',
#     'facename': '김선화',
#     'id': '5450a4d2e4b022a314f574da',
#     'name': '월드공인중개사사무소',
#     'profile-url': 'https://dabang-prod-profile-image.s3.amazonaws.com/de26f080b9c857048217459c189479f3',
#     's': 0.0681771831586957,
#     'sub_emails': None,
#     'tel': '010-5185-3411'},
#    'rooms': [{'_id': '56d40facd9cb7f1c7d08ff85',
#      'actived_time': '2016-02-29T09:30:20.993Z',
#      'address': '서울특별시 강서구 화곡동',
#      'agent_id': '5450a4d2e4b022a314f574da',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 13000,
#      'favorite_count': 1,
#      'floor': '2층',
#      'hash_tags': ['#전세가능', '#주차'],
#      'heating': None,
#      'id': '56d40facd9cb7f1c7d08ff85',
#      'is_pano': False,
#      'location': [126.85073478352669, 37.5388819484434],
#      'maintenance_cost': None,
#      'maintenance_items_str': [],
#      'name': '김선화',
#      'options': [],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': 'd2654337-e0c6-45da-8d84-368dd0f405bc'},
#       {'desc': '', 'key': '00b598c2-4869-449c-9f09-6e8161e4a8c3'},
#       {'desc': '', 'key': '4d38b585-99cf-4b95-aca2-0b020360d504'},
#       {'desc': '', 'key': '7f48a0e9-2379-4fce-ab34-880802722321'},
#       {'desc': '', 'key': '9a71f911-a80b-4afb-800f-5b4f5a7c825b'},
#       {'desc': '', 'key': '5af07a7c-0a55-448f-be3b-a6a1e52221d0'},
#       {'desc': '', 'key': '705ac82f-29dd-4aea-98ed-9b5da0574583'},
#       {'desc': '', 'key': '0bea0c7b-66a6-4a2c-a3f4-3313270a3188'}],
#      'photos': ['d2654337-e0c6-45da-8d84-368dd0f405bc',
#       '00b598c2-4869-449c-9f09-6e8161e4a8c3',
#       '4d38b585-99cf-4b95-aca2-0b020360d504',
#       '7f48a0e9-2379-4fce-ab34-880802722321',
#       '9a71f911-a80b-4afb-800f-5b4f5a7c825b',
#       '5af07a7c-0a55-448f-be3b-a6a1e52221d0',
#       '705ac82f-29dd-4aea-98ed-9b5da0574583',
#       '0bea0c7b-66a6-4a2c-a3f4-3313270a3188'],
#      'price': 0,
#      'price-title': '1억3000',
#      'price_info': [[13000, 0]],
#      'price_title': '1억3000',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 27,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 56.1,
#      'room-title': '쓰리룸 전세',
#      'room_desc': '쓰리룸 | 2층 | 56.1m²',
#      'room_floor': 2,
#      'room_options': [],
#      'room_size': 56.1,
#      'room_title': '쓰리룸 전세',
#      'room_type': 2,
#      'room_type_str': '쓰리룸',
#      'saved-time': '2016-02-29T09:30:20.993Z',
#      'saved_time': '2016-02-29T09:30:20.993Z',
#      'selling_type': 1,
#      'seq': 780939,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개', '전세가능'],
#      'title': '깔끔한 3룸 전세입니다.',
#      'user_id': 'minandgun@nate.com',
#      'view_count': 121},
#     {'_id': '56d3dc9c2fddf83b34fa7053',
#      'actived_time': '2016-02-29T05:52:28.190Z',
#      'address': '서울특별시 강서구 화곡동',
#      'agent_id': '5450a4d2e4b022a314f574da',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 2500,
#      'favorite_count': 0,
#      'floor': '3층',
#      'hash_tags': [],
#      'heating': None,
#      'id': '56d3dc9c2fddf83b34fa7053',
#      'is_pano': False,
#      'location': [126.84189976574638, 37.532642740167965],
#      'maintenance_cost': None,
#      'maintenance_items_str': [],
#      'name': '김선화',
#      'options': ['신발장', '냉장고', '세탁기', '에어컨'],
#      'pano': None,
#      'parking': False,
#      'photo': [{'desc': '', 'key': '8e638fde-e16d-421e-9f18-c4790fbc0053'},
#       {'desc': '', 'key': '8df2153b-7c40-4a04-b6f0-b509712e7d78'},
#       {'desc': '', 'key': '9ea98a80-ed95-43f2-94b6-10a50a43b40d'},
#       {'desc': '', 'key': '763f2e64-2733-4ae2-878b-ddc261eeca75'},
#       {'desc': '', 'key': 'f270aad3-a218-44ad-b022-d7bd26270359'},
#       {'desc': '', 'key': '7cc53744-3663-4b06-8d55-951d0301371a'},
#       {'desc': '', 'key': 'db632a23-2904-4496-b325-884cc5d02956'}],
#      'photos': ['8e638fde-e16d-421e-9f18-c4790fbc0053',
#       '8df2153b-7c40-4a04-b6f0-b509712e7d78',
#       '9ea98a80-ed95-43f2-94b6-10a50a43b40d',
#       '763f2e64-2733-4ae2-878b-ddc261eeca75',
#       'f270aad3-a218-44ad-b022-d7bd26270359',
#       '7cc53744-3663-4b06-8d55-951d0301371a',
#       'db632a23-2904-4496-b325-884cc5d02956'],
#      'price': 43,
#      'price-title': '2500/43',
#      'price_info': [[2500, 43], [1000, 50]],
#      'price_title': '2500/43',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 27,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 42.9,
#      'room-title': '1.5룸 월세',
#      'room_desc': '1.5룸 | 3층 | 42.9m²',
#      'room_floor': 3,
#      'room_options': [6, 7, 1, 0],
#      'room_size': 42.9,
#      'room_title': '1.5룸 월세',
#      'room_type': 5,
#      'room_type_str': '1.5룸',
#      'saved-time': '2016-02-29T05:52:28.190Z',
#      'saved_time': '2016-02-29T05:52:28.190Z',
#      'selling_type': 0,
#      'seq': 779987,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개'],
#      'title': '넓은 1.5룸 입니다.',
#      'user_id': 'minandgun@nate.com',
#      'view_count': 42}],
#    'show-banner': False},
#   {'agent': {'_id': '56332d5bfd43805b39f9e370',
#     'active-room-count': 17,
#     'address': '서울특별시 영등포구 문래동5가 23-4 명지페르마타 209호',
#     'completed-room-count': 0,
#     'count-title': '거래중인방: 17개 | 거래완료방: 0개',
#     'description': None,
#     'email': 'niceman04@naver.com',
#     'facename': '조인선',
#     'id': '56332d5bfd43805b39f9e370',
#     'name': '명지부동산공인중개사사무소',
#     'profile-url': 'https://dabang-prod-profile-image.s3.amazonaws.com/30a1ad7ba7a14f97da118d5692b1f903',
#     's': 0.08364512771368027,
#     'sub_emails': None,
#     'tel': '02-2675-6565'},
#    'rooms': [{'_id': '56cd87313356b521ad792e78',
#      'actived_time': '2016-02-25T07:32:57.291Z',
#      'address': '서울특별시 영등포구 문래동',
#      'agent_id': '56332d5bfd43805b39f9e370',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 3000,
#      'favorite_count': 0,
#      'floor': '2층',
#      'hash_tags': ['#주차'],
#      'heating': None,
#      'id': '56cd87313356b521ad792e78',
#      'is_pano': False,
#      'location': [126.88378507389777, 37.51720496625499],
#      'maintenance_cost': 7.0,
#      'maintenance_items_str': [],
#      'name': '조인선',
#      'options': ['에어컨', '세탁기', '옷장', '신발장', '가스레인지', '전자도어락'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': '5350f158-9b6a-4928-8c5f-8730764ce3eb'},
#       {'desc': '', 'key': 'edccc6a4-ecdf-4c69-87bc-25c34ca0d9b4'},
#       {'desc': '', 'key': 'e6c9ad79-020b-4651-bbe1-efbf390573fe'},
#       {'desc': '', 'key': 'b171b590-3dae-4831-8d19-2e3c10f72949'},
#       {'desc': '', 'key': '27107e01-866d-43c6-b9bd-f6247ecb7acf'},
#       {'desc': '', 'key': '6e00b42f-2d76-4aca-bf16-7564c3e44670'},
#       {'desc': '', 'key': '06a39a8e-2668-4c41-97cb-82b170d0842d'},
#       {'desc': '', 'key': '4cd05d55-1688-470d-825e-6b3fc48b8c5a'},
#       {'desc': '', 'key': 'ccc055de-ce7c-4495-b347-81bbbc26dbfc'},
#       {'desc': '', 'key': '33ebf4c3-22dd-4bb8-8f0a-c2e96c970f0e'},
#       {'desc': '', 'key': '375a0561-9a94-4ac9-ac06-f45809ef4ef7'},
#       {'desc': '', 'key': '56dcd2b4-02cf-4c68-a895-ffda69996152'}],
#      'photos': ['5350f158-9b6a-4928-8c5f-8730764ce3eb',
#       'edccc6a4-ecdf-4c69-87bc-25c34ca0d9b4',
#       'e6c9ad79-020b-4651-bbe1-efbf390573fe',
#       'b171b590-3dae-4831-8d19-2e3c10f72949',
#       '27107e01-866d-43c6-b9bd-f6247ecb7acf',
#       '6e00b42f-2d76-4aca-bf16-7564c3e44670',
#       '06a39a8e-2668-4c41-97cb-82b170d0842d',
#       '4cd05d55-1688-470d-825e-6b3fc48b8c5a',
#       'ccc055de-ce7c-4495-b347-81bbbc26dbfc',
#       '33ebf4c3-22dd-4bb8-8f0a-c2e96c970f0e',
#       '375a0561-9a94-4ac9-ac06-f45809ef4ef7',
#       '56dcd2b4-02cf-4c68-a895-ffda69996152'],
#      'price': 35,
#      'price-title': '3000/35',
#      'price_info': [[3000, 35]],
#      'price_title': '3000/35',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 23,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 25.7,
#      'room-title': '오피스텔 월세',
#      'room_desc': '오피스텔 | 2층 | 25.7m² | 관리비 7만원',
#      'room_floor': 2,
#      'room_options': [0, 1, 4, 6, 8, 11],
#      'room_size': 25.7,
#      'room_title': '오피스텔 월세',
#      'room_type': 3,
#      'room_type_str': '오피스텔',
#      'saved-time': '2016-02-24T10:34:25.312Z',
#      'saved_time': '2016-02-24T10:34:25.312Z',
#      'selling_type': 0,
#      'seq': 770279,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개'],
#      'title': '전입가능 융자무 입주빨리가능 상태깨끗하고 좋아요',
#      'user_id': 'niceman04@naver.com',
#      'view_count': 48},
#     {'_id': '56cd880ab7245521765e0ff1',
#      'actived_time': '2016-02-25T07:32:26.998Z',
#      'address': '서울특별시 영등포구 문래동',
#      'agent_id': '56332d5bfd43805b39f9e370',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 4000,
#      'favorite_count': 0,
#      'floor': '2층',
#      'hash_tags': ['#주차'],
#      'heating': None,
#      'id': '56cd880ab7245521765e0ff1',
#      'is_pano': False,
#      'location': [126.88378507389777, 37.51720496625499],
#      'maintenance_cost': 7.0,
#      'maintenance_items_str': [],
#      'name': '조인선',
#      'options': ['에어컨', '세탁기', '옷장', '신발장', '가스레인지', '전자도어락'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': 'ef94f840-5988-49a8-8eae-a02c8281ac4b'},
#       {'desc': '', 'key': '9a100d8b-852f-440a-b7fb-779d35d76380'},
#       {'desc': '', 'key': '32109413-1dea-43a9-947f-6e371e605cfe'},
#       {'desc': '', 'key': '71fe3cc4-20d4-4dab-8ed5-6ed1cd879e0f'},
#       {'desc': '', 'key': '1da09148-c11a-4876-a6f7-f84b706eb9d3'},
#       {'desc': '', 'key': 'c83ccf21-c5da-4b63-8995-7e52be245d77'},
#       {'desc': '', 'key': 'b148ebf7-3b94-4281-b5c1-d5f84cfb77bb'},
#       {'desc': '', 'key': '7b5fc49e-0371-473f-b568-ec76fa702e24'},
#       {'desc': '', 'key': '5a83937e-7408-4a45-b2f1-b5f3096dac24'},
#       {'desc': '', 'key': '5449635b-7634-4750-824a-46778b843e17'}],
#      'photos': ['ef94f840-5988-49a8-8eae-a02c8281ac4b',
#       '9a100d8b-852f-440a-b7fb-779d35d76380',
#       '32109413-1dea-43a9-947f-6e371e605cfe',
#       '71fe3cc4-20d4-4dab-8ed5-6ed1cd879e0f',
#       '1da09148-c11a-4876-a6f7-f84b706eb9d3',
#       'c83ccf21-c5da-4b63-8995-7e52be245d77',
#       'b148ebf7-3b94-4281-b5c1-d5f84cfb77bb',
#       '7b5fc49e-0371-473f-b568-ec76fa702e24',
#       '5a83937e-7408-4a45-b2f1-b5f3096dac24',
#       '5449635b-7634-4750-824a-46778b843e17'],
#      'price': 30,
#      'price-title': '4000/30',
#      'price_info': [[4000, 30]],
#      'price_title': '4000/30',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 23,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 25.7,
#      'room-title': '오피스텔 월세',
#      'room_desc': '오피스텔 | 2층 | 25.7m² | 관리비 7만원',
#      'room_floor': 2,
#      'room_options': [0, 1, 4, 6, 8, 11],
#      'room_size': 25.7,
#      'room_title': '오피스텔 월세',
#      'room_type': 3,
#      'room_type_str': '오피스텔',
#      'saved-time': '2016-02-24T10:38:02.783Z',
#      'saved_time': '2016-02-24T10:38:02.783Z',
#      'selling_type': 0,
#      'seq': 770289,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개'],
#      'title': '깔끔한오피스텔 귀한반전세 융자무 전입가능 입주빨리가능 상태좋아요',
#      'user_id': 'niceman04@naver.com',
#      'view_count': 80}],
#    'show-banner': False},
#   {'agent': {'_id': '536dd4dae4b0c359a9463aba',
#     'active-room-count': 20,
#     'address': '서울특별시 양천구 오목로 24길 7, 101호(신정동, 이호빌)',
#     'completed-room-count': 110,
#     'count-title': '거래중인방: 20개 | 거래완료방: 110개',
#     'description': '바른부동산',
#     'email': 'endeldia@nate.com',
#     'facename': '김현수',
#     'id': '536dd4dae4b0c359a9463aba',
#     'name': '바른부동산공인중개사무소',
#     'profile-url': 'https://dabang-prod-profile-image.s3.amazonaws.com/71e049067b2b72e7eb32620fece50110',
#     's': 0.15509954746812582,
#     'sub_emails': ['chltjsal002@hanmail.net'],
#     'tel': '010-8926-8355'},
#    'rooms': [{'_id': '56a7626578fc416edace6824',
#      'actived_time': '2016-03-02T09:33:55.069Z',
#      'address': '서울특별시 양천구 목동',
#      'agent_id': '536dd4dae4b0c359a9463aba',
#      'animal': True,
#      'building_floor_str': '',
#      'deposit': 17000,
#      'favorite_count': 0,
#      'floor': '4층',
#      'hash_tags': ['#전세가능', '#주차', '#반려동물'],
#      'heating': None,
#      'id': '56a7626578fc416edace6824',
#      'is_pano': False,
#      'location': [126.87335720718711, 37.54582804903426],
#      'maintenance_cost': None,
#      'maintenance_items_str': [],
#      'name': '최선미',
#      'options': ['전자도어락', '세탁기', '에어컨', '신발장', '냉장고', '가스레인지'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': 'a2a608bd-fcee-475b-a377-23420e71f9a8'},
#       {'desc': '', 'key': 'fdb087ae-1c16-40ea-8af6-53d037bcec6e'},
#       {'desc': '', 'key': 'e57bf020-efdc-4803-af5c-3b2b8516bfa7'},
#       {'desc': '', 'key': 'b1b39fae-06ca-4364-95c8-f7f58cf7c310'},
#       {'desc': '', 'key': '061db55a-588b-4ebd-8c7b-4617a9605d3d'},
#       {'desc': '', 'key': 'b8afe2a1-9dcf-49f0-9aa1-6d5b3692dbf3'},
#       {'desc': '', 'key': '0f458ec2-dc6d-4824-a6c4-145762fb5dbc'},
#       {'desc': '', 'key': 'a2bc377d-1458-457d-bc68-417b155799e9'},
#       {'desc': '', 'key': 'ddb2d5ad-246b-4be9-9229-19e8655335ac'}],
#      'photos': ['a2a608bd-fcee-475b-a377-23420e71f9a8',
#       'fdb087ae-1c16-40ea-8af6-53d037bcec6e',
#       'e57bf020-efdc-4803-af5c-3b2b8516bfa7',
#       'b1b39fae-06ca-4364-95c8-f7f58cf7c310',
#       '061db55a-588b-4ebd-8c7b-4617a9605d3d',
#       'b8afe2a1-9dcf-49f0-9aa1-6d5b3692dbf3',
#       '0f458ec2-dc6d-4824-a6c4-145762fb5dbc',
#       'a2bc377d-1458-457d-bc68-417b155799e9',
#       'ddb2d5ad-246b-4be9-9229-19e8655335ac'],
#      'price': 0,
#      'price-title': '1억7000',
#      'price_info': [[17000, 0]],
#      'price_title': '1억7000',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 29,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 29.7,
#      'room-title': '원룸 전세',
#      'room_desc': '원룸 | 4층 | 29.7m²',
#      'room_floor': 4,
#      'room_options': [11, 1, 0, 6, 7, 8],
#      'room_size': 29.7,
#      'room_title': '원룸 전세',
#      'room_type': 0,
#      'room_type_str': '원룸',
#      'saved-time': '2016-01-26T12:11:17.876Z',
#      'saved_time': '2016-01-26T12:11:17.876Z',
#      'selling_type': 1,
#      'seq': 700298,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개', '전세가능'],
#      'title': '◀◀추천,9호선 염창역급행선,테라스 있는 신축빌라형원룸,첫입주●',
#      'user_id': 'chltjsal002@hanmail.net',
#      'view_count': 93},
#     {'_id': '569cb83c37a9800257e816f9',
#      'actived_time': '2016-03-02T09:32:01.268Z',
#      'address': '서울특별시 강서구 화곡동',
#      'agent_id': '536dd4dae4b0c359a9463aba',
#      'animal': True,
#      'building_floor_str': '',
#      'deposit': 15500,
#      'favorite_count': 1,
#      'floor': '2층',
#      'hash_tags': ['#전세가능', '#주차', '#반려동물'],
#      'heating': None,
#      'id': '569cb83c37a9800257e816f9',
#      'is_pano': False,
#      'location': [126.8558040714748, 37.53170187129939],
#      'maintenance_cost': None,
#      'maintenance_items_str': [],
#      'name': '최선미',
#      'options': ['전자도어락', '신발장', '가스레인지'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': 'fe84b2ff-19f6-43f3-bf99-24f1cb4998fc'},
#       {'desc': '', 'key': '52af470c-60ec-4f5f-9c1e-66fa33f83fb5'},
#       {'desc': '', 'key': 'b4475f98-d551-4eaf-bdd8-ce52aebe57d4'},
#       {'desc': '', 'key': 'a9d8039c-12b5-476f-b691-c31a32d0b60b'},
#       {'desc': '', 'key': '16d76d33-9523-44cb-8448-f25dc75ea0fa'},
#       {'desc': '', 'key': '04f0704c-33b4-46d4-8921-89c855ee8dd7'},
#       {'desc': '', 'key': '78bafc1f-4c5a-44e5-bbd0-47bf4c479ef3'},
#       {'desc': '', 'key': 'ff976148-0f86-433a-af2b-360de043aa63'},
#       {'desc': '', 'key': '376a41f9-127e-4217-a5f8-b0b8c7f61111'}],
#      'photos': ['fe84b2ff-19f6-43f3-bf99-24f1cb4998fc',
#       '52af470c-60ec-4f5f-9c1e-66fa33f83fb5',
#       'b4475f98-d551-4eaf-bdd8-ce52aebe57d4',
#       'a9d8039c-12b5-476f-b691-c31a32d0b60b',
#       '16d76d33-9523-44cb-8448-f25dc75ea0fa',
#       '04f0704c-33b4-46d4-8921-89c855ee8dd7',
#       '78bafc1f-4c5a-44e5-bbd0-47bf4c479ef3',
#       'ff976148-0f86-433a-af2b-360de043aa63',
#       '376a41f9-127e-4217-a5f8-b0b8c7f61111'],
#      'price': 0,
#      'price-title': '1억5500',
#      'price_info': [[15500, 0]],
#      'price_title': '1억5500',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 29,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 46.2,
#      'room-title': '투룸 전세',
#      'room_desc': '투룸 | 2층 | 46.2m²',
#      'room_floor': 2,
#      'room_options': [11, 6, 8],
#      'room_size': 46.2,
#      'room_title': '투룸 전세',
#      'room_type': 1,
#      'room_type_str': '투룸',
#      'saved-time': '2016-01-18T10:02:36.408Z',
#      'saved_time': '2016-01-18T10:02:36.408Z',
#      'selling_type': 1,
#      'seq': 677566,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개', '전세가능'],
#      'title': '◀◀추천,인테리어 예쁜집. 가격,구조,추천,첫입주●',
#      'user_id': 'chltjsal002@hanmail.net',
#      'view_count': 175}],
#    'show-banner': False},
#   {'agent': {'_id': '55c81c5265ffe360031d2fd8',
#     'active-room-count': 15,
#     'address': '인천광역시 서구 검암로29번길 6-6, 101(검암동)',
#     'completed-room-count': 86,
#     'count-title': '거래중인방: 15개 | 거래완료방: 86개',
#     'description': None,
#     'email': 'sk5670004@naver.com',
#     'facename': '장동주',
#     'id': '55c81c5265ffe360031d2fd8',
#     'name': '서경공인중개사사무소',
#     'profile-url': 'https://dabang-prod-profile-image.s3.amazonaws.com/142585fb0960957905b24032cc40d7b7',
#     's': 0.18840497452765703,
#     'sub_emails': ['chaoshjw@daum.net', 'jayun1120_1@naver.com'],
#     'tel': '032-567-0004'},
#    'rooms': [{'_id': '56d55fb99f5ab026c054266c',
#      'actived_time': '2016-03-01T09:24:09.303Z',
#      'address': '인천광역시 서구 검암동',
#      'agent_id': '55c81c5265ffe360031d2fd8',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 20000,
#      'favorite_count': 0,
#      'floor': '5층',
#      'hash_tags': ['#전세가능', '#주차'],
#      'heating': None,
#      'id': '56d55fb99f5ab026c054266c',
#      'is_pano': False,
#      'location': [126.67625170118927, 37.558703974208115],
#      'maintenance_cost': 3.0,
#      'maintenance_items_str': [],
#      'name': '박자연',
#      'options': ['가스레인지', '신발장', '인덕션'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': '4b6b8767-be68-4499-9bfd-700d74f0d098'},
#       {'desc': '', 'key': '5fbb14f5-5038-4ad7-9029-f0fd4110fdec'},
#       {'desc': '', 'key': '49c5513f-aef1-4658-b191-828676df9e61'},
#       {'desc': '', 'key': '8bf845ce-b2be-477f-9311-e6d941195b80'},
#       {'desc': '', 'key': 'd6ff4747-d0ac-407d-a0cc-6c016865c5ca'},
#       {'desc': '', 'key': '151884a1-2715-4d12-b00a-a1d77897a4eb'},
#       {'desc': '', 'key': 'b9ee38c9-f089-48ff-aa54-82d77bb29d58'},
#       {'desc': '', 'key': 'e575dfdc-8783-45aa-bf52-ec8c65777b67'},
#       {'desc': '', 'key': '96c571ab-8cf0-43d5-bb77-f287f78f5e01'},
#       {'desc': '', 'key': 'e68edfba-3829-45e6-903b-632b9d2ca4b0'}],
#      'photos': ['4b6b8767-be68-4499-9bfd-700d74f0d098',
#       '5fbb14f5-5038-4ad7-9029-f0fd4110fdec',
#       '49c5513f-aef1-4658-b191-828676df9e61',
#       '8bf845ce-b2be-477f-9311-e6d941195b80',
#       'd6ff4747-d0ac-407d-a0cc-6c016865c5ca',
#       '151884a1-2715-4d12-b00a-a1d77897a4eb',
#       'b9ee38c9-f089-48ff-aa54-82d77bb29d58',
#       'e575dfdc-8783-45aa-bf52-ec8c65777b67',
#       '96c571ab-8cf0-43d5-bb77-f287f78f5e01',
#       'e68edfba-3829-45e6-903b-632b9d2ca4b0'],
#      'price': 0,
#      'price-title': '2억',
#      'price_info': [[20000, 0]],
#      'price_title': '2억',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 28,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 56.1,
#      'room-title': '쓰리룸 전세',
#      'room_desc': '쓰리룸 | 5층 | 56.1m² | 관리비 3만원',
#      'room_floor': 5,
#      'room_options': [8, 6, 9],
#      'room_size': 56.1,
#      'room_title': '쓰리룸 전세',
#      'room_type': 2,
#      'room_type_str': '쓰리룸',
#      'saved-time': '2016-03-01T09:24:09.303Z',
#      'saved_time': '2016-03-01T09:24:09.303Z',
#      'selling_type': 1,
#      'seq': 783332,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개', '전세가능'],
#      'title': '신축 복층빌라 첫 입주~  방4개, 욕실3개, 테라스',
#      'user_id': 'jayun1120_1@naver.com',
#      'view_count': 27},
#     {'_id': '56a186c28c23967b3d31a9a0',
#      'actived_time': '2016-03-01T09:18:47.298Z',
#      'address': '인천광역시 서구 검암동',
#      'agent_id': '55c81c5265ffe360031d2fd8',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 2000,
#      'favorite_count': 0,
#      'floor': '3층',
#      'hash_tags': ['#주차'],
#      'heating': None,
#      'id': '56a186c28c23967b3d31a9a0',
#      'is_pano': False,
#      'location': [126.67413876778764, 37.55530321753964],
#      'maintenance_cost': None,
#      'maintenance_items_str': [],
#      'name': '박자연',
#      'options': ['신발장', '가스레인지', '전자도어락'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': '7f6ab673-b385-4aa8-8b6b-c4852e0fa0d7'},
#       {'desc': '', 'key': 'f7b8f67d-5f1c-4cb8-b6e8-96722ee27676'},
#       {'desc': '', 'key': 'ccd7963f-196f-42da-8ef3-47f1ddc89aa9'},
#       {'desc': '', 'key': '50bbb7cf-5e9d-4774-b367-66784cf75cfe'},
#       {'desc': '', 'key': '61a1b35b-1f0c-44de-bc52-eab2a8add925'},
#       {'desc': '', 'key': 'bf5d7d56-9690-4b53-a32d-ef774fb350db'},
#       {'desc': '', 'key': '619c6d87-c638-4ee3-8d32-bf416ccd653e'},
#       {'desc': '', 'key': '74c807e0-4fce-46d7-b06a-2600fcf0ecd2'},
#       {'desc': '', 'key': '85d6e11e-59b8-4637-9e07-ee220c1cf33b'}],
#      'photos': ['7f6ab673-b385-4aa8-8b6b-c4852e0fa0d7',
#       'f7b8f67d-5f1c-4cb8-b6e8-96722ee27676',
#       'ccd7963f-196f-42da-8ef3-47f1ddc89aa9',
#       '50bbb7cf-5e9d-4774-b367-66784cf75cfe',
#       '61a1b35b-1f0c-44de-bc52-eab2a8add925',
#       'bf5d7d56-9690-4b53-a32d-ef774fb350db',
#       '619c6d87-c638-4ee3-8d32-bf416ccd653e',
#       '74c807e0-4fce-46d7-b06a-2600fcf0ecd2',
#       '85d6e11e-59b8-4637-9e07-ee220c1cf33b'],
#      'price': 45,
#      'price-title': '2000/45',
#      'price_info': [[2000, 45]],
#      'price_title': '2000/45',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 28,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 39.6,
#      'room-title': '투룸 월세',
#      'room_desc': '투룸 | 3층 | 39.6m²',
#      'room_floor': 3,
#      'room_options': [6, 8, 11],
#      'room_size': 39.6,
#      'room_title': '투룸 월세',
#      'room_type': 1,
#      'room_type_str': '투룸',
#      'saved-time': '2016-01-22T01:32:50.595Z',
#      'saved_time': '2016-01-22T01:32:50.595Z',
#      'selling_type': 0,
#      'seq': 688464,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개'],
#      'title': '정남향으로 거실있는 투룸, 주방,거실분리 되어있어요^^',
#      'user_id': 'jayun1120_1@naver.com',
#      'view_count': 144}],
#    'show-banner': False},
#   {'agent': {'_id': '566fae22208bcc1f93bde2c4',
#     'active-room-count': 20,
#     'address': '서울특별시 양천구 목동중앙북로16길15(목동)',
#     'completed-room-count': 2,
#     'count-title': '거래중인방: 20개 | 거래완료방: 2개',
#     'description': None,
#     'email': 'sk127777@naver.com',
#     'facename': '심경분',
#     'id': '566fae22208bcc1f93bde2c4',
#     'name': '양화진역공인중개사사무소',
#     'profile-url': 'https://dabang-prod-profile-image.s3.amazonaws.com/84d7e8ecdf7e836d10accdda8ef82848',
#     's': 0.008040385786443949,
#     'sub_emails': None,
#     'tel': '02-2649-2028'},
#    'rooms': [{'_id': '56d0469b937fa65ae1f7b5a9',
#      'actived_time': '2016-02-26T12:35:39.710Z',
#      'address': '서울특별시 양천구 목동',
#      'agent_id': '566fae22208bcc1f93bde2c4',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 21000,
#      'favorite_count': 0,
#      'floor': '3층',
#      'hash_tags': ['#전세가능', '#주차'],
#      'heating': None,
#      'id': '56d0469b937fa65ae1f7b5a9',
#      'is_pano': False,
#      'location': [126.873678747716, 37.54572748160788],
#      'maintenance_cost': 5.0,
#      'maintenance_items_str': [],
#      'name': '심경분',
#      'options': [],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': '1b8aedcb-6ffb-4e87-99b7-626139b0cbba'},
#       {'desc': '', 'key': '21455226-abfd-4e55-80bf-12f3dd597cdc'},
#       {'desc': '', 'key': 'e90a2ab8-759c-4664-bff6-0322007c6e5d'},
#       {'desc': '', 'key': 'bf5dc4d4-f24e-4851-9d14-63d70d6a2752'},
#       {'desc': '', 'key': '0f82dfd3-f45d-4ba3-b2ff-4d27e5c4ae69'},
#       {'desc': '', 'key': '7a58ee14-246f-4fdb-9253-683f813c8448'},
#       {'desc': '', 'key': '9ba51310-ebe3-42f3-8044-77e4ba76165d'}],
#      'photos': ['1b8aedcb-6ffb-4e87-99b7-626139b0cbba',
#       '21455226-abfd-4e55-80bf-12f3dd597cdc',
#       'e90a2ab8-759c-4664-bff6-0322007c6e5d',
#       'bf5dc4d4-f24e-4851-9d14-63d70d6a2752',
#       '0f82dfd3-f45d-4ba3-b2ff-4d27e5c4ae69',
#       '7a58ee14-246f-4fdb-9253-683f813c8448',
#       '9ba51310-ebe3-42f3-8044-77e4ba76165d'],
#      'price': 0,
#      'price-title': '2억1000',
#      'price_info': [[21000, 0]],
#      'price_title': '2억1000',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 24,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 46.2,
#      'room-title': '투룸 전세',
#      'room_desc': '투룸 | 3층 | 46.2m² | 관리비 5만원',
#      'room_floor': 3,
#      'room_options': [],
#      'room_size': 46.2,
#      'room_title': '투룸 전세',
#      'room_type': 1,
#      'room_type_str': '투룸',
#      'saved-time': '2016-02-26T12:35:39.710Z',
#      'saved_time': '2016-02-26T12:35:39.710Z',
#      'selling_type': 1,
#      'seq': 775779,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개', '전세가능'],
#      'title': '방2개 거실 신혼부부추천  공실',
#      'user_id': 'sk127777@naver.com',
#      'view_count': 34},
#     {'_id': '56d046992639155a73ad57be',
#      'actived_time': '2016-02-26T12:35:37.662Z',
#      'address': '서울특별시 양천구 목동',
#      'agent_id': '566fae22208bcc1f93bde2c4',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 21000,
#      'favorite_count': 0,
#      'floor': '3층',
#      'hash_tags': ['#전세가능', '#주차'],
#      'heating': None,
#      'id': '56d046992639155a73ad57be',
#      'is_pano': False,
#      'location': [126.873678747716, 37.54572748160788],
#      'maintenance_cost': 5.0,
#      'maintenance_items_str': [],
#      'name': '심경분',
#      'options': [],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': '1b8aedcb-6ffb-4e87-99b7-626139b0cbba'},
#       {'desc': '', 'key': '21455226-abfd-4e55-80bf-12f3dd597cdc'},
#       {'desc': '', 'key': 'e90a2ab8-759c-4664-bff6-0322007c6e5d'},
#       {'desc': '', 'key': 'bf5dc4d4-f24e-4851-9d14-63d70d6a2752'},
#       {'desc': '', 'key': '0f82dfd3-f45d-4ba3-b2ff-4d27e5c4ae69'},
#       {'desc': '', 'key': '7a58ee14-246f-4fdb-9253-683f813c8448'},
#       {'desc': '', 'key': '9ba51310-ebe3-42f3-8044-77e4ba76165d'}],
#      'photos': ['1b8aedcb-6ffb-4e87-99b7-626139b0cbba',
#       '21455226-abfd-4e55-80bf-12f3dd597cdc',
#       'e90a2ab8-759c-4664-bff6-0322007c6e5d',
#       'bf5dc4d4-f24e-4851-9d14-63d70d6a2752',
#       '0f82dfd3-f45d-4ba3-b2ff-4d27e5c4ae69',
#       '7a58ee14-246f-4fdb-9253-683f813c8448',
#       '9ba51310-ebe3-42f3-8044-77e4ba76165d'],
#      'price': 0,
#      'price-title': '2억1000',
#      'price_info': [[21000, 0]],
#      'price_title': '2억1000',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 24,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 46.2,
#      'room-title': '투룸 전세',
#      'room_desc': '투룸 | 3층 | 46.2m² | 관리비 5만원',
#      'room_floor': 3,
#      'room_options': [],
#      'room_size': 46.2,
#      'room_title': '투룸 전세',
#      'room_type': 1,
#      'room_type_str': '투룸',
#      'saved-time': '2016-02-26T12:35:37.662Z',
#      'saved_time': '2016-02-26T12:35:37.662Z',
#      'selling_type': 1,
#      'seq': 775778,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개', '전세가능'],
#      'title': '방2개 거실 신혼부부추천  공실',
#      'user_id': 'sk127777@naver.com',
#      'view_count': 13}],
#    'show-banner': False},
#   {'agent': {'_id': '550f99c6e4b01c409ee5e16f',
#     'active-room-count': 60,
#     'address': '서울특별시 영등포구 당산로48길 22(당산동6가)',
#     'completed-room-count': 266,
#     'count-title': '거래중인방: 60개 | 거래완료방: 266개',
#     'description': None,
#     'email': 'yunjun2002@naver.com',
#     'facename': '김윤준',
#     'id': '550f99c6e4b01c409ee5e16f',
#     'name': '정부동산공인중개사사무소',
#     'profile-url': 'https://dabang-prod-profile-image.s3.amazonaws.com/dbe208276f3471bb1fc0c6ee5a33c512',
#     's': 0.014818411786109209,
#     'sub_emails': ['lucete91@naver.com',
#      'anpyt@naver.com',
#      'tjsdyd8025@gmail.com',
#      'gkswlgns2302@gmail.com',
#      'yoonhyeri@ymail.com',
#      'grisdo2012@naver.com',
#      'hurry27@hanmail.net',
#      'youseuk@nate.com'],
#     'tel': '02-2677-2005'},
#    'rooms': [{'_id': '5689ddc54ffe5c691b549cf3',
#      'actived_time': '2016-03-01T09:25:18.860Z',
#      'address': '서울특별시 영등포구 당산동',
#      'agent_id': '550f99c6e4b01c409ee5e16f',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 4000,
#      'favorite_count': 1,
#      'floor': '4층',
#      'hash_tags': [],
#      'heating': None,
#      'id': '5689ddc54ffe5c691b549cf3',
#      'is_pano': False,
#      'location': [126.90044186357235, 37.536386288325986],
#      'maintenance_cost': 11.0,
#      'maintenance_items_str': [],
#      'name': '한지훈',
#      'options': ['세탁기', '에어컨', '책상', '옷장', '냉장고', '인덕션', '전자도어락', '전자레인지'],
#      'pano': None,
#      'parking': False,
#      'photo': [{'desc': '', 'key': '63cde653-8a5b-4521-ab0f-59027d3c5308'},
#       {'desc': '', 'key': 'a9d198bc-b27f-40b4-b128-d31c87fe0e13'},
#       {'desc': '', 'key': 'f221d781-4adf-4314-b488-e21dafb6216a'},
#       {'desc': '', 'key': '67416e27-e7fd-4844-a3c6-98352dc8a507'},
#       {'desc': '', 'key': 'e4fd40bc-f6a8-4097-8420-54de6b5ac2ba'}],
#      'photos': ['63cde653-8a5b-4521-ab0f-59027d3c5308',
#       'a9d198bc-b27f-40b4-b128-d31c87fe0e13',
#       'f221d781-4adf-4314-b488-e21dafb6216a',
#       '67416e27-e7fd-4844-a3c6-98352dc8a507',
#       'e4fd40bc-f6a8-4097-8420-54de6b5ac2ba'],
#      'price': 30,
#      'price-title': '4000/30',
#      'price_info': [[4000, 30]],
#      'price_title': '4000/30',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 28,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 19.8,
#      'room-title': '원룸 월세',
#      'room_desc': '원룸 | 4층 | 19.8m² | 관리비 11만원',
#      'room_floor': 4,
#      'room_options': [1, 0, 3, 4, 7, 9, 11, 10],
#      'room_size': 19.8,
#      'room_title': '원룸 월세',
#      'room_type': 0,
#      'room_type_str': '원룸',
#      'saved-time': '2016-01-04T02:49:41.460Z',
#      'saved_time': '2016-01-04T02:49:41.460Z',
#      'selling_type': 0,
#      'seq': 631390,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개'],
#      'title': '👑당산역걸어서1분👑',
#      'user_id': 'gkswlgns2302@gmail.com',
#      'view_count': 276},
#     {'_id': '568b572db7079b7bfcd4d72f',
#      'actived_time': '2016-03-01T09:21:32.871Z',
#      'address': '서울특별시 영등포구',
#      'agent_id': '550f99c6e4b01c409ee5e16f',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 1000,
#      'favorite_count': 4,
#      'floor': '4층',
#      'hash_tags': ['#주차'],
#      'heating': None,
#      'id': '568b572db7079b7bfcd4d72f',
#      'is_pano': False,
#      'location': [126.90048242791991, 37.5365124625444],
#      'maintenance_cost': 11.0,
#      'maintenance_items_str': [],
#      'name': '한지훈',
#      'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자도어락'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': '6ac4cde2-c04f-400e-b3c1-395961f8eb01'},
#       {'desc': '', 'key': 'c6410125-fb06-4657-b629-91826fcb7a6c'},
#       {'desc': '', 'key': '9e464885-72d8-4cd6-8071-912acf150ecf'},
#       {'desc': '', 'key': '4eecfffb-4a84-45d6-82aa-e54e8b96fcce'},
#       {'desc': '', 'key': '295ad213-843a-4bb4-8812-e33a83ef60dd'},
#       {'desc': '', 'key': '0ff6a7a0-d06a-4321-97f3-944eda4318ec'}],
#      'photos': ['6ac4cde2-c04f-400e-b3c1-395961f8eb01',
#       'c6410125-fb06-4657-b629-91826fcb7a6c',
#       '9e464885-72d8-4cd6-8071-912acf150ecf',
#       '4eecfffb-4a84-45d6-82aa-e54e8b96fcce',
#       '295ad213-843a-4bb4-8812-e33a83ef60dd',
#       '0ff6a7a0-d06a-4321-97f3-944eda4318ec'],
#      'price': 39,
#      'price-title': '1000/39',
#      'price_info': [[1000, 39], [2000, 30]],
#      'price_title': '1000/39',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 28,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 19.8,
#      'room-title': '원룸 월세',
#      'room_desc': '원룸 | 4층 | 19.8m² | 관리비 11만원',
#      'room_floor': 4,
#      'room_options': [0, 1, 3, 4, 6, 7, 9, 11],
#      'room_size': 19.8,
#      'room_title': '원룸 월세',
#      'room_type': 0,
#      'room_type_str': '원룸',
#      'saved-time': '2016-01-05T05:39:57.600Z',
#      'saved_time': '2016-01-05T05:39:57.600Z',
#      'selling_type': 0,
#      'seq': 636122,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개'],
#      'title': '🎱분리형원룸최저가🎱',
#      'user_id': 'gkswlgns2302@gmail.com',
#      'view_count': 213}],
#    'show-banner': False},
#   {'agent': {'_id': '54a62942e4b02ceec8160a4f',
#     'active-room-count': 20,
#     'address': '서울특별시 강서구 공항대로 509(등촌동, 우림보보카운티뷰제1층제104-2호)',
#     'completed-room-count': 5,
#     'count-title': '거래중인방: 20개 | 거래완료방: 5개',
#     'description': None,
#     'email': 'threestreets@naver.com',
#     'facename': '표태복',
#     'id': '54a62942e4b02ceec8160a4f',
#     'name': '삼거리공인중개사사무소',
#     'profile-url': 'https://dabang-prod-profile-image.s3.amazonaws.com/a15e6dff420e1bda0b84db380a1c1897',
#     's': 0.06674242438748479,
#     'sub_emails': None,
#     'tel': '02-3661-8888'},
#    'rooms': [{'_id': '55de592cb7349e7ba0286b6c',
#      'actived_time': '2016-02-29T07:08:43.644Z',
#      'address': '서울특별시 강서구 등촌동',
#      'agent_id': '54a62942e4b02ceec8160a4f',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 500,
#      'favorite_count': 9,
#      'floor': '9층',
#      'hash_tags': ['#주차'],
#      'heating': None,
#      'id': '55de592cb7349e7ba0286b6c',
#      'is_pano': False,
#      'location': [126.86323832703548, 37.552145372782725],
#      'maintenance_cost': 5.0,
#      'maintenance_items_str': [],
#      'name': '우민정',
#      'options': ['에어컨', '세탁기', '신발장', '냉장고', '가스레인지', '전자도어락'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': '77d8e908-cc98-4232-bff6-33dea12f5f9b'},
#       {'desc': '', 'key': 'c3ece373-de48-412b-aa20-a6393b040092'},
#       {'desc': '', 'key': '3a56db71-db7c-4381-ac27-ce1a1e255727'},
#       {'desc': '', 'key': '51b2290a-ca2c-47c2-aa90-f7edf7d35b84'},
#       {'desc': '', 'key': 'dc3b3b70-8d9b-487a-87a0-eec08d905f7d'},
#       {'desc': '', 'key': 'fddc2032-7683-469d-ab53-2a878a09b84b'}],
#      'photos': ['77d8e908-cc98-4232-bff6-33dea12f5f9b',
#       'c3ece373-de48-412b-aa20-a6393b040092',
#       '3a56db71-db7c-4381-ac27-ce1a1e255727',
#       '51b2290a-ca2c-47c2-aa90-f7edf7d35b84',
#       'dc3b3b70-8d9b-487a-87a0-eec08d905f7d',
#       'fddc2032-7683-469d-ab53-2a878a09b84b'],
#      'price': 55,
#      'price-title': '500/55',
#      'price_info': [[500, 55]],
#      'price_title': '500/55',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 27,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 26.4,
#      'room-title': '오피스텔 월세',
#      'room_desc': '오피스텔 | 9층 | 26.4m² | 관리비 5만원',
#      'room_floor': 9,
#      'room_options': [0, 1, 6, 7, 8, 11],
#      'room_size': 26.4,
#      'room_title': '오피스텔 월세',
#      'room_type': 3,
#      'room_type_str': '오피스텔',
#      'saved-time': '2015-08-27T00:26:20.674Z',
#      'saved_time': '2015-08-27T00:26:20.674Z',
#      'selling_type': 0,
#      'seq': 426670,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개'],
#      'title': '9호선 등촌역 우림오피스텔',
#      'user_id': 'threestreets@naver.com',
#      'view_count': 637},
#     {'_id': '55e3152c91e3067e66ef6df5',
#      'actived_time': '2016-02-29T07:05:41.877Z',
#      'address': '서울특별시 강서구 등촌동',
#      'agent_id': '54a62942e4b02ceec8160a4f',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 8500,
#      'favorite_count': 6,
#      'floor': '11층',
#      'hash_tags': ['#전세가능', '#주차'],
#      'heating': None,
#      'id': '55e3152c91e3067e66ef6df5',
#      'is_pano': False,
#      'location': [126.85367926666866, 37.55606226134857],
#      'maintenance_cost': 6.0,
#      'maintenance_items_str': [],
#      'name': '우민정',
#      'options': ['에어컨', '세탁기', '옷장', '가스레인지', '비데'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': 'dd44f931-16b8-47f5-86de-c89cc9676375'},
#       {'desc': '', 'key': '81ea68c4-3255-4b46-a478-cec1c9e7804e'},
#       {'desc': '', 'key': 'fa0c4541-2e37-4155-aab8-3600dc553804'},
#       {'desc': '', 'key': '17b07ec2-9e93-4b83-babe-856c97d9a3d2'},
#       {'desc': '', 'key': '2ace6d22-3dd4-4479-9dec-559bb76c7b6a'},
#       {'desc': '', 'key': '3b72357f-00d9-42a7-ae23-3759b012c3c7'},
#       {'desc': '', 'key': 'f88a70d2-0aa8-40fe-b05b-6da4ffbbdbdb'}],
#      'photos': ['dd44f931-16b8-47f5-86de-c89cc9676375',
#       '81ea68c4-3255-4b46-a478-cec1c9e7804e',
#       'fa0c4541-2e37-4155-aab8-3600dc553804',
#       '17b07ec2-9e93-4b83-babe-856c97d9a3d2',
#       '2ace6d22-3dd4-4479-9dec-559bb76c7b6a',
#       '3b72357f-00d9-42a7-ae23-3759b012c3c7',
#       'f88a70d2-0aa8-40fe-b05b-6da4ffbbdbdb'],
#      'price': 0,
#      'price-title': '8500',
#      'price_info': [[8500, 0]],
#      'price_title': '8500',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 27,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 19.8,
#      'room-title': '원룸 전세',
#      'room_desc': '원룸 | 11층 | 19.8m² | 관리비 6만원',
#      'room_floor': 11,
#      'room_options': [0, 1, 4, 8, 12],
#      'room_size': 19.8,
#      'room_title': '원룸 전세',
#      'room_type': 0,
#      'room_type_str': '원룸',
#      'saved-time': '2015-08-30T14:37:32.318Z',
#      'saved_time': '2015-08-30T14:37:32.318Z',
#      'selling_type': 1,
#      'seq': 432220,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개', '전세가능'],
#      'title': '강서구청사거리  메트로칸오피스텔',
#      'user_id': 'threestreets@naver.com',
#      'view_count': 572}],
#    'show-banner': False},
#   {'agent': {'_id': '54336e69e4b063e2099445c9',
#     'active-room-count': 20,
#     'address': '서울특별시 강서구 화곡동 1032-14',
#     'completed-room-count': 146,
#     'count-title': '거래중인방: 20개 | 거래완료방: 146개',
#     'description': '화곡역,까치산역 전문중개업소',
#     'email': 'ys7901@naver.com',
#     'facename': '양준섭',
#     'id': '54336e69e4b063e2099445c9',
#     'name': '시티공인중개사사무소',
#     'profile-url': 'https://dabang-prod-profile-image.s3.amazonaws.com/9a3a9fef1190d69596f1ef47302e362a',
#     's': 0.06675768410786986,
#     'sub_emails': None,
#     'tel': '02-2698-0070'},
#    'rooms': [{'_id': '56cea9a225b9a85955237e82',
#      'actived_time': '2016-03-02T03:52:12.273Z',
#      'address': '서울특별시 강서구 화곡동',
#      'agent_id': '54336e69e4b063e2099445c9',
#      'animal': False,
#      'building_floor_str': '',
#      'deposit': 8000,
#      'favorite_count': 0,
#      'floor': '2층',
#      'hash_tags': ['#전세가능'],
#      'heating': None,
#      'id': '56cea9a225b9a85955237e82',
#      'is_pano': False,
#      'location': [126.84340475267341, 37.54875821193034],
#      'maintenance_cost': None,
#      'maintenance_items_str': [],
#      'name': '양준섭',
#      'options': [],
#      'pano': None,
#      'parking': False,
#      'photo': [{'desc': '', 'key': '0205d4f4-3635-4435-8c1f-e924ed1778bb'},
#       {'desc': '', 'key': 'e1e2edce-23bd-4192-93fa-351b635c14cf'},
#       {'desc': '', 'key': 'f8b41a67-558a-4640-8ed3-61d2f6347572'},
#       {'desc': '', 'key': 'b46c8bd8-04e5-4673-9b6c-60f0c9e3d59f'},
#       {'desc': '', 'key': '2889c55b-7888-4914-954e-7e7fed1a561c'},
#       {'desc': '', 'key': '8719d12b-8300-4e8a-a48d-cbea2a7c8eac'},
#       {'desc': '', 'key': '8666558a-a8d0-4f19-a8e7-245d2bd1905c'},
#       {'desc': '', 'key': '6369568f-e350-46f9-9aa6-a9188433d4f0'}],
#      'photos': ['0205d4f4-3635-4435-8c1f-e924ed1778bb',
#       'e1e2edce-23bd-4192-93fa-351b635c14cf',
#       'f8b41a67-558a-4640-8ed3-61d2f6347572',
#       'b46c8bd8-04e5-4673-9b6c-60f0c9e3d59f',
#       '2889c55b-7888-4914-954e-7e7fed1a561c',
#       '8719d12b-8300-4e8a-a48d-cbea2a7c8eac',
#       '8666558a-a8d0-4f19-a8e7-245d2bd1905c',
#       '6369568f-e350-46f9-9aa6-a9188433d4f0'],
#      'price': 0,
#      'price-title': '8000',
#      'price_info': [[8000, 0]],
#      'price_title': '8000',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 29,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 46.2,
#      'room-title': '투룸 전세',
#      'room_desc': '투룸 | 2층 | 46.2m²',
#      'room_floor': 2,
#      'room_options': [],
#      'room_size': 46.2,
#      'room_title': '투룸 전세',
#      'room_type': 1,
#      'room_type_str': '투룸',
#      'saved-time': '2016-02-25T07:13:38.609Z',
#      'saved_time': '2016-02-25T07:13:38.609Z',
#      'selling_type': 1,
#      'seq': 771970,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개', '전세가능'],
#      'title': '화곡역.우장산역도보7분 / 2층  / 방2',
#      'user_id': 'ys7901@naver.com',
#      'view_count': 267},
#     {'_id': '5597a47d556f5c61c7f81bc9',
#      'actived_time': '2016-03-02T03:52:08.359Z',
#      'address': '서울특별시 강서구 화곡동',
#      'agent_id': '54336e69e4b063e2099445c9',
#      'animal': True,
#      'building_floor_str': '',
#      'deposit': 500,
#      'favorite_count': 15,
#      'floor': '2층',
#      'hash_tags': ['#주차', '#반려동물'],
#      'heating': None,
#      'id': '5597a47d556f5c61c7f81bc9',
#      'is_pano': False,
#      'location': [126.83706677202828, 37.54290756436373],
#      'maintenance_cost': 1.0,
#      'maintenance_items_str': [],
#      'name': '양준섭',
#      'options': ['에어컨', '세탁기', '옷장', '신발장', '냉장고', '가스레인지', '전자도어락'],
#      'pano': None,
#      'parking': True,
#      'photo': [{'desc': '', 'key': 'aa505ba4-46aa-4204-8d33-8d1d75ef42ee'},
#       {'desc': '', 'key': '688510f1-8f57-4a06-aeb0-04f13d51df0e'},
#       {'desc': '', 'key': '9dfab85d-42e5-4dfb-ad61-06d7781531d6'},
#       {'desc': '', 'key': '4f1785d4-02f4-423e-8f31-a690f9b95d0e'},
#       {'desc': '', 'key': 'fef4d064-116b-40be-a59e-4033d1328050'},
#       {'desc': '', 'key': '476cd9f1-17e5-40e1-abfa-e97e3280d347'}],
#      'photos': ['aa505ba4-46aa-4204-8d33-8d1d75ef42ee',
#       '688510f1-8f57-4a06-aeb0-04f13d51df0e',
#       '9dfab85d-42e5-4dfb-ad61-06d7781531d6',
#       '4f1785d4-02f4-423e-8f31-a690f9b95d0e',
#       'fef4d064-116b-40be-a59e-4033d1328050',
#       '476cd9f1-17e5-40e1-abfa-e97e3280d347'],
#      'price': 37,
#      'price-title': '500/37',
#      'price_info': [[500, 37]],
#      'price_title': '500/37',
#      'private-memo': None,
#      'processing': False,
#      'refresh': False,
#      'remaining_days': 29,
#      'report_check_comment': None,
#      'report_check_saved_time': None,
#      'room-size-m2': 23.1,
#      'room-title': '원룸 월세',
#      'room_desc': '원룸 | 2층 | 23.1m² | 관리비 1만원',
#      'room_floor': 2,
#      'room_options': [0, 1, 4, 6, 7, 8, 11],
#      'room_size': 23.1,
#      'room_title': '원룸 월세',
#      'room_type': 0,
#      'room_type_str': '원룸',
#      'saved-time': '2015-07-04T09:16:45.161Z',
#      'saved_time': '2015-07-04T09:16:45.161Z',
#      'selling_type': 0,
#      'seq': 344043,
#      'short_lease': False,
#      'status': 1,
#      'tags': ['중개'],
#      'title': '화곡역3분/2011년식/ 풀옵션 원룸/ 주차가능',
#      'user_id': 'ys7901@naver.com',
#      'view_count': 1558}],
#    'show-banner': False}],
#  'filter-str': None,
#  'has-more': True,
#  'limit': 24,
#  'next-page': 2,
#  'offset': 0,
#  'page': 1,
#  'rooms': [{'_id': '566b9cbe2a10374e780d750b',
#    'actived_time': '2016-02-12T01:43:02.709Z',
#    'address': '서울특별시 영등포구 양평동3가',
#    'agent_id': '566a6c8c8b0f5e48bd772b47',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 300,
#    'favorite_count': 4,
#    'floor': '5층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '566b9cbe2a10374e780d750b',
#    'is_pano': False,
#    'location': [126.88485752384084, 37.525963759441815],
#    'maintenance_cost': 6.0,
#    'maintenance_items_str': [],
#    'name': '고유정',
#    'options': ['에어컨',
#     '세탁기',
#     '책상',
#     '옷장',
#     '신발장',
#     '냉장고',
#     '인덕션',
#     '전자도어락',
#     '전자레인지'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '8d9e1e6a-c3fe-440f-a17e-0c4a6f4dc368'},
#     {'desc': '', 'key': '9bd1ea3d-600c-41e7-93f1-55e9f7fe8670'},
#     {'desc': '', 'key': 'd855e550-74a4-4e31-9f0b-787e783b45ee'},
#     {'desc': '', 'key': '1c14e2d2-92ee-4afb-9998-2450e8128c95'},
#     {'desc': '', 'key': 'fb12a839-f69c-4ac7-884b-82fcadb9d72e'},
#     {'desc': '', 'key': '396c6eee-6b50-4bdb-a1f8-42ebad0d3a3d'},
#     {'desc': '', 'key': '5142fccd-b13c-4bed-8043-97c4372e5a59'},
#     {'desc': '', 'key': 'd85b0735-a6d8-4dc2-82fd-08e8004f8a18'}],
#    'photos': ['8d9e1e6a-c3fe-440f-a17e-0c4a6f4dc368',
#     '9bd1ea3d-600c-41e7-93f1-55e9f7fe8670',
#     'd855e550-74a4-4e31-9f0b-787e783b45ee',
#     '1c14e2d2-92ee-4afb-9998-2450e8128c95',
#     'fb12a839-f69c-4ac7-884b-82fcadb9d72e',
#     '396c6eee-6b50-4bdb-a1f8-42ebad0d3a3d',
#     '5142fccd-b13c-4bed-8043-97c4372e5a59',
#     'd85b0735-a6d8-4dc2-82fd-08e8004f8a18'],
#    'price': 45,
#    'price-title': '300/45',
#    'price_info': [[300, 45], [500, 43], [1000, 40], [2000, 30], [3000, 20]],
#    'price_title': '300/45',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 10,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 5층 | 19.8m² | 관리비 6만원',
#    'room_floor': 5,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 11, 10],
#    'room_size': 19.8,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-12-12T04:04:14.339Z',
#    'saved_time': '2015-12-12T04:04:14.339Z',
#    'selling_type': 0,
#    'seq': 590743,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '▣양평역▣ 도보3분! 최저가 싸다구!',
#    'user_id': 'namoo1@naver.com',
#    'view_count': 154},
#   {'_id': '56469eb8deaa1c0667360bdd',
#    'actived_time': '2016-02-24T03:00:25.798Z',
#    'address': '서울특별시 강서구 화곡동',
#    'agent_id': '560cb4dca251073283c4a9f7',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 16500,
#    'favorite_count': 0,
#    'floor': '3층',
#    'hash_tags': ['#전세가능', '#주차'],
#    'heating': None,
#    'id': '56469eb8deaa1c0667360bdd',
#    'is_pano': False,
#    'location': [126.83764633630466, 37.53863402359982],
#    'maintenance_cost': None,
#    'maintenance_items_str': [],
#    'name': '김종철',
#    'options': ['신발장', '가스레인지', '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '3d3cc120-8fd7-480d-82e9-607af1ec924c'},
#     {'desc': '', 'key': '37aaf717-7001-4ca1-967c-4c88515db43f'},
#     {'desc': '', 'key': 'e64228d5-6607-4b2e-b607-460d3e44092b'},
#     {'desc': '', 'key': '2c8a66d7-811e-4120-9f6b-56f11425da94'},
#     {'desc': '', 'key': '9435fafe-e3b0-4939-9f34-358b651e99de'},
#     {'desc': '', 'key': '26fd43a0-6cab-4ded-b683-b30f4ba181a4'},
#     {'desc': '', 'key': '4ee2a034-3714-44ae-a986-301139939ae1'},
#     {'desc': '', 'key': 'c47c5c47-d191-4c78-b4cb-a9468a32ea7c'},
#     {'desc': '', 'key': '509b2c17-4495-4e61-a825-556068f438e7'},
#     {'desc': '', 'key': '254e4d87-44f7-48ec-913c-de0194b9ff23'},
#     {'desc': '', 'key': 'f9bb8288-1b4d-4d58-82cf-d9d94f71c7a1'},
#     {'desc': '', 'key': '4baeb8f9-6ebd-4ec1-a37a-fcbe464eb8ad'},
#     {'desc': '', 'key': 'c8270fa4-d3da-4ef6-9f27-ca0262117306'}],
#    'photos': ['3d3cc120-8fd7-480d-82e9-607af1ec924c',
#     '37aaf717-7001-4ca1-967c-4c88515db43f',
#     'e64228d5-6607-4b2e-b607-460d3e44092b',
#     '2c8a66d7-811e-4120-9f6b-56f11425da94',
#     '9435fafe-e3b0-4939-9f34-358b651e99de',
#     '26fd43a0-6cab-4ded-b683-b30f4ba181a4',
#     '4ee2a034-3714-44ae-a986-301139939ae1',
#     'c47c5c47-d191-4c78-b4cb-a9468a32ea7c',
#     '509b2c17-4495-4e61-a825-556068f438e7',
#     '254e4d87-44f7-48ec-913c-de0194b9ff23',
#     'f9bb8288-1b4d-4d58-82cf-d9d94f71c7a1',
#     '4baeb8f9-6ebd-4ec1-a37a-fcbe464eb8ad',
# ...
#    'photos': ['27d052bc-0547-4646-abd0-93c4a8d5ea55',
#     '592b7648-1afa-4803-9512-6827894cd81c',
#     'd9dabe96-bb07-4ce8-aa32-d84427f46a71',
#     '4b556881-ea7a-43f9-b5f3-b52fe68889a2',
#     'f1a40296-ec84-4e3c-bd79-7c58221a7e29',
#     '0f9e68bc-e318-4bdb-bb85-d1521e894af1',
#     '807e3768-ccc5-4659-b423-84c5ce8ed222',
#     '9952469f-af1b-4b94-92f6-70294b1db507',
#     '6a0a8497-44e9-4926-9cad-1a3fc30485d2',
#     'c12ba81d-b0e0-491a-a76d-abb495cf55b1',
#     '645f0675-2295-4e34-b792-a517961f9c29',
#     'a779fec5-1100-40e8-8581-7580489d123b',
#     'c15c0c66-c85e-4fe8-8572-b8294a076618',
#     '80a7903d-6fde-4e74-b33f-eedb5ac23548'],
#    'price': 0,
#    'price-title': '1억7000',
#    'price_info': [[17000, 0]],
#    'price_title': '1억7000',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 29,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 33.0,
#    'room-title': '투룸 전세',
#    'room_desc': '투룸 | 5층 | 33m²',
#    'room_floor': 5,
#    'room_options': [8, 6, 11],
#    'room_size': 33.0,
#    'room_title': '투룸 전세',
#    'room_type': 1,
#    'room_type_str': '투룸',
#    'saved-time': '2016-03-02T06:13:04.545Z',
#    'saved_time': '2016-03-02T06:13:04.545Z',
#    'selling_type': 1,
#    'seq': 785213,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개', '전세가능'],
#    'title': '☆★ 깔끔한 신축빌라 투룸 거실 넓은 투룸!! 화곡역 도보 6~7분거리 ★☆',
#    'user_id': 'coomman@nate.com',
#    'view_count': 6},
#   {'_id': '55e01a9192c7a61d857e1a23',
#    'actived_time': '2016-02-12T03:19:22.384Z',
#    'address': '인천광역시 계양구 계산동',
#    'agent_id': '55adb1b9360ac33f3243751c',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 30,
#    'favorite_count': 4,
#    'floor': '2층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '55e01a9192c7a61d857e1a23',
#    'is_pano': False,
#    'location': [126.72505782510741, 37.540411360598384],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '이정관대리',
#    'options': ['에어컨', '세탁기', '인덕션', '냉장고', '신발장', 'TV'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'b0f46a02-f417-46f5-aaa3-6388c5e107c7'},
#     {'desc': '', 'key': '752f06f4-5c4f-464c-b61d-8fd5462a73eb'},
#     {'desc': '', 'key': 'cfd2f8cd-7d14-42cd-9fbe-51ffce7e3ead'},
#     {'desc': '', 'key': '8f17806c-4a8c-4854-8740-ee6958c26a15'},
#     {'desc': '', 'key': '34bc4257-b9cb-4cad-93f1-fc92258925b6'},
#     {'desc': '', 'key': 'c5c92177-9c1f-48d2-85cf-88a2199ae097'},
#     {'desc': '', 'key': 'f805545a-9a96-4e33-b4ce-b333b0043eef'},
#     {'desc': '', 'key': 'ef02d385-bece-4c88-9253-b9b9bd0406b4'},
#     {'desc': '', 'key': '76c00e62-85ed-449c-adb0-a7d21b150180'}],
#    'photos': ['b0f46a02-f417-46f5-aaa3-6388c5e107c7',
#     '752f06f4-5c4f-464c-b61d-8fd5462a73eb',
#     'cfd2f8cd-7d14-42cd-9fbe-51ffce7e3ead',
#     '8f17806c-4a8c-4854-8740-ee6958c26a15',
#     '34bc4257-b9cb-4cad-93f1-fc92258925b6',
#     'c5c92177-9c1f-48d2-85cf-88a2199ae097',
#     'f805545a-9a96-4e33-b4ce-b333b0043eef',
#     'ef02d385-bece-4c88-9253-b9b9bd0406b4',
#     '76c00e62-85ed-449c-adb0-a7d21b150180'],
#    'price': 30,
#    'price-title': '30/30',
#    'price_info': [[30, 30]],
#    'price_title': '30/30',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 10,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 2층 | 19.8m² | 관리비 5만원',
#    'room_floor': 2,
#    'room_options': [0, 1, 9, 7, 6, 5],
#    'room_size': 19.8,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-08-28T08:23:45.944Z',
#    'saved_time': '2015-08-28T08:23:45.944Z',
#    'selling_type': 0,
#    'seq': 429842,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '계산동 무보증 단기 최저가 30/30만원',
#    'user_id': 'SKYLJK86@hanmail.net',
#    'view_count': 1493},
#   {'_id': '5614d5d4746fd2123c3861f7',
#    'actived_time': '2016-02-29T05:18:16.385Z',
#    'address': '서울특별시 양천구 신월동',
#    'agent_id': '52ff0b3be4b089dec7755b9c',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 1000,
#    'favorite_count': 9,
#    'floor': '4층',
#    'hash_tags': [],
#    'heating': None,
#    'id': '5614d5d4746fd2123c3861f7',
#    'is_pano': False,
#    'location': [126.83683514418396, 37.53080862273996],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '김갑',
#    'options': ['에어컨', '세탁기', '옷장', '신발장', '냉장고', '인덕션'],
#    'pano': None,
#    'parking': False,
#    'photo': [{'desc': '', 'key': '5deb0ccf-ac0a-47b2-b480-53c0470812ac'},
#     {'desc': '', 'key': '50e3d6e4-a3bb-44e7-ba36-9947c55d69da'},
#     {'desc': '', 'key': '2e0f8f93-d8ff-4187-b4e8-9776351e2a96'},
#     {'desc': '', 'key': '8d084582-a884-469d-92e9-728e4c1f9c7d'}],
#    'photos': ['5deb0ccf-ac0a-47b2-b480-53c0470812ac',
#     '50e3d6e4-a3bb-44e7-ba36-9947c55d69da',
#     '2e0f8f93-d8ff-4187-b4e8-9776351e2a96',
#     '8d084582-a884-469d-92e9-728e4c1f9c7d'],
#    'price': 50,
#    'price-title': '1000/50',
#    'price_info': [[1000, 50]],
#    'price_title': '1000/50',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 27,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 39.6,
#    'room-title': '투룸 월세',
#    'room_desc': '투룸 | 4층 | 39.6m² | 관리비 5만원',
#    'room_floor': 4,
#    'room_options': [0, 1, 4, 6, 7, 9],
#    'room_size': 39.6,
#    'room_title': '투룸 월세',
#    'room_type': 1,
#    'room_type_str': '투룸',
#    'saved-time': '2015-10-07T08:20:36.190Z',
#    'saved_time': '2015-10-07T08:20:36.190Z',
#    'selling_type': 0,
#    'seq': 486551,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '까치산역 도보 가능/깔끔한 풀옵션 투룸',
#    'user_id': 'clc47@hanmail.net',
#    'view_count': 1044},
#   {'_id': '55aefa293be9384693aa07ff',
#    'actived_time': '2016-02-25T04:42:38.965Z',
#    'address': '서울특별시 영등포구 당산동',
#    'agent_id': '54e6a298e4b08d0a98810ec8',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 1000,
#    'favorite_count': 0,
#    'floor': '7층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '55aefa293be9384693aa07ff',
#    'is_pano': False,
#    'location': [126.90147968372217, 37.53530956234303],
#    'maintenance_cost': 6.0,
#    'maintenance_items_str': [],
#    'name': '채영민',
#    'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'fce2ee2c-5a67-40b0-b4f6-d2f843b6b9ac'},
#     {'desc': '', 'key': '6237a01f-2ea7-4497-a1a2-9bc388191cdc'},
#     {'desc': '', 'key': 'eca97271-f254-4763-a9bb-9382f5c1df99'},
#     {'desc': '', 'key': '8b392fa6-ffea-403f-b4cb-89fbe2e26141'},
#     {'desc': '', 'key': '16e3b724-10c5-413c-b5df-55305edb668b'},
#     {'desc': '', 'key': '8bf8a342-7f0a-41fa-a063-87a8531d9204'},
#     {'desc': '', 'key': 'ffbe4000-064a-4c6c-95a7-d850bba4edd5'},
#     {'desc': '', 'key': '6b5af723-26ca-4a55-bccf-4546109e8eee'},
#     {'desc': '', 'key': 'bc0dfc7c-517d-4bfb-a7d5-5f674e21e091'}],
#    'photos': ['fce2ee2c-5a67-40b0-b4f6-d2f843b6b9ac',
#     '6237a01f-2ea7-4497-a1a2-9bc388191cdc',
#     'eca97271-f254-4763-a9bb-9382f5c1df99',
#     '8b392fa6-ffea-403f-b4cb-89fbe2e26141',
#     '16e3b724-10c5-413c-b5df-55305edb668b',
#     '8bf8a342-7f0a-41fa-a063-87a8531d9204',
#     'ffbe4000-064a-4c6c-95a7-d850bba4edd5',
#     '6b5af723-26ca-4a55-bccf-4546109e8eee',
#     'bc0dfc7c-517d-4bfb-a7d5-5f674e21e091'],
#    'price': 70,
#    'price-title': '1000/70',
#    'price_info': [[1000, 70]],
#    'price_title': '1000/70',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 23,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 24.8,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 7층 | 24.8m² | 관리비 6만원',
#    'room_floor': 7,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 11],
#    'room_size': 24.8,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-07-22T02:04:25.787Z',
#    'saved_time': '2015-07-22T02:04:25.787Z',
#    'selling_type': 0,
#    'seq': 368167,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '##당산역 NO.1 오피스텔##스타~~빌!!!##',
#    'user_id': '0min18@naver.com',
#    'view_count': 36},
#   {'_id': '56b70857401cc22a77188951',
#    'actived_time': '2016-02-07T09:03:19.119Z',
#    'address': '서울특별시 양천구 신정4동',
#    'agent_id': None,
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 0,
#    'favorite_count': 9,
#    'floor': '2층',
#    'hash_tags': ['#직거래', '#단기가능', '#주차'],
#    'heating': None,
#    'id': '56b70857401cc22a77188951',
#    'is_pano': False,
#    'location': [126.85922490284717, 37.52712170586233],
#    'maintenance_cost': None,
#    'maintenance_items_str': [],
#    'name': '조은하',
#    'options': ['에어컨',
#     '책상',
#     '신발장',
#     '세탁기',
#     '옷장',
#     '냉장고',
#     '전자레인지',
#     '침대',
#     'TV',
#     '가스레인지'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'd367a2aa-0f7b-4593-a7a7-1fc0bac63d12'},
#     {'desc': '', 'key': '5ca109e0-4ee5-4d35-a7d3-6d4a2747095b'},
#     {'desc': '', 'key': '7b456590-8c51-4e36-95c8-729fef2e9077'},
#     {'desc': '', 'key': '14be377b-cac4-402c-9bb1-f6827f8d307d'},
#     {'desc': '', 'key': 'abd757b6-674e-44b3-adf0-0155581d7252'}],
#    'photos': ['d367a2aa-0f7b-4593-a7a7-1fc0bac63d12',
#     '5ca109e0-4ee5-4d35-a7d3-6d4a2747095b',
#     '7b456590-8c51-4e36-95c8-729fef2e9077',
#     '14be377b-cac4-402c-9bb1-f6827f8d307d',
#     'abd757b6-674e-44b3-adf0-0155581d7252'],
#    'price': 22,
#    'price-title': '0/22',
#    'price_info': [[0, 22]],
#    'price_title': '0/22',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 5,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 9.9,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 2층 | 9.9m²',
#    'room_floor': 2,
#    'room_options': [0, 3, 6, 1, 4, 7, 10, 2, 5, 8],
#    'room_size': 9.9,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-07T09:03:19.119Z',
#    'saved_time': '2016-02-07T09:03:19.119Z',
#    'selling_type': 0,
#    'seq': 732681,
#    'short_lease': True,
#    'status': 1,
#    'tags': ['직거래'],
#    'title': '목동역1번 노블레지던스',
#    'user_id': 'star5512@navet.com',
#    'view_count': 502},
#   {'_id': '561492410c809c6886d89737',
#    'actived_time': '2016-03-02T04:21:30.796Z',
#    'address': '서울특별시 강서구 화곡동',
#    'agent_id': '52d3a24be4b02acb1311d818',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 4500,
#    'favorite_count': 13,
#    'floor': '5층',
#    'hash_tags': ['#전세가능', '#주차'],
#    'heating': None,
#    'id': '561492410c809c6886d89737',
#    'is_pano': False,
#    'location': [126.847021255876, 37.5466365974297],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '김정식',
#    'options': ['에어컨',
#     '세탁기',
#     '책상',
#     '옷장',
#     '신발장',
#     '냉장고',
#     '인덕션',
#     '전자레인지',
#     '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'd2ae45d6-6fc7-44ec-93de-fdf99e68b7db'},
#     {'desc': '', 'key': 'e342b72b-e75e-4f1a-aa88-2e42cf9e9190'},
#     {'desc': '', 'key': '2fb8bc5b-3303-46e1-918a-cd8ccbe8cabc'},
#     {'desc': '', 'key': '4d12dbd4-9a1f-4b87-9d1f-08d5710ae73f'},
#     {'desc': '', 'key': '694aa316-3411-4a2c-8d0c-4eedb57f0c28'},
#     {'desc': '', 'key': 'cf3601d5-a3ce-4186-9457-18a8caf0b63b'},
#     {'desc': '', 'key': 'ef7f6fc2-f174-4986-8f02-bcf44b1560bc'},
#     {'desc': '', 'key': '81c1186c-2181-433e-af18-45d2effc61a9'},
#     {'desc': '', 'key': '7446041e-5cbf-4e4b-9837-7b5a69bcc876'}],
#    'photos': ['d2ae45d6-6fc7-44ec-93de-fdf99e68b7db',
#     'e342b72b-e75e-4f1a-aa88-2e42cf9e9190',
#     '2fb8bc5b-3303-46e1-918a-cd8ccbe8cabc',
#     '4d12dbd4-9a1f-4b87-9d1f-08d5710ae73f',
#     '694aa316-3411-4a2c-8d0c-4eedb57f0c28',
#     'cf3601d5-a3ce-4186-9457-18a8caf0b63b',
#     'ef7f6fc2-f174-4986-8f02-bcf44b1560bc',
#     '81c1186c-2181-433e-af18-45d2effc61a9',
#     '7446041e-5cbf-4e4b-9837-7b5a69bcc876'],
#    'price': 0,
#    'price-title': '4500',
#    'price_info': [[4500, 0], [2000, 25], [3000, 15], [4000, 5]],
#    'price_title': '4500',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 29,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 21.4,
#    'room-title': '원룸 전세',
#    'room_desc': '원룸 | 5층 | 21.4m² | 관리비 5만원',
#    'room_floor': 5,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 10, 11],
#    'room_size': 21.4,
#    'room_title': '원룸 전세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-10-07T03:32:17.452Z',
#    'saved_time': '2015-10-07T03:32:17.452Z',
#    'selling_type': 1,
#    'seq': 485865,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개', '전세가능'],
#    'title': '※가격대비 넓은 방입니다',
#    'user_id': 'skydiver7223@nate.com',
#    'view_count': 956},
#   {'_id': '56b2db96b334122d2e9016b5',
#    'actived_time': '2016-02-23T06:42:06.592Z',
#    'address': '서울특별시 영등포구 양평동',
#    'agent_id': '56373cba853a2a545c8967c9',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 1000,
#    'favorite_count': 1,
#    'floor': '7층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '56b2db96b334122d2e9016b5',
#    'is_pano': False,
#    'location': [126.88445325630683, 37.52108714152279],
#    'maintenance_cost': 7.0,
#    'maintenance_items_str': [],
#    'name': '유상훈',
#    'options': ['에어컨',
#     '세탁기',
#     '옷장',
#     'TV',
#     '신발장',
#     '냉장고',
#     '가스레인지',
#     '전자레인지',
#     '전자도어락',
#     '비데'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'bc12d9fc-b953-461f-b58f-8a11eee1d671'},
#     {'desc': '', 'key': 'd0bf9901-9481-4591-a0b9-73cf7a126675'},
#     {'desc': '', 'key': '80fe8c01-e9dd-40ba-a352-f0d0edf5a18e'},
#     {'desc': '', 'key': '389aba2e-4a9d-4c3c-8ae8-c63499c5b8c9'},
#     {'desc': '', 'key': '8d638a76-d3ed-4ae8-a544-fbbb0af4b6fd'},
#     {'desc': '', 'key': 'e1b150ad-4c62-44aa-be45-88162ebb6659'},
#     {'desc': '', 'key': 'b90898e2-f6ba-421b-af14-102b7125bcc4'},
#     {'desc': '', 'key': 'c5dd57da-3f18-4eb8-9d01-9518c8881105'},
#     {'desc': '', 'key': 'a66e675d-b49d-40ea-9f54-d785b08e7f24'},
#     {'desc': '', 'key': '2f44fe4e-9c29-44ef-b2cc-246448c34de4'},
#     {'desc': '', 'key': 'b465c11f-1457-401c-86cb-eb7c9ceacc82'},
#     {'desc': '', 'key': 'a08cb316-6d92-4671-ac03-0f8fbe831ced'},
#     {'desc': '', 'key': '926eddae-42b8-450f-a615-7b969952cec4'},
#     {'desc': '', 'key': 'b906cb7e-f818-494d-a8f0-15e4897f7bf5'},
#     {'desc': '', 'key': 'd300b856-1fbd-4adc-bf1f-43b687d84c9a'},
#     {'desc': '', 'key': '009418e4-b9a7-4a61-a30d-8a4dc50bd328'}],
#    'photos': ['bc12d9fc-b953-461f-b58f-8a11eee1d671',
#     'd0bf9901-9481-4591-a0b9-73cf7a126675',
#     '80fe8c01-e9dd-40ba-a352-f0d0edf5a18e',
#     '389aba2e-4a9d-4c3c-8ae8-c63499c5b8c9',
#     '8d638a76-d3ed-4ae8-a544-fbbb0af4b6fd',
#     'e1b150ad-4c62-44aa-be45-88162ebb6659',
#     'b90898e2-f6ba-421b-af14-102b7125bcc4',
#     'c5dd57da-3f18-4eb8-9d01-9518c8881105',
#     'a66e675d-b49d-40ea-9f54-d785b08e7f24',
#     '2f44fe4e-9c29-44ef-b2cc-246448c34de4',
#     'b465c11f-1457-401c-86cb-eb7c9ceacc82',
#     'a08cb316-6d92-4671-ac03-0f8fbe831ced',
#     '926eddae-42b8-450f-a615-7b969952cec4',
#     'b906cb7e-f818-494d-a8f0-15e4897f7bf5',
#     'd300b856-1fbd-4adc-bf1f-43b687d84c9a',
#     '009418e4-b9a7-4a61-a30d-8a4dc50bd328'],
#    'price': 62,
#    'price-title': '1000/62',
#    'price_info': [[1000, 62], [1500, 60]],
#    'price_title': '1000/62',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 21,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 7층 | 19.8m² | 관리비 7만원',
#    'room_floor': 7,
#    'room_options': [0, 1, 4, 5, 6, 7, 8, 10, 11, 12],
#    'room_size': 19.8,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-04T05:03:18.441Z',
#    'saved_time': '2016-02-04T05:03:18.441Z',
#    'selling_type': 0,
#    'seq': 725945,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '★★ 완전 풀옵션 ^^ / 예쁜 복층오피스텔 / 전세★월세 ',
#    'user_id': 'yusanghun27@gmail.com',
#    'view_count': 37}],
#  'total': 500,
#  'total-str': '500+'}

# %%
dabang_dict.keys()
# Out:
# dict_keys(['next-page', 'features', 'ad-banner', 'offset', 'total', 'has-more', 'filter-str', 'rooms', 'page', 'limit', 'total-str'])

# %%
rooms
# Out:
# [{'_id': '566b9cbe2a10374e780d750b',
#   'actived_time': '2016-02-12T01:43:02.709Z',
#   'address': '서울특별시 영등포구 양평동3가',
#   'agent_id': '566a6c8c8b0f5e48bd772b47',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 300,
#   'favorite_count': 4,
#   'floor': '5층',
#   'hash_tags': ['#주차'],
#   'heating': None,
#   'id': '566b9cbe2a10374e780d750b',
#   'is_pano': False,
#   'location': [126.88485752384084, 37.525963759441815],
#   'maintenance_cost': 6.0,
#   'maintenance_items_str': [],
#   'name': '고유정',
#   'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자도어락', '전자레인지'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '8d9e1e6a-c3fe-440f-a17e-0c4a6f4dc368'},
#    {'desc': '', 'key': '9bd1ea3d-600c-41e7-93f1-55e9f7fe8670'},
#    {'desc': '', 'key': 'd855e550-74a4-4e31-9f0b-787e783b45ee'},
#    {'desc': '', 'key': '1c14e2d2-92ee-4afb-9998-2450e8128c95'},
#    {'desc': '', 'key': 'fb12a839-f69c-4ac7-884b-82fcadb9d72e'},
#    {'desc': '', 'key': '396c6eee-6b50-4bdb-a1f8-42ebad0d3a3d'},
#    {'desc': '', 'key': '5142fccd-b13c-4bed-8043-97c4372e5a59'},
#    {'desc': '', 'key': 'd85b0735-a6d8-4dc2-82fd-08e8004f8a18'}],
#   'photos': ['8d9e1e6a-c3fe-440f-a17e-0c4a6f4dc368',
#    '9bd1ea3d-600c-41e7-93f1-55e9f7fe8670',
#    'd855e550-74a4-4e31-9f0b-787e783b45ee',
#    '1c14e2d2-92ee-4afb-9998-2450e8128c95',
#    'fb12a839-f69c-4ac7-884b-82fcadb9d72e',
#    '396c6eee-6b50-4bdb-a1f8-42ebad0d3a3d',
#    '5142fccd-b13c-4bed-8043-97c4372e5a59',
#    'd85b0735-a6d8-4dc2-82fd-08e8004f8a18'],
#   'price': 45,
#   'price-title': '300/45',
#   'price_info': [[300, 45], [500, 43], [1000, 40], [2000, 30], [3000, 20]],
#   'price_title': '300/45',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 10,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 5층 | 19.8m² | 관리비 6만원',
#   'room_floor': 5,
#   'room_options': [0, 1, 3, 4, 6, 7, 9, 11, 10],
#   'room_size': 19.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2015-12-12T04:04:14.339Z',
#   'saved_time': '2015-12-12T04:04:14.339Z',
#   'selling_type': 0,
#   'seq': 590743,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '▣양평역▣ 도보3분! 최저가 싸다구!',
#   'user_id': 'namoo1@naver.com',
#   'view_count': 154},
#  {'_id': '56469eb8deaa1c0667360bdd',
#   'actived_time': '2016-02-24T03:00:25.798Z',
#   'address': '서울특별시 강서구 화곡동',
#   'agent_id': '560cb4dca251073283c4a9f7',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 16500,
#   'favorite_count': 0,
#   'floor': '3층',
#   'hash_tags': ['#전세가능', '#주차'],
#   'heating': None,
#   'id': '56469eb8deaa1c0667360bdd',
#   'is_pano': False,
#   'location': [126.83764633630466, 37.53863402359982],
#   'maintenance_cost': None,
#   'maintenance_items_str': [],
#   'name': '김종철',
#   'options': ['신발장', '가스레인지', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '3d3cc120-8fd7-480d-82e9-607af1ec924c'},
#    {'desc': '', 'key': '37aaf717-7001-4ca1-967c-4c88515db43f'},
#    {'desc': '', 'key': 'e64228d5-6607-4b2e-b607-460d3e44092b'},
#    {'desc': '', 'key': '2c8a66d7-811e-4120-9f6b-56f11425da94'},
#    {'desc': '', 'key': '9435fafe-e3b0-4939-9f34-358b651e99de'},
#    {'desc': '', 'key': '26fd43a0-6cab-4ded-b683-b30f4ba181a4'},
#    {'desc': '', 'key': '4ee2a034-3714-44ae-a986-301139939ae1'},
#    {'desc': '', 'key': 'c47c5c47-d191-4c78-b4cb-a9468a32ea7c'},
#    {'desc': '', 'key': '509b2c17-4495-4e61-a825-556068f438e7'},
#    {'desc': '', 'key': '254e4d87-44f7-48ec-913c-de0194b9ff23'},
#    {'desc': '', 'key': 'f9bb8288-1b4d-4d58-82cf-d9d94f71c7a1'},
#    {'desc': '', 'key': '4baeb8f9-6ebd-4ec1-a37a-fcbe464eb8ad'},
#    {'desc': '', 'key': 'c8270fa4-d3da-4ef6-9f27-ca0262117306'}],
#   'photos': ['3d3cc120-8fd7-480d-82e9-607af1ec924c',
#    '37aaf717-7001-4ca1-967c-4c88515db43f',
#    'e64228d5-6607-4b2e-b607-460d3e44092b',
#    '2c8a66d7-811e-4120-9f6b-56f11425da94',
#    '9435fafe-e3b0-4939-9f34-358b651e99de',
#    '26fd43a0-6cab-4ded-b683-b30f4ba181a4',
#    '4ee2a034-3714-44ae-a986-301139939ae1',
#    'c47c5c47-d191-4c78-b4cb-a9468a32ea7c',
#    '509b2c17-4495-4e61-a825-556068f438e7',
#    '254e4d87-44f7-48ec-913c-de0194b9ff23',
#    'f9bb8288-1b4d-4d58-82cf-d9d94f71c7a1',
#    '4baeb8f9-6ebd-4ec1-a37a-fcbe464eb8ad',
#    'c8270fa4-d3da-4ef6-9f27-ca0262117306'],
#   'price': 0,
#   'price-title': '1억6500',
#   'price_info': [[16500, 0]],
#   'price_title': '1억6500',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 22,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 49.5,
#   'room-title': '투룸 전세',
#   'room_desc': '투룸 | 3층 | 49.5m²',
#   'room_floor': 3,
#   'room_options': [6, 8, 11],
#   'room_size': 49.5,
#   'room_title': '투룸 전세',
#   'room_type': 1,
#   'room_type_str': '투룸',
#   'saved-time': '2015-11-14T02:38:48.250Z',
#   'saved_time': '2015-11-14T02:38:48.250Z',
#   'selling_type': 1,
#   'seq': 543090,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개', '전세가능'],
#   'title': '♥희망♥~대박!!화곡역도보5분 신축빌라 첫입주 전세자금대출가능 역세권 신혼부부추천',
#   'user_id': 'wsung8484@naver.com',
#   'view_count': 136},
#  {'_id': '56c3d6fd87b2c95f6d98e461',
#   'actived_time': '2016-02-17T02:12:13.021Z',
#   'address': '서울특별시 강서구 화곡동 ',
#   'agent_id': '534232b3e4b0d61b62710d88',
#   'animal': True,
#   'building_floor_str': '',
#   'deposit': 16800,
#   'favorite_count': 3,
#   'floor': '9층',
#   'hash_tags': ['#전세가능', '#주차', '#반려동물'],
#   'heating': None,
#   'id': '56c3d6fd87b2c95f6d98e461',
#   'is_pano': False,
#   'location': [126.84441204998673, 37.53017373146788],
#   'maintenance_cost': 3.0,
#   'maintenance_items_str': [],
#   'name': '권혁일',
#   'options': ['신발장', '인덕션', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '3f6c57a6-5375-44fb-91ee-6b49cea87042'},
#    {'desc': '', 'key': '3d10a678-e0f3-43da-9e0e-9d1090137d85'},
#    {'desc': '', 'key': '15e29876-45e5-415e-b757-7d22e0c1f4a8'},
#    {'desc': '', 'key': 'a48bfdad-0759-41f8-b4f4-9f3860616e72'},
#    {'desc': '', 'key': '5a686b81-116d-4d0f-a12b-1bc7009cdd0f'},
#    {'desc': '', 'key': '9f452b61-e8c7-4eca-90b1-e071b22b2082'},
#    {'desc': '', 'key': '50a1399c-f58b-407b-8d3d-f902d0b08b3f'},
#    {'desc': '', 'key': '1d49b9e1-4315-4143-84fb-ba89a162a3d5'},
#    {'desc': '', 'key': 'f969344b-9b1f-43b3-a3f9-303f8a93b638'},
#    {'desc': '', 'key': 'eadf0d2a-c767-476e-82e6-fd07a227f5a2'},
#    {'desc': '', 'key': 'afbbc28e-01b7-40a4-9de2-d046a5c11b64'},
#    {'desc': '', 'key': '6206fb2d-146d-49b1-bc4d-a28caaa5e911'},
#    {'desc': '', 'key': 'f678fa08-f2fa-429d-b570-34acc8dfe5fd'},
#    {'desc': '', 'key': '2a4e9aca-2d6b-4546-b1e4-d60604349e93'},
#    {'desc': '', 'key': '483a87a3-bc86-4d28-9d33-2121249a3cd1'},
#    {'desc': '', 'key': '1118c1a8-d8ac-4810-9f2c-6f6e4359c40c'},
#    {'desc': '', 'key': 'ea7626d3-3990-4c99-b132-08ef0aeace24'}],
#   'photos': ['3f6c57a6-5375-44fb-91ee-6b49cea87042',
#    '3d10a678-e0f3-43da-9e0e-9d1090137d85',
#    '15e29876-45e5-415e-b757-7d22e0c1f4a8',
#    'a48bfdad-0759-41f8-b4f4-9f3860616e72',
#    '5a686b81-116d-4d0f-a12b-1bc7009cdd0f',
#    '9f452b61-e8c7-4eca-90b1-e071b22b2082',
#    '50a1399c-f58b-407b-8d3d-f902d0b08b3f',
#    '1d49b9e1-4315-4143-84fb-ba89a162a3d5',
#    'f969344b-9b1f-43b3-a3f9-303f8a93b638',
#    'eadf0d2a-c767-476e-82e6-fd07a227f5a2',
#    'afbbc28e-01b7-40a4-9de2-d046a5c11b64',
#    '6206fb2d-146d-49b1-bc4d-a28caaa5e911',
#    'f678fa08-f2fa-429d-b570-34acc8dfe5fd',
#    '2a4e9aca-2d6b-4546-b1e4-d60604349e93',
#    '483a87a3-bc86-4d28-9d33-2121249a3cd1',
#    '1118c1a8-d8ac-4810-9f2c-6f6e4359c40c',
#    'ea7626d3-3990-4c99-b132-08ef0aeace24'],
#   'price': 0,
#   'price-title': '1억6800',
#   'price_info': [[16800, 0]],
#   'price_title': '1억6800',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 15,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 49.5,
#   'room-title': '투룸 전세',
#   'room_desc': '투룸 | 9층 | 49.5m² | 관리비 3만원',
#   'room_floor': 9,
#   'room_options': [6, 9, 11],
#   'room_size': 49.5,
#   'room_title': '투룸 전세',
#   'room_type': 1,
#   'room_type_str': '투룸',
#   'saved-time': '2016-02-17T02:12:13.021Z',
#   'saved_time': '2016-02-17T02:12:13.021Z',
#   'selling_type': 1,
#   'seq': 750480,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개', '전세가능'],
#   'title': '❤❤[신축첫입주 아파트] 신혼부부들이 한눈에 쏘~옥 반하는 전세자금대출 가능한 신축첫입주 아파트전세/입주협의가능',
#   'user_id': 'hikwon77@hanmail.net',
#   'view_count': 64},
#  {'_id': '560df2a0d026986ad595de63',
#   'actived_time': '2016-02-12T01:41:55.837Z',
#   'address': '서울특별시 강서구 화곡동',
#   'agent_id': '53ba22a2e4b0102e6fb94891',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 1000,
#   'favorite_count': 0,
#   'floor': '7층',
#   'hash_tags': [],
#   'heating': None,
#   'id': '560df2a0d026986ad595de63',
#   'is_pano': False,
#   'location': [126.84417439358533, 37.52912104928763],
#   'maintenance_cost': 6.0,
#   'maintenance_items_str': [],
#   'name': '이정세',
#   'options': ['세탁기', '에어컨', '옷장', '신발장', '인덕션', '전자도어락'],
#   'pano': None,
#   'parking': False,
#   'photo': [{'desc': '', 'key': '08ae2e85-a70d-407d-a9ec-0127a65b9e65'},
#    {'desc': '', 'key': '41627c55-5ccb-4e38-9823-8739f16c9466'},
#    {'desc': '', 'key': '722defd0-c5cb-477a-9bc6-92c76c32b939'},
#    {'desc': '', 'key': '8b07088e-b446-48fd-8c85-e5d77aa4a968'},
#    {'desc': '', 'key': 'def77a68-9fc6-4206-90bf-27170f9acb12'},
#    {'desc': '', 'key': '551bcd2a-4f68-4fbe-bfdf-c05a9b61402a'},
#    {'desc': '', 'key': '01afc366-3d32-4765-a479-192d195fb024'}],
#   'photos': ['08ae2e85-a70d-407d-a9ec-0127a65b9e65',
#    '41627c55-5ccb-4e38-9823-8739f16c9466',
#    '722defd0-c5cb-477a-9bc6-92c76c32b939',
#    '8b07088e-b446-48fd-8c85-e5d77aa4a968',
#    'def77a68-9fc6-4206-90bf-27170f9acb12',
#    '551bcd2a-4f68-4fbe-bfdf-c05a9b61402a',
#    '01afc366-3d32-4765-a479-192d195fb024'],
#   'price': 50,
#   'price-title': '1000/50',
#   'price_info': [[1000, 50], [2000, 40], [3000, 30]],
#   'price_title': '1000/50',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 10,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 23.1,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 7층 | 23.1m² | 관리비 6만원',
#   'room_floor': 7,
#   'room_options': [1, 0, 4, 6, 9, 11],
#   'room_size': 23.1,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2015-10-02T02:57:36.602Z',
#   'saved_time': '2015-10-02T02:57:36.602Z',
#   'selling_type': 0,
#   'seq': 478317,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '큰방 보증금 조절이 다양하게 가능합니다~^^',
#   'user_id': 'delight286@naver.com',
#   'view_count': 326},
#  {'_id': '56c121164dc1a411e4a989b4',
#   'actived_time': '2016-02-15T00:51:34.399Z',
#   'address': '인천광역시 부평구 갈산1동',
#   'agent_id': None,
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 250,
#   'favorite_count': 1,
#   'floor': '2층',
#   'hash_tags': ['#직거래'],
#   'heating': None,
#   'id': '56c121164dc1a411e4a989b4',
#   'is_pano': False,
#   'location': [126.72428483097181, 37.51679257163452],
#   'maintenance_cost': None,
#   'maintenance_items_str': [],
#   'name': '구정',
#   'options': ['에어컨', '세탁기', '옷장', '냉장고', '신발장', '가스레인지'],
#   'pano': None,
#   'parking': False,
#   'photo': [{'desc': '', 'key': '911bdfa6-255e-47c1-9fa4-7f2c64a28cfc'},
#    {'desc': '', 'key': '3970d109-6def-4be9-a0d9-286c168ee950'},
#    {'desc': '', 'key': '0b3877e6-8495-4850-970e-bf6b5584d55e'},
#    {'desc': '', 'key': 'd3f5a17f-6458-4909-a1ef-e8259af616d2'}],
#   'photos': ['911bdfa6-255e-47c1-9fa4-7f2c64a28cfc',
#    '3970d109-6def-4be9-a0d9-286c168ee950',
#    '0b3877e6-8495-4850-970e-bf6b5584d55e',
#    'd3f5a17f-6458-4909-a1ef-e8259af616d2'],
#   'price': 35,
#   'price-title': '250/35',
#   'price_info': [[250, 35]],
#   'price_title': '250/35',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 13,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 2층 | 19.8m²',
#   'room_floor': 2,
#   'room_options': [0, 1, 4, 7, 6, 8],
#   'room_size': 19.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2016-02-15T00:51:34.399Z',
#   'saved_time': '2016-02-15T00:51:34.399Z',
#   'selling_type': 0,
#   'seq': 743905,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['직거래'],
#   'title': '갈산역 도보 3분 , 깨끗하고 조용함',
#   'user_id': 'rnwjdsla@naver.com',
#   'view_count': 128},
#  {'_id': '56ab0f3fab7a4c318044840d',
#   'actived_time': '2016-02-29T01:51:24.511Z',
#   'address': '서울특별시 영등포구 당산동',
#   'agent_id': '54d2c6d8e4b0f3d9770eeb79',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 2000,
#   'favorite_count': 0,
#   'floor': '3층',
#   'hash_tags': ['#주차'],
#   'heating': None,
#   'id': '56ab0f3fab7a4c318044840d',
#   'is_pano': False,
#   'location': [126.90404344764717, 37.53358535632537],
#   'maintenance_cost': 5.0,
#   'maintenance_items_str': [],
#   'name': '서혜정',
#   'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'fd594fc0-7c16-40e0-9f6d-89a0118aba1b'},
#    {'desc': '', 'key': 'd7ad892b-22cb-48b6-861f-494f253025e3'},
#    {'desc': '', 'key': '9d32d3a1-e163-4a4c-b3e3-524f127df817'},
#    {'desc': '', 'key': '971c7f9f-4c03-4d1d-8306-6b20e422475e'},
#    {'desc': '', 'key': '11a287b0-090c-4d48-ac67-0ac374a665fa'},
#    {'desc': '', 'key': 'e9cb484e-305b-4174-8529-a468edc5083e'},
#    {'desc': '', 'key': '702949da-43e4-4336-b5e8-b188fb60e556'}],
#   'photos': ['fd594fc0-7c16-40e0-9f6d-89a0118aba1b',
#    'd7ad892b-22cb-48b6-861f-494f253025e3',
#    '9d32d3a1-e163-4a4c-b3e3-524f127df817',
#    '971c7f9f-4c03-4d1d-8306-6b20e422475e',
#    '11a287b0-090c-4d48-ac67-0ac374a665fa',
#    'e9cb484e-305b-4174-8529-a468edc5083e',
#    '702949da-43e4-4336-b5e8-b188fb60e556'],
#   'price': 50,
#   'price-title': '2000/50',
#   'price_info': [[2000, 50]],
#   'price_title': '2000/50',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 27,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 3층 | 19.8m² | 관리비 5만원',
#   'room_floor': 3,
#   'room_options': [0, 1, 3, 4, 6, 7, 9, 11],
#   'room_size': 19.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2016-01-29T07:05:35.632Z',
#   'saved_time': '2016-01-29T07:05:35.632Z',
#   'selling_type': 0,
#   'seq': 708501,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '당산역 분리형 원룸  저렴한 관리비',
#   'user_id': 'gounzari@hanmail.net',
#   'view_count': 46},
#  {'_id': '5437a693e4b007ee2d1d7648',
#   'actived_time': '2016-02-10T02:08:44.448Z',
#   'address': '서울특별시 영등포구 영등포동6가',
#   'agent_id': '53ec52b0e4b018569e1a3a3c',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 1000,
#   'favorite_count': 4,
#   'floor': '',
#   'hash_tags': [],
#   'heating': None,
#   'id': '5437a693e4b007ee2d1d7648',
#   'is_pano': False,
#   'location': [126.904236693, 37.5216708742],
#   'maintenance_cost': 10,
#   'maintenance_items_str': [],
#   'name': '박성배',
#   'options': ['에어컨', '세탁기', '옷장', 'TV', '신발장', '냉장고', '인덕션', '전자도어락'],
#   'pano': None,
#   'parking': False,
#   'photo': [{'desc': '', 'key': '995a0363-9552-48da-b589-de31a401e528'},
#    {'desc': '', 'key': '08160e3f-b8b8-4462-95fd-2210a1eadfd8'},
#    {'desc': '', 'key': '948dd52b-02d9-46a5-9e3c-3e4da5b3b6ef'},
#    {'desc': '', 'key': '07f6c91e-b8da-4bcf-9e00-9f302823de0e'},
#    {'desc': '', 'key': 'fa81fb53-6644-48ed-a249-112e612745fc'},
#    {'desc': '', 'key': '84c5557e-b8a4-4295-8599-b8d54016c509'},
#    {'desc': '', 'key': '184963c0-ea6f-41e0-87fb-3b40a211e994'},
#    {'desc': '', 'key': '197d0181-a205-41e1-826d-c8e407958492'},
#    {'desc': '', 'key': '97b3d55b-48a1-402b-819f-321b276b2c01'},
#    {'desc': '', 'key': '70bf8fdd-2187-4dc4-a7cb-5402cb314046'},
#    {'desc': '', 'key': 'b5d57e28-94cb-4aa7-b5db-7a4f661a7ae5'},
#    {'desc': '', 'key': '2436a3e7-2d39-4211-84f1-4c3bc740cb00'},
#    {'desc': '', 'key': '7fb45b55-bbd3-4b93-b475-607887b0678d'},
#    {'desc': '', 'key': 'fc745ab4-30e2-4b0d-aa0c-a890a9b5d169'},
#    {'desc': '', 'key': '9d24d253-684c-4821-8e65-fe3f7bfadd8e'}],
#   'photos': ['995a0363-9552-48da-b589-de31a401e528',
#    '08160e3f-b8b8-4462-95fd-2210a1eadfd8',
#    '948dd52b-02d9-46a5-9e3c-3e4da5b3b6ef',
#    '07f6c91e-b8da-4bcf-9e00-9f302823de0e',
#    'fa81fb53-6644-48ed-a249-112e612745fc',
#    '84c5557e-b8a4-4295-8599-b8d54016c509',
#    '184963c0-ea6f-41e0-87fb-3b40a211e994',
#    '197d0181-a205-41e1-826d-c8e407958492',
#    '97b3d55b-48a1-402b-819f-321b276b2c01',
#    '70bf8fdd-2187-4dc4-a7cb-5402cb314046',
#    'b5d57e28-94cb-4aa7-b5db-7a4f661a7ae5',
#    '2436a3e7-2d39-4211-84f1-4c3bc740cb00',
#    '7fb45b55-bbd3-4b93-b475-607887b0678d',
#    'fc745ab4-30e2-4b0d-aa0c-a890a9b5d169',
#    '9d24d253-684c-4821-8e65-fe3f7bfadd8e'],
#   'price': 38,
#   'price-title': '1000/38',
#   'price_info': [[1000, 38], [500, 43], [300, 45]],
#   'price_title': '1000/38',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 8,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.799999999999997,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 19.8m² | 관리비 10만원',
#   'room_floor': None,
#   'room_options': [0, 1, 4, 5, 6, 7, 9, 11],
#   'room_size': 19.799999999999997,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2015-06-15T15:01:00.000Z',
#   'saved_time': '2015-06-15T15:01:00.000Z',
#   'selling_type': 0,
#   'seq': 112488,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '저보증금 원룸',
#   'user_id': 'one5001@naver.com',
#   'view_count': 707},
#  {'_id': '56cff09b1f0b5452f563912d',
#   'actived_time': '2016-02-28T07:24:59.172Z',
#   'address': '서울특별시 양천구 신월동',
#   'agent_id': '56c2b62eae70795f6f08de12',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 16500,
#   'favorite_count': 0,
#   'floor': '5층',
#   'hash_tags': ['#전세가능', '#주차'],
#   'heating': None,
#   'id': '56cff09b1f0b5452f563912d',
#   'is_pano': False,
#   'location': [126.84216338088972, 37.52136616295026],
#   'maintenance_cost': 2.0,
#   'maintenance_items_str': [],
#   'name': '우언임',
#   'options': ['가스레인지', '전자도어락', '신발장'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'aaeec1c2-fd58-465f-a950-27b780e12827'},
#    {'desc': '', 'key': 'd4a2016b-2d4d-4222-8d5e-365f3ddc1c82'},
#    {'desc': '', 'key': '7f8c8133-5997-4995-9e92-567329e2acef'},
#    {'desc': '', 'key': '38eb5b2e-d99c-425d-ace0-603f6224f2ab'},
#    {'desc': '', 'key': 'a63b6695-8232-40aa-a5e3-61118e2c8c7a'},
#    {'desc': '', 'key': '3a34720a-8278-4cbd-99ca-79db16bc6aea'},
#    {'desc': '', 'key': '0a3f1b90-221c-42f8-964b-f1fa879b6f21'},
#    {'desc': '', 'key': '9be88448-d2f1-43ed-8b83-11c5fd7dd408'},
#    {'desc': '', 'key': '417b598d-076d-40a3-a716-dd86d5c84d43'},
#    {'desc': '', 'key': '787d222c-e9cf-4992-9267-6056dfe81091'},
#    {'desc': '', 'key': '76922943-76f1-4d4a-b1b2-f699d740a299'},
#    {'desc': '', 'key': '00a0c3f4-2e6e-4e03-aa58-6ecd0c3f72be'},
#    {'desc': '', 'key': '052e4bf0-2061-448d-beb8-9829a37cc5ba'}],
#   'photos': ['aaeec1c2-fd58-465f-a950-27b780e12827',
#    'd4a2016b-2d4d-4222-8d5e-365f3ddc1c82',
#    '7f8c8133-5997-4995-9e92-567329e2acef',
#    '38eb5b2e-d99c-425d-ace0-603f6224f2ab',
#    'a63b6695-8232-40aa-a5e3-61118e2c8c7a',
#    '3a34720a-8278-4cbd-99ca-79db16bc6aea',
#    '0a3f1b90-221c-42f8-964b-f1fa879b6f21',
#    '9be88448-d2f1-43ed-8b83-11c5fd7dd408',
#    '417b598d-076d-40a3-a716-dd86d5c84d43',
#    '787d222c-e9cf-4992-9267-6056dfe81091',
#    '76922943-76f1-4d4a-b1b2-f699d740a299',
#    '00a0c3f4-2e6e-4e03-aa58-6ecd0c3f72be',
#    '052e4bf0-2061-448d-beb8-9829a37cc5ba'],
#   'price': 0,
#   'price-title': '1억6500',
#   'price_info': [[16500, 0]],
#   'price_title': '1억6500',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 26,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 30.0,
#   'room-title': '쓰리룸 전세',
#   'room_desc': '쓰리룸 | 5층 | 30m² | 관리비 2만원',
#   'room_floor': 5,
#   'room_options': [8, 11, 6],
#   'room_size': 30.0,
#   'room_title': '쓰리룸 전세',
#   'room_type': 2,
#   'room_type_str': '쓰리룸',
#   'saved-time': '2016-02-26T06:28:43.777Z',
#   'saved_time': '2016-02-26T06:28:43.777Z',
#   'selling_type': 1,
#   'seq': 774502,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개', '전세가능'],
#   'title': '## 신축 쓰리룸전세 16500만원 ##',
#   'user_id': 'gnfmfmr1@naver.com',
#   'view_count': 62},
#  {'_id': '562f0fb9cf50b354be25899c',
#   'actived_time': '2016-02-04T02:16:43.884Z',
#   'address': '서울특별시 영등포구 당산동4가',
#   'agent_id': '54b759fde4b0874b0aa12f67',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 500,
#   'favorite_count': 2,
#   'floor': '5층',
#   'hash_tags': ['#주차'],
#   'heating': None,
#   'id': '562f0fb9cf50b354be25899c',
#   'is_pano': False,
#   'location': [126.89861487865167, 37.528643335202894],
#   'maintenance_cost': 10.0,
#   'maintenance_items_str': [],
#   'name': '신한인',
#   'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자레인지', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '92b7866b-f29e-4744-b0fb-6f041a5aad0b'},
#    {'desc': '', 'key': 'a060a467-3423-4c99-9a4e-3af0f67ad444'},
#    {'desc': '', 'key': '154e125f-ed84-45ae-a9a8-979de47eeebd'},
#    {'desc': '', 'key': '938b6b13-6354-4988-b719-267d3e542c88'},
#    {'desc': '', 'key': 'c9e466cc-b943-4c54-8bce-66a2d178baee'},
#    {'desc': '', 'key': '84e4a9b2-1415-4c9c-9a3a-7108b3080ad6'},
#    {'desc': '', 'key': 'a5180614-ac99-4a91-a6d9-d0a89577757d'},
#    {'desc': '', 'key': '291137dd-8ed6-48ab-adc4-de2609d6177e'},
#    {'desc': '', 'key': 'd00272ad-a530-4291-910d-a3c144486278'},
#    {'desc': '', 'key': 'acdcc92d-fc57-43a5-b121-867ce0d3e3ab'}],
#   'photos': ['92b7866b-f29e-4744-b0fb-6f041a5aad0b',
#    'a060a467-3423-4c99-9a4e-3af0f67ad444',
#    '154e125f-ed84-45ae-a9a8-979de47eeebd',
#    '938b6b13-6354-4988-b719-267d3e542c88',
#    'c9e466cc-b943-4c54-8bce-66a2d178baee',
#    '84e4a9b2-1415-4c9c-9a3a-7108b3080ad6',
#    'a5180614-ac99-4a91-a6d9-d0a89577757d',
#    '291137dd-8ed6-48ab-adc4-de2609d6177e',
#    'd00272ad-a530-4291-910d-a3c144486278',
#    'acdcc92d-fc57-43a5-b121-867ce0d3e3ab'],
#   'price': 45,
#   'price-title': '500/45',
#   'price_info': [[500, 45], [1000, 40]],
#   'price_title': '500/45',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 2,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 5층 | 19.8m² | 관리비 10만원',
#   'room_floor': 5,
#   'room_options': [0, 1, 3, 4, 6, 7, 9, 10, 11],
#   'room_size': 19.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2015-10-27T05:46:33.574Z',
#   'saved_time': '2015-10-27T05:46:33.574Z',
#   'selling_type': 0,
#   'seq': 513529,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '▣당산역 영등포구청역 트리플역세권 최강원룸',
#   'user_id': 'vkarin@naver.com',
#   'view_count': 367},
#  {'_id': '56c6e76264fe9f33158673ef',
#   'actived_time': '2016-02-19T09:58:58.003Z',
#   'address': '인천광역시 부평구 부평동',
#   'agent_id': '568b77743254797eb5abd780',
#   'animal': True,
#   'building_floor_str': '',
#   'deposit': 300,
#   'favorite_count': 4,
#   'floor': '반지층',
#   'hash_tags': ['#주차', '#반려동물'],
#   'heating': None,
#   'id': '56c6e76264fe9f33158673ef',
#   'is_pano': False,
#   'location': [126.72302889141767, 37.50526041554956],
#   'maintenance_cost': None,
#   'maintenance_items_str': [],
#   'name': '류승현',
#   'options': ['세탁기'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '28a12561-a4e8-4d45-807e-2bdd99c20f94'},
#    {'desc': '', 'key': 'c35cc885-52c7-44a6-ac05-b757450799b5'},
#    {'desc': '', 'key': '2670cc82-31d4-4f37-be99-31d404d29e14'},
#    {'desc': '', 'key': '95659ba9-7bcb-43eb-9561-c2fdd332e5b7'},
#    {'desc': '', 'key': 'b299a308-4af1-4a27-a1a8-7a9ceaefe456'}],
#   'photos': ['28a12561-a4e8-4d45-807e-2bdd99c20f94',
#    'c35cc885-52c7-44a6-ac05-b757450799b5',
#    '2670cc82-31d4-4f37-be99-31d404d29e14',
#    '95659ba9-7bcb-43eb-9561-c2fdd332e5b7',
#    'b299a308-4af1-4a27-a1a8-7a9ceaefe456'],
#   'price': 25,
#   'price-title': '300/25',
#   'price_info': [[300, 25]],
#   'price_title': '300/25',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 17,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 39.6,
#   'room-title': '투룸 월세',
#   'room_desc': '투룸 | 반지층 | 39.6m²',
#   'room_floor': -1,
#   'room_options': [1],
#   'room_size': 39.6,
#   'room_title': '투룸 월세',
#   'room_type': 1,
#   'room_type_str': '투룸',
#   'saved-time': '2016-02-19T09:58:58.003Z',
#   'saved_time': '2016-02-19T09:58:58.003Z',
#   'selling_type': 0,
#   'seq': 758880,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '큰방1,작은방,거실,욕실,베란다, 깨끗하고 널직해요',
#   'user_id': 'ryu9955@hanmail.net',
#   'view_count': 325},
#  {'_id': '56a9d3731fbfe8301a283a3f',
#   'actived_time': '2016-02-19T09:02:53.655Z',
#   'address': '서울특별시 강서구 화곡동',
#   'agent_id': '55c9b653e6e9e635d2c70c01',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 1000,
#   'favorite_count': 3,
#   'floor': '5층',
#   'hash_tags': ['#주차'],
#   'heating': None,
#   'id': '56a9d3731fbfe8301a283a3f',
#   'is_pano': False,
#   'location': [126.84785005321181, 37.54640701271922],
#   'maintenance_cost': 4.0,
#   'maintenance_items_str': [],
#   'name': '이부형',
#   'options': ['에어컨', '세탁기', '신발장', '냉장고', '인덕션'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'a8a24c2e-e920-4daa-8387-648ecfbc649d'},
#    {'desc': '', 'key': '97d01eea-dc6e-4b1a-83e4-619860173a84'},
#    {'desc': '', 'key': '94b83a11-0c1f-4376-9763-726b8141b013'},
#    {'desc': '', 'key': 'e9fd2aef-f512-4fdd-9b08-17ff3e566a9c'},
#    {'desc': '', 'key': '8fb10555-3d05-4c0a-b57f-db7f54ddacbd'},
#    {'desc': '', 'key': 'fc5acb30-52dd-4f86-b38f-3bbd44c7724a'},
#    {'desc': '', 'key': '3fc03da0-baa1-425d-908d-e07149fbf060'},
#    {'desc': '', 'key': '9cf7a48e-fb81-445c-929f-2e74185ef1e8'},
#    {'desc': '', 'key': 'c3bbf41a-f3bc-42d5-acec-a55cfb039709'},
#    {'desc': '', 'key': '499d8905-7b52-4f12-b8f3-bb11e5052cb7'}],
#   'photos': ['a8a24c2e-e920-4daa-8387-648ecfbc649d',
#    '97d01eea-dc6e-4b1a-83e4-619860173a84',
#    '94b83a11-0c1f-4376-9763-726b8141b013',
#    'e9fd2aef-f512-4fdd-9b08-17ff3e566a9c',
#    '8fb10555-3d05-4c0a-b57f-db7f54ddacbd',
#    'fc5acb30-52dd-4f86-b38f-3bbd44c7724a',
#    '3fc03da0-baa1-425d-908d-e07149fbf060',
#    '9cf7a48e-fb81-445c-929f-2e74185ef1e8',
#    'c3bbf41a-f3bc-42d5-acec-a55cfb039709',
#    '499d8905-7b52-4f12-b8f3-bb11e5052cb7'],
#   'price': 41,
#   'price-title': '1000/41',
#   'price_info': [[1000, 41], [500, 45]],
#   'price_title': '1000/41',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 17,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 29.7,
#   'room-title': '오피스텔 월세',
#   'room_desc': '오피스텔 | 5층 | 29.7m² | 관리비 4만원',
#   'room_floor': 5,
#   'room_options': [0, 1, 6, 7, 9],
#   'room_size': 29.7,
#   'room_title': '오피스텔 월세',
#   'room_type': 3,
#   'room_type_str': '오피스텔',
#   'saved-time': '2016-01-28T08:38:11.349Z',
#   'saved_time': '2016-01-28T08:38:11.349Z',
#   'selling_type': 0,
#   'seq': 705935,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '★☆화곡 큰방,베란다월세특가★☆',
#   'user_id': 'smart3008@naver.com',
#   'view_count': 210},
#  {'_id': '56a2109fdc35ca6557db282b',
#   'actived_time': '2016-03-01T07:37:13.322Z',
#   'address': '서울특별시 강서구 화곡동',
#   'agent_id': '543f826ce4b0b8e5b3d73ad9',
#   'animal': True,
#   'building_floor_str': '',
#   'deposit': 100,
#   'favorite_count': 2,
#   'floor': '9층',
#   'hash_tags': ['#주차', '#반려동물'],
#   'heating': None,
#   'id': '56a2109fdc35ca6557db282b',
#   'is_pano': False,
#   'location': [126.85289873143152, 37.55472421211303],
#   'maintenance_cost': 6.0,
#   'maintenance_items_str': [],
#   'name': '김미란',
#   'options': ['에어컨', '전자레인지', '비데', '세탁기', '옷장', '신발장', '냉장고', '인덕션'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '536da1a7-447a-48e7-8f36-702756ca8275'},
#    {'desc': '', 'key': '6463ed72-c869-46f6-a7e5-9f97d8c78d0e'},
#    {'desc': '', 'key': '861f7ca7-cc85-4629-b4a3-de9720cc9ae5'},
#    {'desc': '', 'key': '534a556c-cf3e-47b9-80d9-a0a923b90f54'},
#    {'desc': '', 'key': '9e5c2a1e-d436-40aa-b96e-b3c061d82f32'},
#    {'desc': '', 'key': '245b1c0b-f10b-487c-9a3f-0ad9de4267b4'},
#    {'desc': '', 'key': 'd2375c1e-e153-4f57-b843-0172618b2417'},
#    {'desc': '', 'key': '3c1c799f-a26f-4a17-8e92-c91eb51b2939'},
#    {'desc': '', 'key': 'bb9ca2b3-eca4-4ad0-8c58-71a353306769'},
#    {'desc': '', 'key': '9f36f716-dda7-4f24-8ee9-1ba18880a968'},
#    {'desc': '', 'key': '39545ef3-1e00-4811-9d14-c8e15cf44231'},
#    {'desc': '', 'key': '5e47a956-3902-4599-bc74-815a3ac9eb11'},
#    {'desc': '', 'key': 'f77d1491-6d96-4b4c-acd0-5164fafd92c7'},
#    {'desc': '', 'key': '28367d7d-dbe7-429c-ba0f-178cc0fcc5fd'},
#    {'desc': '', 'key': '21aafdd1-a05d-4cfd-9634-0f16ccdbddc0'},
#    {'desc': '', 'key': 'd7b4fcf8-203f-4ce8-b1a5-2beb8202b969'},
#    {'desc': '', 'key': '3441884d-6e38-46ec-a0b3-7c21c4821b02'},
#    {'desc': '', 'key': '74681daf-739c-4004-8bf1-a639a2f19723'},
#    {'desc': '', 'key': '8f2cdba6-400f-4449-9c4f-c6030b55f42e'},
#    {'desc': '', 'key': '07e6e2f4-fe96-4519-aab3-1a18d2ff864d'},
#    {'desc': '', 'key': '7099afbd-501c-4f84-b1c9-de3618fe30b2'},
#    {'desc': '', 'key': '13001b3a-6fda-4f37-88ce-43358a6608b9'},
#    {'desc': '', 'key': '6d1a2042-6518-4652-a64d-40de4b97297b'}],
#   'photos': ['536da1a7-447a-48e7-8f36-702756ca8275',
#    '6463ed72-c869-46f6-a7e5-9f97d8c78d0e',
#    '861f7ca7-cc85-4629-b4a3-de9720cc9ae5',
#    '534a556c-cf3e-47b9-80d9-a0a923b90f54',
#    '9e5c2a1e-d436-40aa-b96e-b3c061d82f32',
#    '245b1c0b-f10b-487c-9a3f-0ad9de4267b4',
#    'd2375c1e-e153-4f57-b843-0172618b2417',
#    '3c1c799f-a26f-4a17-8e92-c91eb51b2939',
#    'bb9ca2b3-eca4-4ad0-8c58-71a353306769',
#    '9f36f716-dda7-4f24-8ee9-1ba18880a968',
#    '39545ef3-1e00-4811-9d14-c8e15cf44231',
#    '5e47a956-3902-4599-bc74-815a3ac9eb11',
#    'f77d1491-6d96-4b4c-acd0-5164fafd92c7',
#    '28367d7d-dbe7-429c-ba0f-178cc0fcc5fd',
#    '21aafdd1-a05d-4cfd-9634-0f16ccdbddc0',
#    'd7b4fcf8-203f-4ce8-b1a5-2beb8202b969',
#    '3441884d-6e38-46ec-a0b3-7c21c4821b02',
#    '74681daf-739c-4004-8bf1-a639a2f19723',
#    '8f2cdba6-400f-4449-9c4f-c6030b55f42e',
#    '07e6e2f4-fe96-4519-aab3-1a18d2ff864d',
#    '7099afbd-501c-4f84-b1c9-de3618fe30b2',
#    '13001b3a-6fda-4f37-88ce-43358a6608b9',
#    '6d1a2042-6518-4652-a64d-40de4b97297b'],
#   'price': 60,
#   'price-title': '100/60',
#   'price_info': [[100, 60]],
#   'price_title': '100/60',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 28,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 16.5,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 9층 | 16.5m² | 관리비 6만원',
#   'room_floor': 9,
#   'room_options': [0, 10, 12, 1, 4, 6, 7, 9],
#   'room_size': 16.5,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2016-01-22T11:21:03.006Z',
#   'saved_time': '2016-01-22T11:21:03.006Z',
#   'selling_type': 0,
#   'seq': 691251,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '[인기단기]동도센트리움 단기가능',
#   'user_id': 'alfkslek31@nate.com',
#   'view_count': 67},
#  {'_id': '560094849c3fdb4c22578341',
#   'actived_time': '2016-02-10T01:02:33.584Z',
#   'address': '서울특별시 강서구 화곡1동',
#   'agent_id': '534232b3e4b0d61b62710d88',
#   'animal': True,
#   'building_floor_str': '',
#   'deposit': 1000,
#   'favorite_count': 8,
#   'floor': '11층',
#   'hash_tags': ['#주차', '#반려동물'],
#   'heating': None,
#   'id': '560094849c3fdb4c22578341',
#   'is_pano': False,
#   'location': [126.84223081228792, 37.530170837698],
#   'maintenance_cost': 5.0,
#   'maintenance_items_str': [],
#   'name': '이연진',
#   'options': ['에어컨', '세탁기', '옷장', '신발장', '냉장고', '인덕션', '전자레인지', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'b86f17e9-7004-4d2b-8631-fb71277b2877'},
#    {'desc': '', 'key': '88e53167-4835-4767-8b3f-3748b6b52147'},
#    {'desc': '', 'key': 'ef3d05ab-e772-4544-bc60-257b961ae65d'},
#    {'desc': '', 'key': 'c1f937f6-b92b-46a2-99fb-3f333c6132e5'},
#    {'desc': '', 'key': '77f23f3e-caa6-48a4-af3e-8cee73d1fc61'},
#    {'desc': '', 'key': 'ac98f075-7fdb-4de3-a374-6732e975a514'},
#    {'desc': '', 'key': '3abeecc3-adaf-4880-92ff-e8f6a57076b0'},
#    {'desc': '', 'key': '19606f0b-6619-4908-b713-12b194b4b5ca'},
#    {'desc': '', 'key': '88337e7a-4b0b-4c2f-82f6-7a0e05c1a837'},
#    {'desc': '', 'key': '9662fe7e-9f44-4029-95bb-09b065423a53'}],
#   'photos': ['b86f17e9-7004-4d2b-8631-fb71277b2877',
#    '88e53167-4835-4767-8b3f-3748b6b52147',
#    'ef3d05ab-e772-4544-bc60-257b961ae65d',
#    'c1f937f6-b92b-46a2-99fb-3f333c6132e5',
#    '77f23f3e-caa6-48a4-af3e-8cee73d1fc61',
#    'ac98f075-7fdb-4de3-a374-6732e975a514',
#    '3abeecc3-adaf-4880-92ff-e8f6a57076b0',
#    '19606f0b-6619-4908-b713-12b194b4b5ca',
#    '88337e7a-4b0b-4c2f-82f6-7a0e05c1a837',
#    '9662fe7e-9f44-4029-95bb-09b065423a53'],
#   'price': 45,
#   'price-title': '1000/45',
#   'price_info': [[1000, 45], [1500, 40], [2000, 35], [500, 50], [300, 52]],
#   'price_title': '1000/45',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 8,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 26.4,
#   'room-title': '오피스텔 월세',
#   'room_desc': '오피스텔 | 11층 | 26.4m² | 관리비 5만원',
#   'room_floor': 11,
#   'room_options': [0, 1, 4, 6, 7, 9, 10, 11],
#   'room_size': 26.4,
#   'room_title': '오피스텔 월세',
#   'room_type': 3,
#   'room_type_str': '오피스텔',
#   'saved-time': '2015-09-21T23:36:36.301Z',
#   'saved_time': '2015-09-21T23:36:36.301Z',
#   'selling_type': 0,
#   'seq': 468950,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '❤❤남서향으로 창이 나있어 하루종일 햇살 쨍쨍 / 분리형이라 넘 좋은 신축원룸 / 즉시입주가능',
#   'user_id': 'kkasang@hanmail.net',
#   'view_count': 566},
#  {'_id': '5630946022f9d15b283cf933',
#   'actived_time': '2016-02-16T06:23:26.584Z',
#   'address': '서울특별시 강서구 화곡동 ',
#   'agent_id': '54043e50e4b091303d795de8',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 500,
#   'favorite_count': 6,
#   'floor': '12층',
#   'hash_tags': [],
#   'heating': None,
#   'id': '5630946022f9d15b283cf933',
#   'is_pano': False,
#   'location': [126.84176750649755, 37.52884034079881],
#   'maintenance_cost': 5.0,
#   'maintenance_items_str': [],
#   'name': '윤경섭',
#   'options': ['에어컨', '세탁기', '옷장', 'TV', '신발장', '냉장고', '인덕션', '전자도어락'],
#   'pano': None,
#   'parking': False,
#   'photo': [{'desc': '', 'key': 'a2cb8c37-0ede-4e29-b5c5-3c39ddfdf777'},
#    {'desc': '', 'key': 'e46dcce5-ab4f-443a-b7b9-b520d12188ea'},
#    {'desc': '', 'key': 'cd8409f8-bc62-49b2-8871-5a81ffce5ab1'},
#    {'desc': '', 'key': 'c76c868e-e768-41c8-bc70-0547eb5af79d'},
#    {'desc': '', 'key': '47fd91de-0124-4f8f-a0d3-fbeda122f294'},
#    {'desc': '', 'key': 'd19c550b-0bc2-42d7-ba8c-96e1c1af5b0e'},
#    {'desc': '', 'key': '8d414710-5cbc-4515-95aa-a816d4537cd0'},
#    {'desc': '', 'key': '88de878e-1b95-4f76-9825-13db9c87dd20'},
#    {'desc': '', 'key': 'bcfe433c-4cdf-4f56-8bca-946b5675efd7'},
#    {'desc': '', 'key': '521ed850-95e2-4381-a914-c05b16b6c7fb'},
#    {'desc': '', 'key': '232b7e05-304e-43a7-8e24-4fc4d0f47cca'},
#    {'desc': '', 'key': '0434486f-2e37-41e1-a6ba-382d200e0ade'},
#    {'desc': '', 'key': '0784ff3f-ded5-42bf-812f-b238b1f36b26'},
#    {'desc': '', 'key': '5b129b8d-8a74-4e62-9903-536d6bbcd419'}],
#   'photos': ['a2cb8c37-0ede-4e29-b5c5-3c39ddfdf777',
#    'e46dcce5-ab4f-443a-b7b9-b520d12188ea',
#    'cd8409f8-bc62-49b2-8871-5a81ffce5ab1',
#    'c76c868e-e768-41c8-bc70-0547eb5af79d',
#    '47fd91de-0124-4f8f-a0d3-fbeda122f294',
#    'd19c550b-0bc2-42d7-ba8c-96e1c1af5b0e',
#    '8d414710-5cbc-4515-95aa-a816d4537cd0',
#    '88de878e-1b95-4f76-9825-13db9c87dd20',
#    'bcfe433c-4cdf-4f56-8bca-946b5675efd7',
#    '521ed850-95e2-4381-a914-c05b16b6c7fb',
#    '232b7e05-304e-43a7-8e24-4fc4d0f47cca',
#    '0434486f-2e37-41e1-a6ba-382d200e0ade',
#    '0784ff3f-ded5-42bf-812f-b238b1f36b26',
#    '5b129b8d-8a74-4e62-9903-536d6bbcd419'],
#   'price': 40,
#   'price-title': '500/40',
#   'price_info': [[500, 40], [300, 42], [1000, 36], [1500, 31]],
#   'price_title': '500/40',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 14,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 12층 | 19.8m² | 관리비 5만원',
#   'room_floor': 12,
#   'room_options': [0, 1, 4, 5, 6, 7, 9, 11],
#   'room_size': 19.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2015-10-28T09:24:48.916Z',
#   'saved_time': '2015-10-28T09:24:48.916Z',
#   'selling_type': 0,
#   'seq': 515963,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '% 예쁘고 착한 월세의 원룸, 여성분께 강력 추천~!!%',
#   'user_id': 'sep70@hanmail.net',
#   'view_count': 561},
#  {'_id': '56d3c6d23f2d69548c8e6594',
#   'actived_time': '2016-03-01T02:36:23.904Z',
#   'address': '서울특별시 강서구 화곡동',
#   'agent_id': '55e901b7a0e57c6312354c04',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 4000,
#   'favorite_count': 0,
#   'floor': '8층',
#   'hash_tags': ['#주차'],
#   'heating': None,
#   'id': '56d3c6d23f2d69548c8e6594',
#   'is_pano': False,
#   'location': [126.84231024765259, 37.528981622846544],
#   'maintenance_cost': 12.0,
#   'maintenance_items_str': [],
#   'name': '전재용',
#   'options': ['에어컨', '세탁기', '신발장', '냉장고', '인덕션', '전자도어락', '옷장'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '6e0bbadd-2541-46dc-86b4-50684a9e7022'},
#    {'desc': '', 'key': 'c35407b7-1d5f-46a2-acb1-29fd250f3f7f'},
#    {'desc': '', 'key': '864cc661-92da-489d-95dd-66a497beaf0b'},
#    {'desc': '', 'key': 'dcebb313-0a32-4a73-ac85-1c01ec0e0a18'},
#    {'desc': '', 'key': '9e7ce0fe-5fad-4436-b85c-ce8e41d7d8b0'},
#    {'desc': '', 'key': 'bb1566a5-7886-489f-baa1-f026495d7b89'},
#    {'desc': '', 'key': 'ebc44028-bac2-4799-a02e-7efde34f2b3f'},
#    {'desc': '', 'key': '2ac1d29c-5683-44b7-992b-188e275b55e5'},
#    {'desc': '', 'key': 'c8ca1661-68ab-4368-aac6-e8953cee9131'},
#    {'desc': '', 'key': 'c0fbf30b-7501-4944-b8dc-5986650e3d49'},
#    {'desc': '', 'key': '60625754-53f0-4784-aeef-973b3ecb82c6'},
#    {'desc': '', 'key': '4cee90cd-d99b-415d-93ad-0b0c4f9df307'},
#    {'desc': '', 'key': '6e5573ae-6b46-41d5-a94c-22045a501b59'},
#    {'desc': '', 'key': '33557757-a1d7-44dd-b69d-5ba8875a4422'},
#    {'desc': '', 'key': 'fb9256f6-6903-422b-a056-79042c871e19'},
#    {'desc': '', 'key': 'c1a0d698-99e6-43a9-8bae-a32cd29863a8'},
#    {'desc': '', 'key': 'b0d11764-79a4-4b1f-b9f7-c5f60c235a0a'}],
#   'photos': ['6e0bbadd-2541-46dc-86b4-50684a9e7022',
#    'c35407b7-1d5f-46a2-acb1-29fd250f3f7f',
#    '864cc661-92da-489d-95dd-66a497beaf0b',
#    'dcebb313-0a32-4a73-ac85-1c01ec0e0a18',
#    '9e7ce0fe-5fad-4436-b85c-ce8e41d7d8b0',
#    'bb1566a5-7886-489f-baa1-f026495d7b89',
#    'ebc44028-bac2-4799-a02e-7efde34f2b3f',
#    '2ac1d29c-5683-44b7-992b-188e275b55e5',
#    'c8ca1661-68ab-4368-aac6-e8953cee9131',
#    'c0fbf30b-7501-4944-b8dc-5986650e3d49',
#    '60625754-53f0-4784-aeef-973b3ecb82c6',
#    '4cee90cd-d99b-415d-93ad-0b0c4f9df307',
#    '6e5573ae-6b46-41d5-a94c-22045a501b59',
#    '33557757-a1d7-44dd-b69d-5ba8875a4422',
#    'fb9256f6-6903-422b-a056-79042c871e19',
#    'c1a0d698-99e6-43a9-8bae-a32cd29863a8',
#    'b0d11764-79a4-4b1f-b9f7-c5f60c235a0a'],
#   'price': 15,
#   'price-title': '4000/15',
#   'price_info': [[4000, 15], [3000, 25], [2000, 35], [1000, 45], [500, 50]],
#   'price_title': '4000/15',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 28,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 8층 | 19.8m² | 관리비 12만원',
#   'room_floor': 8,
#   'room_options': [0, 1, 6, 7, 9, 11, 4],
#   'room_size': 19.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2016-02-29T04:19:30.713Z',
#   'saved_time': '2016-02-29T04:19:30.713Z',
#   'selling_type': 0,
#   'seq': 779626,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '🌺임대료 반전세이상 방좋아서 금방나가는 방~~!! ',
#   'user_id': 'goodjun09@daum.net',
#   'view_count': 18},
#  {'_id': '56d68b4cd0e1fa4c98840512',
#   'actived_time': '2016-03-02T06:42:20.055Z',
#   'address': '서울특별시 영등포구 문래동',
#   'agent_id': '559651af5bf46179b869fa02',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 8300,
#   'favorite_count': 0,
#   'floor': '7층',
#   'hash_tags': ['#전세가능', '#주차'],
#   'heating': None,
#   'id': '56d68b4cd0e1fa4c98840512',
#   'is_pano': False,
#   'location': [126.88871809168899, 37.516409626185805],
#   'maintenance_cost': 13.0,
#   'maintenance_items_str': [],
#   'name': '진영훈',
#   'options': ['에어컨', '세탁기', '책상', '신발장', '냉장고', '인덕션', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '98c3b29d-d108-4950-9654-fa72c6ad1b82'},
#    {'desc': '', 'key': 'c0c3af23-d942-4fe8-ac35-ddb79416cc74'},
#    {'desc': '', 'key': '3136e1bf-b952-45fb-8fb7-ccd805b49d2f'},
#    {'desc': '', 'key': 'e10eda14-5e43-4f14-8f1c-96dd22e62390'},
#    {'desc': '', 'key': '8fa3849f-1da5-4139-b33e-130062916f1d'},
#    {'desc': '', 'key': '5493da1b-ba92-4d67-9a74-0ed206b14517'},
#    {'desc': '', 'key': '48d60c59-d033-4277-be7c-65d90905ab9d'},
#    {'desc': '', 'key': '70b86582-678d-4902-8959-14b681096a31'},
#    {'desc': '', 'key': '8555d5f9-3444-4a2a-ac2d-39eedea7da81'},
#    {'desc': '', 'key': 'f8147818-3743-4835-b476-d2422ed6d493'}],
#   'photos': ['98c3b29d-d108-4950-9654-fa72c6ad1b82',
#    'c0c3af23-d942-4fe8-ac35-ddb79416cc74',
#    '3136e1bf-b952-45fb-8fb7-ccd805b49d2f',
#    'e10eda14-5e43-4f14-8f1c-96dd22e62390',
#    '8fa3849f-1da5-4139-b33e-130062916f1d',
#    '5493da1b-ba92-4d67-9a74-0ed206b14517',
#    '48d60c59-d033-4277-be7c-65d90905ab9d',
#    '70b86582-678d-4902-8959-14b681096a31',
#    '8555d5f9-3444-4a2a-ac2d-39eedea7da81',
#    'f8147818-3743-4835-b476-d2422ed6d493'],
#   'price': 0,
#   'price-title': '8300',
#   'price_info': [[8300, 0]],
#   'price_title': '8300',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 29,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 전세',
#   'room_desc': '원룸 | 7층 | 19.8m² | 관리비 13만원',
#   'room_floor': 7,
#   'room_options': [0, 1, 3, 6, 7, 9, 11],
#   'room_size': 19.8,
#   'room_title': '원룸 전세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2016-03-02T06:42:20.055Z',
#   'saved_time': '2016-03-02T06:42:20.055Z',
#   'selling_type': 1,
#   'seq': 785374,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개', '전세가능'],
#   'title': '★☆★ 2호선 인접 귀한전세 가성비 최고 ★☆★',
#   'user_id': 'sksqorkek3@naver.com',
#   'view_count': 7},
#  {'_id': '56beef9201d49c2506f180ef',
#   'actived_time': '2016-02-13T08:55:46.333Z',
#   'address': '서울특별시 마포구 망원2동',
#   'agent_id': None,
#   'animal': True,
#   'building_floor_str': '',
#   'deposit': 1000,
#   'favorite_count': 11,
#   'floor': '2층',
#   'hash_tags': ['#직거래', '#반려동물'],
#   'heating': None,
#   'id': '56beef9201d49c2506f180ef',
#   'is_pano': False,
#   'location': [126.90511941589087, 37.559473719994244],
#   'maintenance_cost': None,
#   'maintenance_items_str': [],
#   'name': '박상돈',
#   'options': [],
#   'pano': None,
#   'parking': False,
#   'photo': [{'desc': '', 'key': '174F755A-D0E2-4E61-932C-5E781264E7F6'},
#    {'desc': '', 'key': '5CF921C4-9F1E-4B0A-9BF6-32DBFD198FE9'},
#    {'desc': '', 'key': '872F639D-063B-482F-902C-DDCC4F61BF22'},
#    {'desc': '', 'key': '32EE1D23-3612-43B1-8D19-7F1F0A31CC94'},
#    {'desc': '', 'key': '4B1476EB-2C70-4FDA-BBE1-B7490FF22125'}],
#   'photos': ['174F755A-D0E2-4E61-932C-5E781264E7F6',
#    '5CF921C4-9F1E-4B0A-9BF6-32DBFD198FE9',
#    '872F639D-063B-482F-902C-DDCC4F61BF22',
#    '32EE1D23-3612-43B1-8D19-7F1F0A31CC94',
#    '4B1476EB-2C70-4FDA-BBE1-B7490FF22125'],
#   'price': 50,
#   'price-title': '1000/50',
#   'price_info': [[1000, 50]],
#   'price_title': '1000/50',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 11,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 23.1,
#   'room-title': '투룸 월세',
#   'room_desc': '투룸 | 2층 | 23.1m²',
#   'room_floor': 2,
#   'room_options': [],
#   'room_size': 23.1,
#   'room_title': '투룸 월세',
#   'room_type': 1,
#   'room_type_str': '투룸',
#   'saved-time': '2016-02-13T08:55:46.333Z',
#   'saved_time': '2016-02-13T08:55:46.333Z',
#   'selling_type': 0,
#   'seq': 742283,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['직거래'],
#   'title': '마포구청역 도보 7분거리, 월드컵시장 2분거리, 단독주택 2층',
#   'user_id': 'justlanded@hanmail.net',
#   'view_count': 706},
#  {'_id': '56d68470cfd0894ca6e2f047',
#   'actived_time': '2016-03-02T06:13:04.545Z',
#   'address': '서울특별시 강서구 화곡동',
#   'agent_id': '559b8a3cecfe885880050524',
#   'animal': True,
#   'building_floor_str': '',
#   'deposit': 17000,
#   'favorite_count': 0,
#   'floor': '5층',
#   'hash_tags': ['#전세가능', '#주차', '#반려동물'],
#   'heating': None,
#   'id': '56d68470cfd0894ca6e2f047',
#   'is_pano': False,
#   'location': [126.8453828208944, 37.54000311337067],
#   'maintenance_cost': None,
#   'maintenance_items_str': [],
#   'name': '박오배',
#   'options': ['가스레인지', '신발장', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': '27d052bc-0547-4646-abd0-93c4a8d5ea55'},
#    {'desc': '', 'key': '592b7648-1afa-4803-9512-6827894cd81c'},
#    {'desc': '', 'key': 'd9dabe96-bb07-4ce8-aa32-d84427f46a71'},
#    {'desc': '', 'key': '4b556881-ea7a-43f9-b5f3-b52fe68889a2'},
#    {'desc': '', 'key': 'f1a40296-ec84-4e3c-bd79-7c58221a7e29'},
#    {'desc': '', 'key': '0f9e68bc-e318-4bdb-bb85-d1521e894af1'},
#    {'desc': '', 'key': '807e3768-ccc5-4659-b423-84c5ce8ed222'},
#    {'desc': '', 'key': '9952469f-af1b-4b94-92f6-70294b1db507'},
#    {'desc': '', 'key': '6a0a8497-44e9-4926-9cad-1a3fc30485d2'},
#    {'desc': '', 'key': 'c12ba81d-b0e0-491a-a76d-abb495cf55b1'},
#    {'desc': '', 'key': '645f0675-2295-4e34-b792-a517961f9c29'},
#    {'desc': '', 'key': 'a779fec5-1100-40e8-8581-7580489d123b'},
#    {'desc': '', 'key': 'c15c0c66-c85e-4fe8-8572-b8294a076618'},
#    {'desc': '', 'key': '80a7903d-6fde-4e74-b33f-eedb5ac23548'}],
#   'photos': ['27d052bc-0547-4646-abd0-93c4a8d5ea55',
#    '592b7648-1afa-4803-9512-6827894cd81c',
#    'd9dabe96-bb07-4ce8-aa32-d84427f46a71',
#    '4b556881-ea7a-43f9-b5f3-b52fe68889a2',
#    'f1a40296-ec84-4e3c-bd79-7c58221a7e29',
#    '0f9e68bc-e318-4bdb-bb85-d1521e894af1',
#    '807e3768-ccc5-4659-b423-84c5ce8ed222',
#    '9952469f-af1b-4b94-92f6-70294b1db507',
#    '6a0a8497-44e9-4926-9cad-1a3fc30485d2',
#    'c12ba81d-b0e0-491a-a76d-abb495cf55b1',
#    '645f0675-2295-4e34-b792-a517961f9c29',
#    'a779fec5-1100-40e8-8581-7580489d123b',
#    'c15c0c66-c85e-4fe8-8572-b8294a076618',
#    '80a7903d-6fde-4e74-b33f-eedb5ac23548'],
#   'price': 0,
#   'price-title': '1억7000',
#   'price_info': [[17000, 0]],
#   'price_title': '1억7000',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 29,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 33.0,
#   'room-title': '투룸 전세',
#   'room_desc': '투룸 | 5층 | 33m²',
#   'room_floor': 5,
#   'room_options': [8, 6, 11],
#   'room_size': 33.0,
#   'room_title': '투룸 전세',
#   'room_type': 1,
#   'room_type_str': '투룸',
#   'saved-time': '2016-03-02T06:13:04.545Z',
#   'saved_time': '2016-03-02T06:13:04.545Z',
#   'selling_type': 1,
#   'seq': 785213,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개', '전세가능'],
#   'title': '☆★ 깔끔한 신축빌라 투룸 거실 넓은 투룸!! 화곡역 도보 6~7분거리 ★☆',
#   'user_id': 'coomman@nate.com',
#   'view_count': 6},
#  {'_id': '55e01a9192c7a61d857e1a23',
#   'actived_time': '2016-02-12T03:19:22.384Z',
#   'address': '인천광역시 계양구 계산동',
#   'agent_id': '55adb1b9360ac33f3243751c',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 30,
#   'favorite_count': 4,
#   'floor': '2층',
#   'hash_tags': ['#주차'],
#   'heating': None,
#   'id': '55e01a9192c7a61d857e1a23',
#   'is_pano': False,
#   'location': [126.72505782510741, 37.540411360598384],
#   'maintenance_cost': 5.0,
#   'maintenance_items_str': [],
#   'name': '이정관대리',
#   'options': ['에어컨', '세탁기', '인덕션', '냉장고', '신발장', 'TV'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'b0f46a02-f417-46f5-aaa3-6388c5e107c7'},
#    {'desc': '', 'key': '752f06f4-5c4f-464c-b61d-8fd5462a73eb'},
#    {'desc': '', 'key': 'cfd2f8cd-7d14-42cd-9fbe-51ffce7e3ead'},
#    {'desc': '', 'key': '8f17806c-4a8c-4854-8740-ee6958c26a15'},
#    {'desc': '', 'key': '34bc4257-b9cb-4cad-93f1-fc92258925b6'},
#    {'desc': '', 'key': 'c5c92177-9c1f-48d2-85cf-88a2199ae097'},
#    {'desc': '', 'key': 'f805545a-9a96-4e33-b4ce-b333b0043eef'},
#    {'desc': '', 'key': 'ef02d385-bece-4c88-9253-b9b9bd0406b4'},
#    {'desc': '', 'key': '76c00e62-85ed-449c-adb0-a7d21b150180'}],
#   'photos': ['b0f46a02-f417-46f5-aaa3-6388c5e107c7',
#    '752f06f4-5c4f-464c-b61d-8fd5462a73eb',
#    'cfd2f8cd-7d14-42cd-9fbe-51ffce7e3ead',
#    '8f17806c-4a8c-4854-8740-ee6958c26a15',
#    '34bc4257-b9cb-4cad-93f1-fc92258925b6',
#    'c5c92177-9c1f-48d2-85cf-88a2199ae097',
#    'f805545a-9a96-4e33-b4ce-b333b0043eef',
#    'ef02d385-bece-4c88-9253-b9b9bd0406b4',
#    '76c00e62-85ed-449c-adb0-a7d21b150180'],
#   'price': 30,
#   'price-title': '30/30',
#   'price_info': [[30, 30]],
#   'price_title': '30/30',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 10,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 2층 | 19.8m² | 관리비 5만원',
#   'room_floor': 2,
#   'room_options': [0, 1, 9, 7, 6, 5],
#   'room_size': 19.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2015-08-28T08:23:45.944Z',
#   'saved_time': '2015-08-28T08:23:45.944Z',
#   'selling_type': 0,
#   'seq': 429842,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '계산동 무보증 단기 최저가 30/30만원',
#   'user_id': 'SKYLJK86@hanmail.net',
#   'view_count': 1493},
#  {'_id': '5614d5d4746fd2123c3861f7',
#   'actived_time': '2016-02-29T05:18:16.385Z',
#   'address': '서울특별시 양천구 신월동',
#   'agent_id': '52ff0b3be4b089dec7755b9c',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 1000,
#   'favorite_count': 9,
#   'floor': '4층',
#   'hash_tags': [],
#   'heating': None,
#   'id': '5614d5d4746fd2123c3861f7',
#   'is_pano': False,
#   'location': [126.83683514418396, 37.53080862273996],
#   'maintenance_cost': 5.0,
#   'maintenance_items_str': [],
#   'name': '김갑',
#   'options': ['에어컨', '세탁기', '옷장', '신발장', '냉장고', '인덕션'],
#   'pano': None,
#   'parking': False,
#   'photo': [{'desc': '', 'key': '5deb0ccf-ac0a-47b2-b480-53c0470812ac'},
#    {'desc': '', 'key': '50e3d6e4-a3bb-44e7-ba36-9947c55d69da'},
#    {'desc': '', 'key': '2e0f8f93-d8ff-4187-b4e8-9776351e2a96'},
#    {'desc': '', 'key': '8d084582-a884-469d-92e9-728e4c1f9c7d'}],
#   'photos': ['5deb0ccf-ac0a-47b2-b480-53c0470812ac',
#    '50e3d6e4-a3bb-44e7-ba36-9947c55d69da',
#    '2e0f8f93-d8ff-4187-b4e8-9776351e2a96',
#    '8d084582-a884-469d-92e9-728e4c1f9c7d'],
#   'price': 50,
#   'price-title': '1000/50',
#   'price_info': [[1000, 50]],
#   'price_title': '1000/50',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 27,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 39.6,
#   'room-title': '투룸 월세',
#   'room_desc': '투룸 | 4층 | 39.6m² | 관리비 5만원',
#   'room_floor': 4,
#   'room_options': [0, 1, 4, 6, 7, 9],
#   'room_size': 39.6,
#   'room_title': '투룸 월세',
#   'room_type': 1,
#   'room_type_str': '투룸',
#   'saved-time': '2015-10-07T08:20:36.190Z',
#   'saved_time': '2015-10-07T08:20:36.190Z',
#   'selling_type': 0,
#   'seq': 486551,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '까치산역 도보 가능/깔끔한 풀옵션 투룸',
#   'user_id': 'clc47@hanmail.net',
#   'view_count': 1044},
#  {'_id': '55aefa293be9384693aa07ff',
#   'actived_time': '2016-02-25T04:42:38.965Z',
#   'address': '서울특별시 영등포구 당산동',
#   'agent_id': '54e6a298e4b08d0a98810ec8',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 1000,
#   'favorite_count': 0,
#   'floor': '7층',
#   'hash_tags': ['#주차'],
#   'heating': None,
#   'id': '55aefa293be9384693aa07ff',
#   'is_pano': False,
#   'location': [126.90147968372217, 37.53530956234303],
#   'maintenance_cost': 6.0,
#   'maintenance_items_str': [],
#   'name': '채영민',
#   'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'fce2ee2c-5a67-40b0-b4f6-d2f843b6b9ac'},
#    {'desc': '', 'key': '6237a01f-2ea7-4497-a1a2-9bc388191cdc'},
#    {'desc': '', 'key': 'eca97271-f254-4763-a9bb-9382f5c1df99'},
#    {'desc': '', 'key': '8b392fa6-ffea-403f-b4cb-89fbe2e26141'},
#    {'desc': '', 'key': '16e3b724-10c5-413c-b5df-55305edb668b'},
#    {'desc': '', 'key': '8bf8a342-7f0a-41fa-a063-87a8531d9204'},
#    {'desc': '', 'key': 'ffbe4000-064a-4c6c-95a7-d850bba4edd5'},
#    {'desc': '', 'key': '6b5af723-26ca-4a55-bccf-4546109e8eee'},
#    {'desc': '', 'key': 'bc0dfc7c-517d-4bfb-a7d5-5f674e21e091'}],
#   'photos': ['fce2ee2c-5a67-40b0-b4f6-d2f843b6b9ac',
#    '6237a01f-2ea7-4497-a1a2-9bc388191cdc',
#    'eca97271-f254-4763-a9bb-9382f5c1df99',
#    '8b392fa6-ffea-403f-b4cb-89fbe2e26141',
#    '16e3b724-10c5-413c-b5df-55305edb668b',
#    '8bf8a342-7f0a-41fa-a063-87a8531d9204',
#    'ffbe4000-064a-4c6c-95a7-d850bba4edd5',
#    '6b5af723-26ca-4a55-bccf-4546109e8eee',
#    'bc0dfc7c-517d-4bfb-a7d5-5f674e21e091'],
#   'price': 70,
#   'price-title': '1000/70',
#   'price_info': [[1000, 70]],
#   'price_title': '1000/70',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 23,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 24.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 7층 | 24.8m² | 관리비 6만원',
#   'room_floor': 7,
#   'room_options': [0, 1, 3, 4, 6, 7, 9, 11],
#   'room_size': 24.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2015-07-22T02:04:25.787Z',
#   'saved_time': '2015-07-22T02:04:25.787Z',
#   'selling_type': 0,
#   'seq': 368167,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '##당산역 NO.1 오피스텔##스타~~빌!!!##',
#   'user_id': '0min18@naver.com',
#   'view_count': 36},
#  {'_id': '56b70857401cc22a77188951',
#   'actived_time': '2016-02-07T09:03:19.119Z',
#   'address': '서울특별시 양천구 신정4동',
#   'agent_id': None,
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 0,
#   'favorite_count': 9,
#   'floor': '2층',
#   'hash_tags': ['#직거래', '#단기가능', '#주차'],
#   'heating': None,
#   'id': '56b70857401cc22a77188951',
#   'is_pano': False,
#   'location': [126.85922490284717, 37.52712170586233],
#   'maintenance_cost': None,
#   'maintenance_items_str': [],
#   'name': '조은하',
#   'options': ['에어컨',
#    '책상',
#    '신발장',
#    '세탁기',
#    '옷장',
#    '냉장고',
#    '전자레인지',
#    '침대',
#    'TV',
#    '가스레인지'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'd367a2aa-0f7b-4593-a7a7-1fc0bac63d12'},
#    {'desc': '', 'key': '5ca109e0-4ee5-4d35-a7d3-6d4a2747095b'},
#    {'desc': '', 'key': '7b456590-8c51-4e36-95c8-729fef2e9077'},
#    {'desc': '', 'key': '14be377b-cac4-402c-9bb1-f6827f8d307d'},
#    {'desc': '', 'key': 'abd757b6-674e-44b3-adf0-0155581d7252'}],
#   'photos': ['d367a2aa-0f7b-4593-a7a7-1fc0bac63d12',
#    '5ca109e0-4ee5-4d35-a7d3-6d4a2747095b',
#    '7b456590-8c51-4e36-95c8-729fef2e9077',
#    '14be377b-cac4-402c-9bb1-f6827f8d307d',
#    'abd757b6-674e-44b3-adf0-0155581d7252'],
#   'price': 22,
#   'price-title': '0/22',
#   'price_info': [[0, 22]],
#   'price_title': '0/22',
#   'private-memo': None,
#   'processing': False,
#   'refresh': True,
#   'remaining_days': 5,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 9.9,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 2층 | 9.9m²',
#   'room_floor': 2,
#   'room_options': [0, 3, 6, 1, 4, 7, 10, 2, 5, 8],
#   'room_size': 9.9,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2016-02-07T09:03:19.119Z',
#   'saved_time': '2016-02-07T09:03:19.119Z',
#   'selling_type': 0,
#   'seq': 732681,
#   'short_lease': True,
#   'status': 1,
#   'tags': ['직거래'],
#   'title': '목동역1번 노블레지던스',
#   'user_id': 'star5512@navet.com',
#   'view_count': 502},
#  {'_id': '561492410c809c6886d89737',
#   'actived_time': '2016-03-02T04:21:30.796Z',
#   'address': '서울특별시 강서구 화곡동',
#   'agent_id': '52d3a24be4b02acb1311d818',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 4500,
#   'favorite_count': 13,
#   'floor': '5층',
#   'hash_tags': ['#전세가능', '#주차'],
#   'heating': None,
#   'id': '561492410c809c6886d89737',
#   'is_pano': False,
#   'location': [126.847021255876, 37.5466365974297],
#   'maintenance_cost': 5.0,
#   'maintenance_items_str': [],
#   'name': '김정식',
#   'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자레인지', '전자도어락'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'd2ae45d6-6fc7-44ec-93de-fdf99e68b7db'},
#    {'desc': '', 'key': 'e342b72b-e75e-4f1a-aa88-2e42cf9e9190'},
#    {'desc': '', 'key': '2fb8bc5b-3303-46e1-918a-cd8ccbe8cabc'},
#    {'desc': '', 'key': '4d12dbd4-9a1f-4b87-9d1f-08d5710ae73f'},
#    {'desc': '', 'key': '694aa316-3411-4a2c-8d0c-4eedb57f0c28'},
#    {'desc': '', 'key': 'cf3601d5-a3ce-4186-9457-18a8caf0b63b'},
#    {'desc': '', 'key': 'ef7f6fc2-f174-4986-8f02-bcf44b1560bc'},
#    {'desc': '', 'key': '81c1186c-2181-433e-af18-45d2effc61a9'},
#    {'desc': '', 'key': '7446041e-5cbf-4e4b-9837-7b5a69bcc876'}],
#   'photos': ['d2ae45d6-6fc7-44ec-93de-fdf99e68b7db',
#    'e342b72b-e75e-4f1a-aa88-2e42cf9e9190',
#    '2fb8bc5b-3303-46e1-918a-cd8ccbe8cabc',
#    '4d12dbd4-9a1f-4b87-9d1f-08d5710ae73f',
#    '694aa316-3411-4a2c-8d0c-4eedb57f0c28',
#    'cf3601d5-a3ce-4186-9457-18a8caf0b63b',
#    'ef7f6fc2-f174-4986-8f02-bcf44b1560bc',
#    '81c1186c-2181-433e-af18-45d2effc61a9',
#    '7446041e-5cbf-4e4b-9837-7b5a69bcc876'],
#   'price': 0,
#   'price-title': '4500',
#   'price_info': [[4500, 0], [2000, 25], [3000, 15], [4000, 5]],
#   'price_title': '4500',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 29,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 21.4,
#   'room-title': '원룸 전세',
#   'room_desc': '원룸 | 5층 | 21.4m² | 관리비 5만원',
#   'room_floor': 5,
#   'room_options': [0, 1, 3, 4, 6, 7, 9, 10, 11],
#   'room_size': 21.4,
#   'room_title': '원룸 전세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2015-10-07T03:32:17.452Z',
#   'saved_time': '2015-10-07T03:32:17.452Z',
#   'selling_type': 1,
#   'seq': 485865,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개', '전세가능'],
#   'title': '※가격대비 넓은 방입니다',
#   'user_id': 'skydiver7223@nate.com',
#   'view_count': 956},
#  {'_id': '56b2db96b334122d2e9016b5',
#   'actived_time': '2016-02-23T06:42:06.592Z',
#   'address': '서울특별시 영등포구 양평동',
#   'agent_id': '56373cba853a2a545c8967c9',
#   'animal': False,
#   'building_floor_str': '',
#   'deposit': 1000,
#   'favorite_count': 1,
#   'floor': '7층',
#   'hash_tags': ['#주차'],
#   'heating': None,
#   'id': '56b2db96b334122d2e9016b5',
#   'is_pano': False,
#   'location': [126.88445325630683, 37.52108714152279],
#   'maintenance_cost': 7.0,
#   'maintenance_items_str': [],
#   'name': '유상훈',
#   'options': ['에어컨',
#    '세탁기',
#    '옷장',
#    'TV',
#    '신발장',
#    '냉장고',
#    '가스레인지',
#    '전자레인지',
#    '전자도어락',
#    '비데'],
#   'pano': None,
#   'parking': True,
#   'photo': [{'desc': '', 'key': 'bc12d9fc-b953-461f-b58f-8a11eee1d671'},
#    {'desc': '', 'key': 'd0bf9901-9481-4591-a0b9-73cf7a126675'},
#    {'desc': '', 'key': '80fe8c01-e9dd-40ba-a352-f0d0edf5a18e'},
#    {'desc': '', 'key': '389aba2e-4a9d-4c3c-8ae8-c63499c5b8c9'},
#    {'desc': '', 'key': '8d638a76-d3ed-4ae8-a544-fbbb0af4b6fd'},
#    {'desc': '', 'key': 'e1b150ad-4c62-44aa-be45-88162ebb6659'},
#    {'desc': '', 'key': 'b90898e2-f6ba-421b-af14-102b7125bcc4'},
#    {'desc': '', 'key': 'c5dd57da-3f18-4eb8-9d01-9518c8881105'},
#    {'desc': '', 'key': 'a66e675d-b49d-40ea-9f54-d785b08e7f24'},
#    {'desc': '', 'key': '2f44fe4e-9c29-44ef-b2cc-246448c34de4'},
#    {'desc': '', 'key': 'b465c11f-1457-401c-86cb-eb7c9ceacc82'},
#    {'desc': '', 'key': 'a08cb316-6d92-4671-ac03-0f8fbe831ced'},
#    {'desc': '', 'key': '926eddae-42b8-450f-a615-7b969952cec4'},
#    {'desc': '', 'key': 'b906cb7e-f818-494d-a8f0-15e4897f7bf5'},
#    {'desc': '', 'key': 'd300b856-1fbd-4adc-bf1f-43b687d84c9a'},
#    {'desc': '', 'key': '009418e4-b9a7-4a61-a30d-8a4dc50bd328'}],
#   'photos': ['bc12d9fc-b953-461f-b58f-8a11eee1d671',
#    'd0bf9901-9481-4591-a0b9-73cf7a126675',
#    '80fe8c01-e9dd-40ba-a352-f0d0edf5a18e',
#    '389aba2e-4a9d-4c3c-8ae8-c63499c5b8c9',
#    '8d638a76-d3ed-4ae8-a544-fbbb0af4b6fd',
#    'e1b150ad-4c62-44aa-be45-88162ebb6659',
#    'b90898e2-f6ba-421b-af14-102b7125bcc4',
#    'c5dd57da-3f18-4eb8-9d01-9518c8881105',
#    'a66e675d-b49d-40ea-9f54-d785b08e7f24',
#    '2f44fe4e-9c29-44ef-b2cc-246448c34de4',
#    'b465c11f-1457-401c-86cb-eb7c9ceacc82',
#    'a08cb316-6d92-4671-ac03-0f8fbe831ced',
#    '926eddae-42b8-450f-a615-7b969952cec4',
#    'b906cb7e-f818-494d-a8f0-15e4897f7bf5',
#    'd300b856-1fbd-4adc-bf1f-43b687d84c9a',
#    '009418e4-b9a7-4a61-a30d-8a4dc50bd328'],
#   'price': 62,
#   'price-title': '1000/62',
#   'price_info': [[1000, 62], [1500, 60]],
#   'price_title': '1000/62',
#   'private-memo': None,
#   'processing': False,
#   'refresh': False,
#   'remaining_days': 21,
#   'report_check_comment': None,
#   'report_check_saved_time': None,
#   'room-size-m2': 19.8,
#   'room-title': '원룸 월세',
#   'room_desc': '원룸 | 7층 | 19.8m² | 관리비 7만원',
#   'room_floor': 7,
#   'room_options': [0, 1, 4, 5, 6, 7, 8, 10, 11, 12],
#   'room_size': 19.8,
#   'room_title': '원룸 월세',
#   'room_type': 0,
#   'room_type_str': '원룸',
#   'saved-time': '2016-02-04T05:03:18.441Z',
#   'saved_time': '2016-02-04T05:03:18.441Z',
#   'selling_type': 0,
#   'seq': 725945,
#   'short_lease': False,
#   'status': 1,
#   'tags': ['중개'],
#   'title': '★★ 완전 풀옵션 ^^ / 예쁜 복층오피스텔 / 전세★월세 ',
#   'user_id': 'yusanghun27@gmail.com',
#   'view_count': 37}]

# %%
df = pd.DataFrame(columns=['name', 'deposit', 'rent', 'address', 'floor' ])

rooms = dabang_dict.get('rooms')
for room in rooms:
    address = room.get('address')
    deposit = room.get('deposit')
    rent = room.get('price')
    name = room.get('name')
    floor = room.get('floor')
    
    df.loc[len(df)] = [name, deposit, rent, address, floor]

# %%
df
# Out:
#      name  deposit  rent            address floor
# 0     고유정      300    45   서울특별시 영등포구 양평동3가    5층
# 1     김종철    16500     0      서울특별시 강서구 화곡동    3층
# 2     권혁일    16800     0     서울특별시 강서구 화곡동     9층
# 3     이정세     1000    50      서울특별시 강서구 화곡동    7층
# 4      구정      250    35     인천광역시 부평구 갈산1동    2층
# 5     서혜정     2000    50     서울특별시 영등포구 당산동    3층
# 6     박성배     1000    38  서울특별시 영등포구 영등포동6가
# 7     우언임    16500     0      서울특별시 양천구 신월동    5층
# 8     신한인      500    45   서울특별시 영등포구 당산동4가    5층
# 9     류승현      300    25      인천광역시 부평구 부평동   반지층
# 10    이부형     1000    41      서울특별시 강서구 화곡동    5층
# 11    김미란      100    60      서울특별시 강서구 화곡동    9층
# 12    이연진     1000    45     서울특별시 강서구 화곡1동   11층
# 13    윤경섭      500    40     서울특별시 강서구 화곡동    12층
# 14    전재용     4000    15      서울특별시 강서구 화곡동    8층
# 15    진영훈     8300     0     서울특별시 영등포구 문래동    7층
# 16    박상돈     1000    50     서울특별시 마포구 망원2동    2층
# 17    박오배    17000     0      서울특별시 강서구 화곡동    5층
# 18  이정관대리       30    30      인천광역시 계양구 계산동    2층
# 19     김갑     1000    50      서울특별시 양천구 신월동    4층
# 20    채영민     1000    70     서울특별시 영등포구 당산동    7층
# 21    조은하        0    22     서울특별시 양천구 신정4동    2층
# 22    김정식     4500     0      서울특별시 강서구 화곡동    5층
# 23    유상훈     1000    62     서울특별시 영등포구 양평동    7층

# %% [markdown]
# ---
# ### URL Generator사용하여 1000개 데이터 크롤링하기

# %%
df = pd.DataFrame(columns=['name', 'deposit', 'rent', 'address', 'floor' ])

for page in range(1, 11):
    response = requests.get("http://www.dabangapp.com/api/2/room/list/search?page={i}&filters=%7B%22deposit-range%22%3A%5B0%2C999999%5D%2C%22price-range%22%3A%5B0%2C999999%5D%2C%22room-type%22%3A%5B0%2C1%2C2%2C3%2C4%2C5%5D%2C%22deal-type%22%3A%5B0%2C1%5D%2C%22location%22%3A%5B%5B126.65657267485665%2C37.505146062104686%5D%2C%5B126.90719828520821%2C37.560414154305995%5D%5D%7D&_=1456933964300".format(i=page))
    dabang_dict = json.loads(response.text)
    rooms = dabang_dict.get('rooms')
    
    for room in rooms:
        address = room.get('address')
        deposit = room.get('deposit')
        rent = room.get('price')
        name = room.get('name')
        floor = room.get('floor')
    
        df.loc[len(df)] = [name, deposit, rent, address, floor]

# %%
json.loads(response.text)
# Out:
# {'ad-banner': None,
#  'features': [],
#  'filter-str': None,
#  'has-more': True,
#  'limit': 24,
#  'next-page': 11,
#  'offset': 216,
#  'page': 10,
#  'rooms': [{'_id': '563099cd648ebe5b2822aac1',
#    'actived_time': '2016-02-04T02:13:21.576Z',
#    'address': '서울특별시 영등포구 양평동5가',
#    'agent_id': '54b759fde4b0874b0aa12f67',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 500,
#    'favorite_count': 2,
#    'floor': '5층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '563099cd648ebe5b2822aac1',
#    'is_pano': False,
#    'location': [126.89330112802368, 37.53889924834935],
#    'maintenance_cost': 6.0,
#    'maintenance_items_str': [],
#    'name': '신한인',
#    'options': ['에어컨',
#     '세탁기',
#     '책상',
#     '옷장',
#     '신발장',
#     'TV',
#     '냉장고',
#     '인덕션',
#     '전자레인지',
#     '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'dad578ca-9e74-48c4-9d65-42fb6fc4f83d'},
#     {'desc': '', 'key': '96ce12ff-eaa4-4e8b-8002-eac6abcf5576'},
#     {'desc': '', 'key': 'e4345d2d-b790-4a9c-9278-9e52a4d1184d'},
#     {'desc': '', 'key': 'b1772857-89cb-495f-91c2-a626c48f3d0f'},
#     {'desc': '', 'key': '8c3e8d61-0ca7-484f-adbf-b39a2364e033'},
#     {'desc': '', 'key': 'b8f4e2f7-5e34-4ce6-9807-4dcdf97ad488'},
#     {'desc': '', 'key': 'fa58f479-1d01-42f4-a523-021a686d2009'},
#     {'desc': '', 'key': 'de7fdddd-7144-4183-8093-3b63a7befa80'},
#     {'desc': '', 'key': '5a384a98-7fb1-416d-9872-da56ab4dd277'},
#     {'desc': '', 'key': '7b6a2e36-cb0d-4dbc-bb5b-4a87a1d6b35d'}],
#    'photos': ['dad578ca-9e74-48c4-9d65-42fb6fc4f83d',
#     '96ce12ff-eaa4-4e8b-8002-eac6abcf5576',
#     'e4345d2d-b790-4a9c-9278-9e52a4d1184d',
#     'b1772857-89cb-495f-91c2-a626c48f3d0f',
#     '8c3e8d61-0ca7-484f-adbf-b39a2364e033',
#     'b8f4e2f7-5e34-4ce6-9807-4dcdf97ad488',
#     'fa58f479-1d01-42f4-a523-021a686d2009',
#     'de7fdddd-7144-4183-8093-3b63a7befa80',
#     '5a384a98-7fb1-416d-9872-da56ab4dd277',
#     '7b6a2e36-cb0d-4dbc-bb5b-4a87a1d6b35d'],
#    'price': 45,
#    'price-title': '500/45',
#    'price_info': [[500, 45], [2000, 30]],
#    'price_title': '500/45',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 2,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 5층 | 19.8m² | 관리비 6만원',
#    'room_floor': 5,
#    'room_options': [0, 1, 3, 4, 6, 5, 7, 9, 10, 11],
#    'room_size': 19.8,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-10-28T09:47:57.110Z',
#    'saved_time': '2015-10-28T09:47:57.110Z',
#    'selling_type': 0,
#    'seq': 516021,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '▣선유도역세권 재계약률1위 원룸',
#    'user_id': 'vkarin@naver.com',
#    'view_count': 339},
#   {'_id': '56d3e702440acc3b3ad247e3',
#    'actived_time': '2016-02-29T06:36:50.657Z',
#    'address': '인천광역시 서구 경서동',
#    'agent_id': '53217340e4b094bb53cbb987',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 500,
#    'favorite_count': 0,
#    'floor': '1층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '56d3e702440acc3b3ad247e3',
#    'is_pano': False,
#    'location': [126.67084448822835, 37.555005761787235],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '전윤미실장',
#    'options': ['에어컨', '세탁기', 'TV', '신발장', '냉장고', '가스레인지', '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '063aece5-8112-418e-8007-7545408c5962'},
#     {'desc': '', 'key': '2caa6662-f8e7-4768-b670-b0267a8ed6f9'},
#     {'desc': '', 'key': '4a7d960f-4fe9-4f13-8c10-ac2d3a651e62'},
#     {'desc': '', 'key': 'ef62c2d1-474f-40d1-b602-163338764dee'},
#     {'desc': '', 'key': '76a06ca5-4a1a-49f3-96df-fa827b7446e7'},
#     {'desc': '', 'key': '8e47b5d9-8523-4b03-87bc-4a63091b8f87'},
#     {'desc': '', 'key': '6a1c41e0-e954-4048-a457-19140b11427b'},
#     {'desc': '', 'key': '524c7a1d-cdd5-4f4a-894c-990f92437a7e'},
#     {'desc': '', 'key': '344ca5b3-59a7-4e4b-96f8-e5f97f522187'},
#     {'desc': '', 'key': '9e72f136-1017-47b2-b746-a03a9115b1ff'}],
#    'photos': ['063aece5-8112-418e-8007-7545408c5962',
#     '2caa6662-f8e7-4768-b670-b0267a8ed6f9',
#     '4a7d960f-4fe9-4f13-8c10-ac2d3a651e62',
#     'ef62c2d1-474f-40d1-b602-163338764dee',
#     '76a06ca5-4a1a-49f3-96df-fa827b7446e7',
#     '8e47b5d9-8523-4b03-87bc-4a63091b8f87',
#     '6a1c41e0-e954-4048-a457-19140b11427b',
#     '524c7a1d-cdd5-4f4a-894c-990f92437a7e',
#     '344ca5b3-59a7-4e4b-96f8-e5f97f522187',
#     '9e72f136-1017-47b2-b746-a03a9115b1ff'],
#    'price': 43,
#    'price-title': '500/43',
#    'price_info': [[500, 43]],
#    'price_title': '500/43',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 27,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 29.7,
#    'room-title': '1.5룸 월세',
#    'room_desc': '1.5룸 | 1층 | 29.7m² | 관리비 5만원',
#    'room_floor': 1,
#    'room_options': [0, 1, 5, 6, 7, 8, 11],
#    'room_size': 29.7,
#    'room_title': '1.5룸 월세',
#    'room_type': 5,
#    'room_type_str': '1.5룸',
#    'saved-time': '2016-02-29T06:36:50.657Z',
#    'saved_time': '2016-02-29T06:36:50.657Z',
#    'selling_type': 0,
#    'seq': 780143,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '신축1.5룸,거실별도 있어요.남향.채광좋아요~',
#    'user_id': 'yunseogi@naver.com',
#    'view_count': 16},
#   {'_id': '56cbe14e5fa1d86fdf48590a',
#    'actived_time': '2016-02-23T04:34:22.261Z',
#    'address': '서울특별시 강서구 화곡동',
#    'agent_id': '543639e8e4b05b7ebc491a32',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 6000,
#    'favorite_count': 2,
#    'floor': '12층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '56cbe14e5fa1d86fdf48590a',
#    'is_pano': False,
#    'location': [126.84677760519526, 37.53077508864424],
#    'maintenance_cost': 7.0,
#    'maintenance_items_str': [],
#    'name': '김원진',
#    'options': ['에어컨',
#     '세탁기',
#     '책상',
#     '옷장',
#     '신발장',
#     '냉장고',
#     '인덕션',
#     '전자레인지',
#     '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '5499f398-3106-404c-bb63-d90be29a6ea8'},
#     {'desc': '', 'key': '52286edb-d993-4e1d-9898-f4c89778220f'},
#     {'desc': '', 'key': '4833e5b2-cfa9-4ec6-a15f-91fdaa794bc0'},
#     {'desc': '', 'key': '22096f3d-22df-4314-af7a-36c09e67a7e5'},
#     {'desc': '', 'key': '281b971d-a54d-404a-947e-3e8c5ad31ba4'},
#     {'desc': '', 'key': '8d35ca56-02f5-4fc4-a473-fa2fafa726c3'},
#     {'desc': '', 'key': '9f0cdb1f-c394-47a7-9ecb-58c854987c74'},
#     {'desc': '', 'key': '8533abf4-4ae0-4350-b4cf-741799660a79'},
#     {'desc': '', 'key': '38080a5b-3af2-48c0-91a1-0bf98c10fd14'}],
#    'photos': ['5499f398-3106-404c-bb63-d90be29a6ea8',
#     '52286edb-d993-4e1d-9898-f4c89778220f',
#     '4833e5b2-cfa9-4ec6-a15f-91fdaa794bc0',
#     '22096f3d-22df-4314-af7a-36c09e67a7e5',
#     '281b971d-a54d-404a-947e-3e8c5ad31ba4',
#     '8d35ca56-02f5-4fc4-a473-fa2fafa726c3',
#     '9f0cdb1f-c394-47a7-9ecb-58c854987c74',
#     '8533abf4-4ae0-4350-b4cf-741799660a79',
#     '38080a5b-3af2-48c0-91a1-0bf98c10fd14'],
#    'price': 10,
#    'price-title': '6000/10',
#    'price_info': [[6000, 10]],
#    'price_title': '6000/10',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 21,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 23.1,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 12층 | 23.1m² | 관리비 7만원',
#    'room_floor': 12,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 10, 11],
#    'room_size': 23.1,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-23T04:34:22.261Z',
#    'saved_time': '2016-02-23T04:34:22.261Z',
#    'selling_type': 0,
#    'seq': 765914,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '☆☆초초 역세권~ 보증금 대출가능한 정말정말 귀한집~☆☆',
#    'user_id': 'hayato1201@nate.com',
#    'view_count': 19},
#   {'_id': '562238330060122d08ac3fec',
#    'actived_time': '2016-02-16T06:12:14.396Z',
#    'address': '서울특별시 강서구 화곡동 ',
#    'agent_id': '54043e50e4b091303d795de8',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 2000,
#    'favorite_count': 2,
#    'floor': '11층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '562238330060122d08ac3fec',
#    'is_pano': False,
#    'location': [126.84629356205642, 37.53068796359582],
#    'maintenance_cost': 7.0,
#    'maintenance_items_str': [],
#    'name': '윤경섭',
#    'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '3d671644-a5eb-489f-8b90-d9bc464c8512'},
#     {'desc': '', 'key': 'fe1bad9d-7f47-405f-8659-c74017b19e0e'},
#     {'desc': '', 'key': '99bdcccd-96fc-4fb3-b8bb-3bfc7e8c986e'},
#     {'desc': '', 'key': '7183d555-b5e0-4469-b771-4e07727888cf'},
#     {'desc': '', 'key': 'eeb4c9bd-fae4-4286-9f83-9703951dfb35'},
#     {'desc': '', 'key': 'aadf75b9-97f3-4fba-835b-3208a657ccd0'},
#     {'desc': '', 'key': '1db8c87e-8c8b-4691-8788-e6a9d194a3ef'},
#     {'desc': '', 'key': '60f21f9c-55a5-4407-b7d3-1ef359352215'},
#     {'desc': '', 'key': 'b0ca6a25-9e1e-4ead-87a1-22bb923c1acf'},
#     {'desc': '', 'key': '77d7ac88-5057-4c2b-8540-cfb6166f9edd'},
#     {'desc': '', 'key': '17e42ed5-00f6-4418-a8b6-58ab5a4b9aa7'}],
#    'photos': ['3d671644-a5eb-489f-8b90-d9bc464c8512',
#     'fe1bad9d-7f47-405f-8659-c74017b19e0e',
#     '99bdcccd-96fc-4fb3-b8bb-3bfc7e8c986e',
#     '7183d555-b5e0-4469-b771-4e07727888cf',
#     'eeb4c9bd-fae4-4286-9f83-9703951dfb35',
#     'aadf75b9-97f3-4fba-835b-3208a657ccd0',
#     '1db8c87e-8c8b-4691-8788-e6a9d194a3ef',
#     '60f21f9c-55a5-4407-b7d3-1ef359352215',
#     'b0ca6a25-9e1e-4ead-87a1-22bb923c1acf',
#     '77d7ac88-5057-4c2b-8540-cfb6166f9edd',
#     '17e42ed5-00f6-4418-a8b6-58ab5a4b9aa7'],
#    'price': 55,
#    'price-title': '2000/55',
#    'price_info': [[2000, 55], [1000, 65]],
#    'price_title': '2000/55',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 14,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 26.4,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 11층 | 26.4m² | 관리비 7만원',
#    'room_floor': 11,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 11],
#    'room_size': 26.4,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-10-17T11:59:47.442Z',
#    'saved_time': '2015-10-17T11:59:47.442Z',
#    'selling_type': 0,
#    'seq': 500005,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '@ 까치산역 도보 1~2분 .완전 깔끔한 원룸~!@',
#    'user_id': 'sep70@hanmail.net',
#    'view_count': 260},
#   {'_id': '56d6ac4b57042b4c8b2114df',
#    'actived_time': '2016-03-02T09:03:07.771Z',
#    'address': '서울특별시 강서구 등촌동',
#    'agent_id': '55af3f542065693fbbeeee61',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 1000,
#    'favorite_count': 0,
#    'floor': '7층',
#    'hash_tags': [],
#    'heating': None,
#    'id': '56d6ac4b57042b4c8b2114df',
#    'is_pano': False,
#    'location': [126.86352658595979, 37.55045903877113],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '박장식',
#    'options': ['에어컨', '세탁기', '신발장', '냉장고', '인덕션', '전자도어락'],
#    'pano': None,
#    'parking': False,
#    'photo': [{'desc': '', 'key': '5c0948fa-0674-4f45-81ab-683c27339991'},
#     {'desc': '', 'key': '53ad5779-8c57-43ff-b187-1b83608a3738'},
#     {'desc': '', 'key': 'abca9240-9835-4b0d-8b99-ce2bad6317b8'},
#     {'desc': '', 'key': '87ab2636-546f-47a2-a66a-ce6aaf21ccf6'},
#     {'desc': '', 'key': '71d83b53-85ac-4205-9f23-cd6930cc77ca'},
#     {'desc': '', 'key': '68ab4f4c-e605-4b2f-babc-2e94a78c0ef2'},
#     {'desc': '', 'key': '729ea867-fb7b-43d0-ae3b-75f6ada04021'},
#     {'desc': '', 'key': '54e9898e-6290-45f6-a436-0fbb1052834b'},
#     {'desc': '', 'key': 'cc91a57c-466b-4628-a8d0-2329e82091ca'},
#     {'desc': '', 'key': '3109ef92-54e9-48da-bb63-350515fe4a39'},
#     {'desc': '', 'key': '93e64468-8433-4e45-9202-934a6fb47ef4'}],
#    'photos': ['5c0948fa-0674-4f45-81ab-683c27339991',
#     '53ad5779-8c57-43ff-b187-1b83608a3738',
#     'abca9240-9835-4b0d-8b99-ce2bad6317b8',
#     '87ab2636-546f-47a2-a66a-ce6aaf21ccf6',
#     '71d83b53-85ac-4205-9f23-cd6930cc77ca',
#     '68ab4f4c-e605-4b2f-babc-2e94a78c0ef2',
#     '729ea867-fb7b-43d0-ae3b-75f6ada04021',
#     '54e9898e-6290-45f6-a436-0fbb1052834b',
#     'cc91a57c-466b-4628-a8d0-2329e82091ca',
#     '3109ef92-54e9-48da-bb63-350515fe4a39',
#     '93e64468-8433-4e45-9202-934a6fb47ef4'],
#    'price': 53,
#    'price-title': '1000/53',
#    'price_info': [[1000, 53]],
#    'price_title': '1000/53',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 29,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 36.3,
#    'room-title': '1.5룸 월세',
#    'room_desc': '1.5룸 | 7층 | 36.3m² | 관리비 5만원',
#    'room_floor': 7,
#    'room_options': [0, 1, 6, 7, 9, 11],
#    'room_size': 36.3,
#    'room_title': '1.5룸 월세',
#    'room_type': 5,
#    'room_type_str': '1.5룸',
#    'saved-time': '2016-03-02T09:03:07.771Z',
#    'saved_time': '2016-03-02T09:03:07.771Z',
#    'selling_type': 0,
#    'seq': 786121,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '@짱좋은 초역세권!! 풀옵션 1.5룸!! 빨리 잡으세요!!',
#    'user_id': 'janggoon011@naver.com',
#    'view_count': 4},
#   {'_id': '56c445e3d2659a46be1ddc7c',
#    'actived_time': '2016-02-17T10:05:23.295Z',
#    'address': '서울특별시 강서구 공항동 ',
#    'agent_id': '543f826ce4b0b8e5b3d73ad9',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 350,
#    'favorite_count': 1,
#    'floor': '3층',
#    'hash_tags': [],
#    'heating': None,
#    'id': '56c445e3d2659a46be1ddc7c',
#    'is_pano': False,
#    'location': [126.81019717237163, 37.558076264460404],
#    'maintenance_cost': 3.0,
#    'maintenance_items_str': [],
#    'name': '김대웅',
#    'options': ['에어컨', '세탁기', '전자도어락', '신발장', '냉장고', '인덕션'],
#    'pano': None,
#    'parking': False,
#    'photo': [{'desc': '', 'key': '5f22c518-a81b-4ddd-ae9d-7ba3fe69983b'},
#     {'desc': '', 'key': 'ac66a5a6-7fd4-46dc-a2aa-50184f70bf9e'},
#     {'desc': '', 'key': 'f7df511a-ff7c-4fcd-a8c5-c8e66085746c'},
#     {'desc': '', 'key': '73af0e5b-86b1-4229-9997-dbe4b12bfff0'},
#     {'desc': '', 'key': '05695d90-9dc4-449a-b67f-b4bd029e10cf'},
#     {'desc': '', 'key': 'a9322fd0-c32c-41e3-bf0e-d9532da8d035'},
#     {'desc': '', 'key': 'b6355e25-9025-487d-b52e-f4726d43c5d2'},
#     {'desc': '', 'key': '1f670fb4-c348-4053-8199-77eabd8ab193'},
#     {'desc': '', 'key': '6dbb12db-0395-45b4-94ee-e0ee8344c638'}],
#    'photos': ['5f22c518-a81b-4ddd-ae9d-7ba3fe69983b',
#     'ac66a5a6-7fd4-46dc-a2aa-50184f70bf9e',
#     'f7df511a-ff7c-4fcd-a8c5-c8e66085746c',
#     '73af0e5b-86b1-4229-9997-dbe4b12bfff0',
#     '05695d90-9dc4-449a-b67f-b4bd029e10cf',
#     'a9322fd0-c32c-41e3-bf0e-d9532da8d035',
#     'b6355e25-9025-487d-b52e-f4726d43c5d2',
#     '1f670fb4-c348-4053-8199-77eabd8ab193',
#     '6dbb12db-0395-45b4-94ee-e0ee8344c638'],
#    'price': 47,
#    'price-title': '350/47',
#    'price_info': [[350, 47], [500, 45]],
#    'price_title': '350/47',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 15,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 23.1,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 3층 | 23.1m² | 관리비 3만원',
#    'room_floor': 3,
#    'room_options': [0, 1, 11, 6, 7, 9],
#    'room_size': 23.1,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-17T10:05:23.295Z',
#    'saved_time': '2016-02-17T10:05:23.295Z',
#    'selling_type': 0,
#    'seq': 752662,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '⚂ 풀옵션이 들어가 있어여 그냥 몸만 들어오시면되세요.\t',
#    'user_id': 'skydiver103@nate.com',
#    'view_count': 54},
#   {'_id': '566a9845c7ae1d4e591838d8',
#    'actived_time': '2016-02-11T04:54:15.219Z',
#    'address': '서울특별시 영등포구 당산동6가',
#    'agent_id': '566a6c8c8b0f5e48bd772b47',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 500,
#    'favorite_count': 11,
#    'floor': '10층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '566a9845c7ae1d4e591838d8',
#    'is_pano': False,
#    'location': [126.90136153582523, 37.53567346786047],
#    'maintenance_cost': 6.0,
#    'maintenance_items_str': [],
#    'name': '고유정',
#    'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '662ba31e-e4e3-4432-a1e1-1fa2cca06e5d'},
#     {'desc': '', 'key': '58739aa6-a625-480c-aee7-d1c5ffc53fc7'},
#     {'desc': '', 'key': 'f8472745-c8f8-49de-9859-93ba680114f1'},
#     {'desc': '', 'key': '81b1e1ba-93e7-4076-ab33-9373f7b1fa86'},
#     {'desc': '', 'key': '507f4db3-c708-43f3-9f3e-2cd546eaad2c'},
#     {'desc': '', 'key': '48151e53-4998-4451-a191-cff32253e107'},
#     {'desc': '', 'key': '79301e81-c53c-4838-93b2-781908e9d00c'},
#     {'desc': '', 'key': '587b8f99-fb6a-4b10-841a-5a1a0db33914'},
#     {'desc': '', 'key': '0e18df43-7610-4d92-b766-0cd5b01a4a80'},
#     {'desc': '', 'key': 'c67438a1-7f1b-4e3c-8b9d-f80531cd5ef9'}],
#    'photos': ['662ba31e-e4e3-4432-a1e1-1fa2cca06e5d',
#     '58739aa6-a625-480c-aee7-d1c5ffc53fc7',
#     'f8472745-c8f8-49de-9859-93ba680114f1',
#     '81b1e1ba-93e7-4076-ab33-9373f7b1fa86',
#     '507f4db3-c708-43f3-9f3e-2cd546eaad2c',
#     '48151e53-4998-4451-a191-cff32253e107',
#     '79301e81-c53c-4838-93b2-781908e9d00c',
#     '587b8f99-fb6a-4b10-841a-5a1a0db33914',
#     '0e18df43-7610-4d92-b766-0cd5b01a4a80',
#     'c67438a1-7f1b-4e3c-8b9d-f80531cd5ef9'],
#    'price': 65,
#    'price-title': '500/65',
#    'price_info': [[500, 65], [1000, 60], [2000, 55]],
#    'price_title': '500/65',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 9,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '오피스텔 월세',
#    'room_desc': '오피스텔 | 10층 | 19.8m² | 관리비 6만원',
#    'room_floor': 10,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 11],
#    'room_size': 19.8,
#    'room_title': '오피스텔 월세',
#    'room_type': 3,
#    'room_type_str': '오피스텔',
#    'saved-time': '2015-12-11T09:32:53.426Z',
#    'saved_time': '2015-12-11T09:32:53.426Z',
#    'selling_type': 0,
#    'seq': 589839,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '▣유탑유블레스▣ 당산역 도보 2분!! 초역세권~',
#    'user_id': 'namoo@naver.com',
#    'view_count': 441},
#   {'_id': '56c441e390d42a35f657741e',
#    'actived_time': '2016-02-23T06:25:59.354Z',
#    'address': '서울특별시 영등포구',
#    'agent_id': '56b2dea28a86056c644e04d7',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 3000,
#    'favorite_count': 1,
#    'floor': '2층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '56c441e390d42a35f657741e',
#    'is_pano': False,
#    'location': [126.89999472681392, 37.52892202010422],
#    'maintenance_cost': 8.0,
#    'maintenance_items_str': [],
#    'name': '김현우',
#    'options': ['냉장고', '옷장', '전자도어락', '신발장', '책상', '에어컨'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '27ad0350-1dc1-4e0d-bbce-a409451939fb'},
#     {'desc': '', 'key': 'd5ef03e4-c98c-4108-8cde-91b3bb27993b'},
#     {'desc': '', 'key': '989bcfd4-7d10-4c8a-8123-11ee9828691d'},
#     {'desc': '', 'key': 'a6fa720a-e8b9-4d96-9555-5667cf0c0d03'},
#     {'desc': '', 'key': '992a4dd1-c928-4de6-9d02-a12f77d3a2bc'}],
#    'photos': ['27ad0350-1dc1-4e0d-bbce-a409451939fb',
#     'd5ef03e4-c98c-4108-8cde-91b3bb27993b',
#     '989bcfd4-7d10-4c8a-8123-11ee9828691d',
#     'a6fa720a-e8b9-4d96-9555-5667cf0c0d03',
#     '992a4dd1-c928-4de6-9d02-a12f77d3a2bc'],
#    'price': 30,
#    'price-title': '3000/30',
#    'price_info': [[3000, 30], [4000, 20]],
#    'price_title': '3000/30',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 21,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 23.1,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 2층 | 23.1m² | 관리비 8만원',
#    'room_floor': 2,
#    'room_options': [7, 4, 11, 6, 3, 0],
#    'room_size': 23.1,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-17T09:48:19.769Z',
#    'saved_time': '2016-02-17T09:48:19.769Z',
#    'selling_type': 0,
#    'seq': 752594,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '★☆역세권! 반전세! 베란다있는 큰방!★☆',
#    'user_id': 'fgjhl@naver.com',
#    'view_count': 69},
#   {'_id': '56ce9b8c48e0a5595debaabe',
#    'actived_time': '2016-02-27T06:56:52.707Z',
#    'address': '서울특별시 양천구 신정동',
#    'agent_id': '543f826ce4b0b8e5b3d73ad9',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 300,
#    'favorite_count': 0,
#    'floor': '4층',
#    'hash_tags': [],
#    'heating': None,
#    'id': '56ce9b8c48e0a5595debaabe',
#    'is_pano': False,
#    'location': [126.86132347481642, 37.52284262896371],
#    'maintenance_cost': 12.0,
#    'maintenance_items_str': [],
#    'name': '조현룡',
#    'options': ['에어컨',
#     '세탁기',
#     '침대',
#     '옷장',
#     '신발장',
#     '냉장고',
#     '인덕션',
#     '전자레인지',
#     '전자도어락'],
#    'pano': None,
#    'parking': False,
#    'photo': [{'desc': '', 'key': '57abd0ed-29c6-473b-a96c-16436e1c6f1e'},
#     {'desc': '', 'key': '481bd910-df86-4ac9-a42d-1f116e672d30'},
#     {'desc': '', 'key': '9400a669-fa7f-4a3f-bd1e-64a72d997c09'},
#     {'desc': '', 'key': 'd6835d00-163e-452d-950f-77d818d5ab38'},
#     {'desc': '', 'key': '25967635-7240-4463-89e9-64ae28996a65'},
#     {'desc': '', 'key': 'f2dd53a6-15e9-4f24-ba1e-d46f7fddd0df'},
#     {'desc': '', 'key': '21a30eda-d838-4a2d-be31-dd5505c6852e'},
#     {'desc': '', 'key': 'ab33252e-89e1-485b-ad83-728dcb2a226d'},
#     {'desc': '', 'key': 'bb4687a5-a61b-4251-a06b-1637aece6b20'},
#     {'desc': '', 'key': '9a91840b-46bb-4381-9d6c-6d4b3faa4120'},
#     {'desc': '', 'key': '8b543c7c-fa30-4d5b-bb77-dda616852e1a'},
#     {'desc': '', 'key': '627826f5-b452-4e95-81e3-0f1052dd1309'},
#     {'desc': '', 'key': 'e4a7f1c1-0929-49e1-84a3-32e1696d986e'}],
#    'photos': ['57abd0ed-29c6-473b-a96c-16436e1c6f1e',
#     '481bd910-df86-4ac9-a42d-1f116e672d30',
#     '9400a669-fa7f-4a3f-bd1e-64a72d997c09',
#     'd6835d00-163e-452d-950f-77d818d5ab38',
#     '25967635-7240-4463-89e9-64ae28996a65',
#     'f2dd53a6-15e9-4f24-ba1e-d46f7fddd0df',
#     '21a30eda-d838-4a2d-be31-dd5505c6852e',
#     'ab33252e-89e1-485b-ad83-728dcb2a226d',
#     'bb4687a5-a61b-4251-a06b-1637aece6b20',
#     '9a91840b-46bb-4381-9d6c-6d4b3faa4120',
#     '8b543c7c-fa30-4d5b-bb77-dda616852e1a',
#     '627826f5-b452-4e95-81e3-0f1052dd1309',
#     'e4a7f1c1-0929-49e1-84a3-32e1696d986e'],
#    'price': 57,
#    'price-title': '300/57',
#    'price_info': [[300, 57]],
#    'price_title': '300/57',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 25,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 4층 | 19.8m² | 관리비 12만원',
#    'room_floor': 4,
#    'room_options': [0, 1, 2, 4, 6, 7, 9, 10, 11],
#    'room_size': 19.8,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-25T06:13:32.456Z',
#    'saved_time': '2016-02-25T06:13:32.456Z',
#    'selling_type': 0,
#    'seq': 771714,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '★★신정동  귀하게 나온 원룸/보증금 조정★★',
#    'user_id': 'clip119@nate.com',
#    'view_count': 14},
#   {'_id': '56c1aab91bcf6f2c23587fb8',
#    'actived_time': '2016-02-15T10:38:49.474Z',
#    'address': '서울특별시 강서구 등촌동 ',
#    'agent_id': '562ddd25823d860887d06213',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 7000,
#    'favorite_count': 0,
#    'floor': '3층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '56c1aab91bcf6f2c23587fb8',
#    'is_pano': False,
#    'location': [126.86387472665405, 37.5531732452281],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '최민희',
#    'options': [],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '706e8016-09fb-4133-a941-640b48045af5'},
#     {'desc': '', 'key': '0717fc51-6b72-4fb7-9278-127fe03c829a'},
#     {'desc': '', 'key': '0db59891-7652-4927-a6f1-d184790ef648'},
#     {'desc': '', 'key': 'd643460b-9672-4b3f-8499-ee887170fdd4'},
#     {'desc': '', 'key': '7e9311aa-0e3e-40c7-944a-50d6212a49ea'},
#     {'desc': '', 'key': '7b430030-0ed4-4e12-94c8-64a2f4f788e6'},
#     {'desc': '', 'key': 'e334db5c-f6a9-4aad-9b77-9eb620da6133'},
#     {'desc': '', 'key': '655eed3b-fe6f-4a27-bdee-6f78a04b4dca'},
#     {'desc': '', 'key': '46a2eaa2-44e7-4e2a-a4c9-b368c66dd5d1'},
#     {'desc': '', 'key': '49256e86-5a2c-4128-97d5-4e1b0a1ae88a'},
#     {'desc': '', 'key': 'f76b97ee-975b-459f-b06d-dc2b52018f8b'},
#     {'desc': '', 'key': '4a8f6dbb-2ca3-4052-b8ab-b289b7982b66'}],
#    'photos': ['706e8016-09fb-4133-a941-640b48045af5',
#     '0717fc51-6b72-4fb7-9278-127fe03c829a',
#     '0db59891-7652-4927-a6f1-d184790ef648',
#     'd643460b-9672-4b3f-8499-ee887170fdd4',
#     '7e9311aa-0e3e-40c7-944a-50d6212a49ea',
#     '7b430030-0ed4-4e12-94c8-64a2f4f788e6',
#     'e334db5c-f6a9-4aad-9b77-9eb620da6133',
#     '655eed3b-fe6f-4a27-bdee-6f78a04b4dca',
#     '46a2eaa2-44e7-4e2a-a4c9-b368c66dd5d1',
#     '49256e86-5a2c-4128-97d5-4e1b0a1ae88a',
#     'f76b97ee-975b-459f-b06d-dc2b52018f8b',
#     '4a8f6dbb-2ca3-4052-b8ab-b289b7982b66'],
#    'price': 70,
#    'price-title': '7000/70',
#    'price_info': [[7000, 70]],
#    'price_title': '7000/70',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 13,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 33.0,
#    'room-title': '투룸 월세',
#    'room_desc': '투룸 | 3층 | 33m² | 관리비 5만원',
#    'room_floor': 3,
#    'room_options': [],
#    'room_size': 33.0,
#    'room_title': '투룸 월세',
#    'room_type': 1,
#    'room_type_str': '투룸',
#    'saved-time': '2016-02-15T10:38:49.474Z',
#    'saved_time': '2016-02-15T10:38:49.474Z',
#    'selling_type': 0,
#    'seq': 746213,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '9호선등촌역,이마트도보5분내',
#    'user_id': 'mommini@naver.com',
#    'view_count': 59},
#   {'_id': '56395db28a45793fc0a74cac',
#    'actived_time': '2016-02-02T02:30:19.437Z',
#    'address': '서울특별시 양천구 목동',
#    'agent_id': '560cb4dca251073283c4a9f7',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 17000,
#    'favorite_count': 3,
#    'floor': '4층',
#    'hash_tags': ['#전세가능', '#주차', '#반려동물'],
#    'heating': None,
#    'id': '56395db28a45793fc0a74cac',
#    'is_pano': False,
#    'location': [126.87375533216378, 37.54325882692881],
#    'maintenance_cost': 1.0,
#    'maintenance_items_str': [],
#    'name': '문규선',
#    'options': ['세탁기', '신발장', '가스레인지', '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '36da1563-7759-4e60-b7d0-58005639236a'},
#     {'desc': '', 'key': '73f33b26-f93d-4beb-81eb-6a728239ec26'},
#     {'desc': '', 'key': '84bb6a3f-814f-4881-ba77-a2f456e2f42a'},
#     {'desc': '', 'key': '8e512f32-fdb8-4c92-b1ab-a4cfbcf092f0'},
#     {'desc': '', 'key': '21d95ebe-9f73-4577-b73b-ab7aa4e5ae32'},
#     {'desc': '', 'key': '0c7c7ce6-47e4-4cb8-8038-03c12e89c910'},
#     {'desc': '', 'key': '6b2ba5ea-ae87-4436-9018-f65409eea4c4'},
#     {'desc': '', 'key': '0789c821-ee54-4939-8593-ef74125dfda4'},
#     {'desc': '', 'key': 'c344a9ed-1b1b-43f3-9bb1-df165b055ed9'},
#     {'desc': '', 'key': 'd8a8c51c-2ff2-4ee5-833e-0978dd8329a8'},
#     {'desc': '', 'key': '38577932-133c-4887-b281-25fcf5d2b089'},
#     {'desc': '', 'key': '0bccd43f-d518-4101-865b-aafa679a39ab'},
#     {'desc': '', 'key': 'a2f4bea9-af29-4411-9f56-b9ad72806c42'},
#     {'desc': '', 'key': 'e15f903d-8890-4303-a42e-7e8d6cdff375'}],
#    'photos': ['36da1563-7759-4e60-b7d0-58005639236a',
#     '73f33b26-f93d-4beb-81eb-6a728239ec26',
#     '84bb6a3f-814f-4881-ba77-a2f456e2f42a',
#     '8e512f32-fdb8-4c92-b1ab-a4cfbcf092f0',
#     '21d95ebe-9f73-4577-b73b-ab7aa4e5ae32',
#     '0c7c7ce6-47e4-4cb8-8038-03c12e89c910',
#     '6b2ba5ea-ae87-4436-9018-f65409eea4c4',
#     '0789c821-ee54-4939-8593-ef74125dfda4',
#     'c344a9ed-1b1b-43f3-9bb1-df165b055ed9',
#     'd8a8c51c-2ff2-4ee5-833e-0978dd8329a8',
#     '38577932-133c-4887-b281-25fcf5d2b089',
#     '0bccd43f-d518-4101-865b-aafa679a39ab',
#     'a2f4bea9-af29-4411-9f56-b9ad72806c42',
#     'e15f903d-8890-4303-a42e-7e8d6cdff375'],
#    'price': 0,
#    'price-title': '1억7000',
#    'price_info': [[17000, 0]],
#    'price_title': '1억7000',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 0,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 49.5,
#    'room-title': '투룸 전세',
#    'room_desc': '투룸 | 4층 | 49.5m² | 관리비 1만원',
#    'room_floor': 4,
#    'room_options': [1, 6, 8, 11],
#    'room_size': 49.5,
#    'room_title': '투룸 전세',
#    'room_type': 1,
#    'room_type_str': '투룸',
#    'saved-time': '2015-11-04T01:21:54.745Z',
#    'saved_time': '2015-11-04T01:21:54.745Z',
#    'selling_type': 1,
#    'seq': 525911,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개', '전세가능'],
#    'title': '♥희망♥와우!염창역도보5분거리!싼전세!귀한9호선전세!신축급!신혼부부추천!',
#    'user_id': 'sunlearn@daum.net',
#    'view_count': 245},
#   {'_id': '55a0a1b33888bb75f1e79970',
#    'actived_time': '2016-02-16T02:09:22.331Z',
#    'address': '서울특별시 강서구 염창동 ',
#    'agent_id': '533bcb03e4b037f267bf37c4',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 1000,
#    'favorite_count': 12,
#    'floor': '9층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '55a0a1b33888bb75f1e79970',
#    'is_pano': False,
#    'location': [126.87755037912565, 37.547511932842376],
#    'maintenance_cost': 6.0,
#    'maintenance_items_str': [],
#    'name': '정태근',
#    'options': ['에어컨',
#     '세탁기',
#     '책상',
#     '옷장',
#     '신발장',
#     '냉장고',
#     '인덕션',
#     '전자레인지',
#     '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '5d5e6ea2-1f2e-4f6b-9d27-0dc58e072785'},
#     {'desc': '', 'key': 'caaa0da6-acc3-4e4b-af75-18aa6f3eb703'},
#     {'desc': '', 'key': '971e0250-3804-469c-a93e-91439d71c939'},
#     {'desc': '', 'key': '65c5318d-cf43-4fc9-bbe8-194c301263c3'},
#     {'desc': '', 'key': '5677f5ea-05eb-4a5e-86ab-a57434c9bf6e'},
#     {'desc': '', 'key': '10aa5df8-9a0c-4596-9656-6d5ae831dded'},
#     {'desc': '', 'key': 'b98969d8-fda5-41cd-b65e-0b19669ae282'},
#     {'desc': '', 'key': 'f3cad25b-8d02-4635-b9d9-9c0d5f044fac'}],
#    'photos': ['5d5e6ea2-1f2e-4f6b-9d27-0dc58e072785',
#     'caaa0da6-acc3-4e4b-af75-18aa6f3eb703',
#     '971e0250-3804-469c-a93e-91439d71c939',
#     '65c5318d-cf43-4fc9-bbe8-194c301263c3',
#     '5677f5ea-05eb-4a5e-86ab-a57434c9bf6e',
#     '10aa5df8-9a0c-4596-9656-6d5ae831dded',
#     'b98969d8-fda5-41cd-b65e-0b19669ae282',
#     'f3cad25b-8d02-4635-b9d9-9c0d5f044fac'],
#    'price': 65,
#    'price-title': '1000/65',
#    'price_info': [[1000, 65]],
#    'price_title': '1000/65',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 14,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 23.1,
#    'room-title': '오피스텔 월세',
#    'room_desc': '오피스텔 | 9층 | 23.1m² | 관리비 6만원',
#    'room_floor': 9,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 10, 11],
#    'room_size': 23.1,
#    'room_title': '오피스텔 월세',
#    'room_type': 3,
#    'room_type_str': '오피스텔',
#    'saved-time': '2015-07-11T04:55:15.285Z',
#    'saved_time': '2015-07-11T04:55:15.285Z',
#    'selling_type': 0,
#    'seq': 353780,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '★염창역 복층 오피스텔★대명투웨니퍼스트!!최고층~ 즉시입주가능해요',
#    'user_id': 'gook52@nate.com',
#    'view_count': 866},
#   {'_id': '566b927f6b7d1d4e5501032a',
#    'actived_time': '2016-02-09T02:24:19.972Z',
#    'address': '서울특별시 강서구 화곡6동',
#    'agent_id': '55e901b7a0e57c6312354c04',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 500,
#    'favorite_count': 5,
#    'floor': '5층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '566b927f6b7d1d4e5501032a',
#    'is_pano': False,
#    'location': [126.85051312685188, 37.55242547520663],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '서준',
#    'options': ['에어컨', '세탁기', '옷장', '신발장', '냉장고', '전자도어락', '가스레인지'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '6273136b-8151-4a1b-b622-f604e164bfa9'},
#     {'desc': '', 'key': '35c0d5ff-9a8b-4f0e-af29-6f405606608f'},
#     {'desc': '', 'key': 'd3ba72f2-05b8-4020-bb33-3c0850ccc105'},
#     {'desc': '', 'key': 'a1fcccc4-a97c-47c2-b39f-b89372b44203'},
#     {'desc': '', 'key': '6e2b3f34-20cd-4506-b2df-352dc366d3e3'},
#     {'desc': '', 'key': 'dbc9785c-d5a0-4c15-8ad5-75cf067e0e0a'},
#     {'desc': '', 'key': '34d1660a-c005-45ec-9783-fb41287dc2e0'},
#     {'desc': '', 'key': '55fa0839-e548-4a08-af52-c083b68f825c'},
#     {'desc': '', 'key': 'e82efa98-40f3-452f-96a8-ce4e69886918'},
#     {'desc': '', 'key': '476b9df2-580f-490b-aa4a-e3751fd034e1'},
#     {'desc': '', 'key': 'd39d035f-c882-43b7-b0b2-4a348f027109'},
#     {'desc': '', 'key': '718c7d1f-3ece-4bfd-b154-82c8f5483639'}],
#    'photos': ['6273136b-8151-4a1b-b622-f604e164bfa9',
#     '35c0d5ff-9a8b-4f0e-af29-6f405606608f',
#     'd3ba72f2-05b8-4020-bb33-3c0850ccc105',
#     'a1fcccc4-a97c-47c2-b39f-b89372b44203',
#     '6e2b3f34-20cd-4506-b2df-352dc366d3e3',
#     'dbc9785c-d5a0-4c15-8ad5-75cf067e0e0a',
#     '34d1660a-c005-45ec-9783-fb41287dc2e0',
#     '55fa0839-e548-4a08-af52-c083b68f825c',
#     'e82efa98-40f3-452f-96a8-ce4e69886918',
#     '476b9df2-580f-490b-aa4a-e3751fd034e1',
#     'd39d035f-c882-43b7-b0b2-4a348f027109',
#     '718c7d1f-3ece-4bfd-b154-82c8f5483639'],
#    'price': 60,
#    'price-title': '500/60',
#    'price_info': [[500, 60], [1000, 55]],
#    'price_title': '500/60',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 7,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 39.6,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 5층 | 39.6m² | 관리비 5만원',
#    'room_floor': 5,
#    'room_options': [0, 1, 4, 6, 7, 11, 8],
#    'room_size': 39.6,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-12-12T03:20:31.923Z',
#    'saved_time': '2015-12-12T03:20:31.923Z',
#    'selling_type': 0,
#    'seq': 590635,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '🏡시원하게 큰 방/넓은 방, 방문 열자마자 달렸습니다.',
#    'user_id': 'seo.redjeans575@gmail.com',
#    'view_count': 200},
#   {'_id': '569deeb5420cc8174e4ff586',
#    'actived_time': '2016-02-19T01:41:32.012Z',
#    'address': '서울특별시 양천구 목동',
#    'agent_id': '5596110a93c017522f50c50c',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 8000,
#    'favorite_count': 0,
#    'floor': '5층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '569deeb5420cc8174e4ff586',
#    'is_pano': False,
#    'location': [126.881507122172, 37.54425795871824],
#    'maintenance_cost': 4.0,
#    'maintenance_items_str': [],
#    'name': '박성진',
#    'options': ['세탁기', '전자도어락', '신발장', '인덕션'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '3c0942db-19e0-4ebc-b139-6d0eda0b573e'},
#     {'desc': '', 'key': '23163d69-97b1-4136-8fe4-c3c1c7f15eb8'},
#     {'desc': '', 'key': '01dcfa9e-5af5-4168-b890-5564dcbd0736'},
#     {'desc': '', 'key': 'ef352b10-93ae-4d50-ad13-ea286e0b90cd'},
#     {'desc': '', 'key': '3f11a756-0b7c-4a7c-b398-47d75cfd0dcd'},
#     {'desc': '', 'key': 'ad534a9e-600d-4432-847b-c485140767a0'},
#     {'desc': '', 'key': '65efb672-1410-423d-afd5-5dde3295ae83'},
#     {'desc': '', 'key': '7034d2c7-cff5-4d6c-8cdc-d11e3cf5373b'},
#     {'desc': '', 'key': '0f273f3d-6810-4d74-8687-d73ae39a0798'},
#     {'desc': '', 'key': '13c88124-4c60-4163-a212-b894232c1eb3'},
#     {'desc': '', 'key': '7c45e21c-3d7a-4a92-b3fa-dfe98e13597a'}],
#    'photos': ['3c0942db-19e0-4ebc-b139-6d0eda0b573e',
#     '23163d69-97b1-4136-8fe4-c3c1c7f15eb8',
#     '01dcfa9e-5af5-4168-b890-5564dcbd0736',
#     'ef352b10-93ae-4d50-ad13-ea286e0b90cd',
#     '3f11a756-0b7c-4a7c-b398-47d75cfd0dcd',
#     'ad534a9e-600d-4432-847b-c485140767a0',
#     '65efb672-1410-423d-afd5-5dde3295ae83',
#     '7034d2c7-cff5-4d6c-8cdc-d11e3cf5373b',
#     '0f273f3d-6810-4d74-8687-d73ae39a0798',
#     '13c88124-4c60-4163-a212-b894232c1eb3',
#     '7c45e21c-3d7a-4a92-b3fa-dfe98e13597a'],
#    'price': 60,
#    'price-title': '8000/60',
#    'price_info': [[8000, 60]],
#    'price_title': '8000/60',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 17,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 49.5,
#    'room-title': '투룸 월세',
#    'room_desc': '투룸 | 5층 | 49.5m² | 관리비 4만원',
#    'room_floor': 5,
#    'room_options': [1, 11, 6, 9],
#    'room_size': 49.5,
#    'room_title': '투룸 월세',
#    'room_type': 1,
#    'room_type_str': '투룸',
#    'saved-time': '2016-01-19T08:07:17.145Z',
#    'saved_time': '2016-01-19T08:07:17.145Z',
#    'selling_type': 0,
#    'seq': 680139,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '★9호선신목동역도보5분★신축투룸전세★신혼부부강추★전세대출가능',
#    'user_id': 'pig925045@hanmail.net',
#    'view_count': 115},
#   {'_id': '56bd8ef41e8fcf7eaa3faf53',
#    'actived_time': '2016-02-12T07:51:16.524Z',
#    'address': '서울특별시 강서구 화곡1동',
#    'agent_id': '52d3a24be4b02acb1311d818',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 500,
#    'favorite_count': 0,
#    'floor': '2층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '56bd8ef41e8fcf7eaa3faf53',
#    'is_pano': False,
#    'location': [126.8446221616521, 37.52923696733942],
#    'maintenance_cost': 12.0,
#    'maintenance_items_str': [],
#    'name': '김정식',
#    'options': ['에어컨', '세탁기', '옷장', '신발장', '냉장고', '인덕션', '전자레인지', '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '8b572c8e-10dc-4952-a6d0-7e7efdf4d9d1'},
#     {'desc': '', 'key': '7de9f6d1-d5ba-4fce-9022-4e4a6bd50ba9'},
#     {'desc': '', 'key': '48b64b09-fa82-4ea4-8126-d9e52ebb5d66'},
#     {'desc': '', 'key': '7073351c-e37e-4966-9b8e-62cb2eb61ac8'},
#     {'desc': '', 'key': 'ccc65a20-eb83-45b8-9595-eec7fa25ebc6'},
#     {'desc': '', 'key': '12b62370-49f5-454d-82be-895d7ef28a5f'},
#     {'desc': '', 'key': '03741815-5205-437f-8364-0247e29c60c3'},
#     {'desc': '', 'key': '48433b77-22a8-44ae-be05-26b28ced12e4'},
#     {'desc': '', 'key': '9895484b-3f18-467a-b7b8-e03cd511f4f2'},
#     {'desc': '', 'key': '02e03ef3-c6bc-4de6-a4dd-be4a42a693dd'},
#     {'desc': '', 'key': 'd6e9dbca-ff03-4c86-8fbd-fa77b2476e3f'},
#     {'desc': '', 'key': '45037aea-bd47-4ad8-8c55-713aadacf752'}],
#    'photos': ['8b572c8e-10dc-4952-a6d0-7e7efdf4d9d1',
#     '7de9f6d1-d5ba-4fce-9022-4e4a6bd50ba9',
#     '48b64b09-fa82-4ea4-8126-d9e52ebb5d66',
#     '7073351c-e37e-4966-9b8e-62cb2eb61ac8',
#     'ccc65a20-eb83-45b8-9595-eec7fa25ebc6',
#     '12b62370-49f5-454d-82be-895d7ef28a5f',
#     '03741815-5205-437f-8364-0247e29c60c3',
#     '48433b77-22a8-44ae-be05-26b28ced12e4',
#     '9895484b-3f18-467a-b7b8-e03cd511f4f2',
#     '02e03ef3-c6bc-4de6-a4dd-be4a42a693dd',
#     'd6e9dbca-ff03-4c86-8fbd-fa77b2476e3f',
#     '45037aea-bd47-4ad8-8c55-713aadacf752'],
#    'price': 47,
#    'price-title': '500/47',
#    'price_info': [[500, 47]],
#    'price_title': '500/47',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 10,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 26.4,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 2층 | 26.4m² | 관리비 12만원',
#    'room_floor': 2,
#    'room_options': [0, 1, 4, 6, 7, 9, 10, 11],
#    'room_size': 26.4,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-12T07:51:16.524Z',
#    'saved_time': '2016-02-12T07:51:16.524Z',
#    'selling_type': 0,
#    'seq': 739684,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '※※월세10만원 할인중 + 신축',
#    'user_id': 'skydiver7223@nate.com',
#    'view_count': 25},
#   {'_id': '55b5934bed928e70412df1c4',
#    'actived_time': '2016-02-04T06:57:46.225Z',
#    'address': '인천광역시 계양구 계산동',
#    'agent_id': '5316eb3de4b04a0446067378',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 300,
#    'favorite_count': 5,
#    'floor': '5층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '55b5934bed928e70412df1c4',
#    'is_pano': False,
#    'location': [126.73672896172266, 37.534386855465165],
#    'maintenance_cost': 8.0,
#    'maintenance_items_str': [],
#    'name': '장지수',
#    'options': ['에어컨', '세탁기', '신발장', '냉장고', '가스레인지', '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '53978b96-beed-4b9f-98e1-18a9bcefbbae'},
#     {'desc': '', 'key': 'f0428a94-bd35-4837-9aa7-11dc8e2ef1d3'},
#     {'desc': '', 'key': 'f56d8f87-76ec-4beb-8517-5ce5bb7bbf2d'},
#     {'desc': '', 'key': 'aa419a90-e42f-47a5-bf15-38a805ac9a81'},
#     {'desc': '', 'key': 'b6c25eb4-c001-40a1-8e99-0a687fc1e01a'},
#     {'desc': '', 'key': '62e70ea4-77b8-4880-883a-3e57fdc8bd85'},
#     {'desc': '', 'key': '918400ab-557e-4552-b8b3-8bd1d5a83e18'},
#     {'desc': '', 'key': '350b02f4-bec8-4391-89c7-f8d808a05604'},
#     {'desc': '', 'key': 'aa2dd78f-1027-4c49-b5a8-0e94be2d53fc'},
#     {'desc': '', 'key': 'cbfff520-0059-4b37-9558-779553afd6f2'},
#     {'desc': '', 'key': '6073f762-e3dc-4cb5-ba96-fd2ab127aa19'},
#     {'desc': '', 'key': 'd010f686-115f-4e63-8f7d-5ecdf0aa0799'},
#     {'desc': '', 'key': 'e7035347-43af-4484-a371-b728ad567956'},
#     {'desc': '', 'key': '741855c3-a510-4817-b76a-c768c94ac92e'}],
#    'photos': ['53978b96-beed-4b9f-98e1-18a9bcefbbae',
#     'f0428a94-bd35-4837-9aa7-11dc8e2ef1d3',
#     'f56d8f87-76ec-4beb-8517-5ce5bb7bbf2d',
#     'aa419a90-e42f-47a5-bf15-38a805ac9a81',
#     'b6c25eb4-c001-40a1-8e99-0a687fc1e01a',
#     '62e70ea4-77b8-4880-883a-3e57fdc8bd85',
#     '918400ab-557e-4552-b8b3-8bd1d5a83e18',
#     '350b02f4-bec8-4391-89c7-f8d808a05604',
#     'aa2dd78f-1027-4c49-b5a8-0e94be2d53fc',
#     'cbfff520-0059-4b37-9558-779553afd6f2',
#     '6073f762-e3dc-4cb5-ba96-fd2ab127aa19',
#     'd010f686-115f-4e63-8f7d-5ecdf0aa0799',
#     'e7035347-43af-4484-a371-b728ad567956',
#     '741855c3-a510-4817-b76a-c768c94ac92e'],
#    'price': 40,
#    'price-title': '300/40',
#    'price_info': [[300, 40], [500, 38]],
#    'price_title': '300/40',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 2,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 29.7,
#    'room-title': '오피스텔 월세',
#    'room_desc': '오피스텔 | 5층 | 29.7m² | 관리비 8만원',
#    'room_floor': 5,
#    'room_options': [0, 1, 6, 7, 8, 11],
#    'room_size': 29.7,
#    'room_title': '오피스텔 월세',
#    'room_type': 3,
#    'room_type_str': '오피스텔',
#    'saved-time': '2015-07-27T02:11:23.097Z',
#    'saved_time': '2015-07-27T02:11:23.097Z',
#    'selling_type': 0,
#    'seq': 375710,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '★넓은 오피스텔 / 애완동물 가능★',
#    'user_id': 'demeter12@naver.com',
#    'view_count': 1329},
#   {'_id': '56cc03d2229f146feaa04bc2',
#    'actived_time': '2016-02-23T07:01:38.591Z',
#    'address': '서울특별시 강서구 등촌동',
#    'agent_id': '56bbf166a7d4753b67529fdd',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 19000,
#    'favorite_count': 0,
#    'floor': '3층',
#    'hash_tags': ['#전세가능', '#주차'],
#    'heating': None,
#    'id': '56cc03d2229f146feaa04bc2',
#    'is_pano': False,
#    'location': [126.85891773519637, 37.546049543543525],
#    'maintenance_cost': 0.0,
#    'maintenance_items_str': [],
#    'name': '박영미',
#    'options': [],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'd293251f-d8f8-4844-a23b-374998fd12f0'},
#     {'desc': '', 'key': '74c805f4-a3f8-4f00-af0b-b3fe2a30095f'},
#     {'desc': '', 'key': '7d75c262-7046-490f-9801-9dd97097f95e'},
#     {'desc': '', 'key': 'da7346fb-5ac8-4a9c-9476-9536330d8eef'},
#     {'desc': '', 'key': '52cc2d16-39b4-4b95-8ab8-f388eb8c1945'},
#     {'desc': '', 'key': '48927216-941f-4d17-ae97-df949d1f38cb'},
#     {'desc': '', 'key': '0ef7a7ab-be47-4a99-af65-be36ed2305f7'},
#     {'desc': '', 'key': 'cf854e2a-ad3c-4431-8b9b-bfd6a80d9ee0'},
#     {'desc': '', 'key': '30a23f9a-66ea-48e1-8514-1b2e5362f515'},
#     {'desc': '', 'key': 'e2191771-1648-4dcd-8129-d43459f7db72'},
#     {'desc': '', 'key': '4bc78648-82e3-415a-9ea9-fd26d062646d'},
#     {'desc': '', 'key': 'ad42205b-4d48-4b92-b699-beffb0b9fdb3'}],
#    'photos': ['d293251f-d8f8-4844-a23b-374998fd12f0',
#     '74c805f4-a3f8-4f00-af0b-b3fe2a30095f',
#     '7d75c262-7046-490f-9801-9dd97097f95e',
#     'da7346fb-5ac8-4a9c-9476-9536330d8eef',
#     '52cc2d16-39b4-4b95-8ab8-f388eb8c1945',
#     '48927216-941f-4d17-ae97-df949d1f38cb',
#     '0ef7a7ab-be47-4a99-af65-be36ed2305f7',
#     'cf854e2a-ad3c-4431-8b9b-bfd6a80d9ee0',
#     '30a23f9a-66ea-48e1-8514-1b2e5362f515',
#     'e2191771-1648-4dcd-8129-d43459f7db72',
#     '4bc78648-82e3-415a-9ea9-fd26d062646d',
#     'ad42205b-4d48-4b92-b699-beffb0b9fdb3'],
#    'price': 0,
#    'price-title': '1억9000',
#    'price_info': [[19000, 0]],
#    'price_title': '1억9000',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 21,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 52.8,
#    'room-title': '쓰리룸 전세',
#    'room_desc': '쓰리룸 | 3층 | 52.8m² | 관리비 0만원',
#    'room_floor': 3,
#    'room_options': [],
#    'room_size': 52.8,
#    'room_title': '쓰리룸 전세',
#    'room_type': 2,
#    'room_type_str': '쓰리룸',
#    'saved-time': '2016-02-23T07:01:38.591Z',
#    'saved_time': '2016-02-23T07:01:38.591Z',
#    'selling_type': 1,
#    'seq': 766532,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개', '전세가능'],
#    'title': '《등촌동 신축 방3거실 전세 》 방3개 전세',
#    'user_id': 'pymalth@naver.com',
#    'view_count': 30},
#   {'_id': '56c3cbeef66b075c13158fdf',
#    'actived_time': '2016-02-17T01:25:02.231Z',
#    'address': '서울특별시 강서구 화곡동 ',
#    'agent_id': '55e901b7a0e57c6312354c04',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 2000,
#    'favorite_count': 0,
#    'floor': '4층',
#    'hash_tags': [],
#    'heating': None,
#    'id': '56c3cbeef66b075c13158fdf',
#    'is_pano': False,
#    'location': [126.84211571218526, 37.528956134917756],
#    'maintenance_cost': 6.0,
#    'maintenance_items_str': [],
#    'name': '임연희',
#    'options': ['에어컨', '세탁기', '책상', '옷장', '신발장', '냉장고', '인덕션', '전자도어락'],
#    'pano': None,
#    'parking': False,
#    'photo': [{'desc': '', 'key': 'bdaa7353-20c6-4ffd-bca2-fa0b00cd422d'},
#     {'desc': '', 'key': 'bff32f09-ba48-4aac-9ad0-f7b17c2bf6a4'},
#     {'desc': '', 'key': '2386839c-aedd-477a-ab60-ba8f694430bf'},
#     {'desc': '', 'key': 'aecd8027-ac4d-4358-865c-684eb156378f'},
#     {'desc': '', 'key': '098b5c4a-8ccc-42a7-884b-c7253e3a888e'},
#     {'desc': '', 'key': '6a4fe95d-04f3-4b19-806c-6e20a84e4ee6'},
#     {'desc': '', 'key': '1a407d2f-af70-43ca-95d6-574af9bfc66e'},
#     {'desc': '', 'key': '744b2662-0331-4eb1-8bb1-cd4e0813b768'},
#     {'desc': '', 'key': 'c4dee7eb-9eb1-43c1-bab3-4607a7732bcd'},
#     {'desc': '', 'key': 'fbdf4673-a3d1-47ef-984b-2797077caada'},
#     {'desc': '', 'key': '8feed8b9-440a-4eae-8c98-c38b716394c3'},
#     {'desc': '', 'key': '8f5214c7-f4dd-4cd9-896b-f52e7136eabd'},
#     {'desc': '', 'key': '41222220-13d5-40ea-a606-2fca6c76599d'},
#     {'desc': '', 'key': '99ebc6ad-53f4-46aa-9904-1825a16dd1fc'},
#     {'desc': '', 'key': '52fa1170-89b3-4e39-b5f9-582ec0c60458'}],
#    'photos': ['bdaa7353-20c6-4ffd-bca2-fa0b00cd422d',
#     'bff32f09-ba48-4aac-9ad0-f7b17c2bf6a4',
#     '2386839c-aedd-477a-ab60-ba8f694430bf',
#     'aecd8027-ac4d-4358-865c-684eb156378f',
#     '098b5c4a-8ccc-42a7-884b-c7253e3a888e',
#     '6a4fe95d-04f3-4b19-806c-6e20a84e4ee6',
#     '1a407d2f-af70-43ca-95d6-574af9bfc66e',
#     '744b2662-0331-4eb1-8bb1-cd4e0813b768',
#     'c4dee7eb-9eb1-43c1-bab3-4607a7732bcd',
#     'fbdf4673-a3d1-47ef-984b-2797077caada',
#     '8feed8b9-440a-4eae-8c98-c38b716394c3',
#     '8f5214c7-f4dd-4cd9-896b-f52e7136eabd',
#     '41222220-13d5-40ea-a606-2fca6c76599d',
#     '99ebc6ad-53f4-46aa-9904-1825a16dd1fc',
#     '52fa1170-89b3-4e39-b5f9-582ec0c60458'],
#    'price': 35,
#    'price-title': '2000/35',
#    'price_info': [[2000, 35], [1500, 40], [1000, 45]],
#    'price_title': '2000/35',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 15,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 23.1,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 4층 | 23.1m² | 관리비 6만원',
#    'room_floor': 4,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 11],
#    'room_size': 23.1,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-17T01:25:02.231Z',
#    'saved_time': '2016-02-17T01:25:02.231Z',
#    'selling_type': 0,
#    'seq': 750262,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '((까치산역)) 베란다있는 방~~',
#    'user_id': 'dodoya6061@naver.com',
#    'view_count': 33},
#   {'_id': '55f0d9319b5aca04ca89a257',
#    'actived_time': '2016-02-16T07:03:41.998Z',
#    'address': '서울특별시 강서구 화곡동 ',
#    'agent_id': '55c9b653e6e9e635d2c70c01',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 1000,
#    'favorite_count': 3,
#    'floor': '6층',
#    'hash_tags': ['#주차'],
#    'heating': None,
#    'id': '55f0d9319b5aca04ca89a257',
#    'is_pano': False,
#    'location': [126.83957358402412, 37.54322814813598],
#    'maintenance_cost': 6.0,
#    'maintenance_items_str': [],
#    'name': '조성민',
#    'options': ['에어컨',
#     '세탁기',
#     '침대',
#     '책상',
#     '옷장',
#     'TV',
#     '신발장',
#     '냉장고',
#     '인덕션',
#     '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'c2761fab-f9e0-45e9-9ed0-6e26712b273f'},
#     {'desc': '', 'key': '60b60560-37f9-4b7f-a0d9-df67856af5c4'},
#     {'desc': '', 'key': '6ab7088c-d5fe-40a9-98fb-d6456636e9e7'},
#     {'desc': '', 'key': '1dbb12d3-3ccd-42d7-988f-163d681c7f41'},
#     {'desc': '', 'key': '8e377b3f-830e-4e6d-a14b-1a1d3129ccf6'}],
#    'photos': ['c2761fab-f9e0-45e9-9ed0-6e26712b273f',
#     '60b60560-37f9-4b7f-a0d9-df67856af5c4',
#     '6ab7088c-d5fe-40a9-98fb-d6456636e9e7',
#     '1dbb12d3-3ccd-42d7-988f-163d681c7f41',
#     '8e377b3f-830e-4e6d-a14b-1a1d3129ccf6'],
#    'price': 31,
#    'price-title': '1000/31',
#    'price_info': [[1000, 31]],
#    'price_title': '1000/31',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 14,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 6층 | 19.8m² | 관리비 6만원',
#    'room_floor': 6,
#    'room_options': [0, 1, 2, 3, 4, 5, 6, 7, 9, 11],
#    'room_size': 19.8,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-09-10T01:13:21.454Z',
#    'saved_time': '2015-09-10T01:13:21.454Z',
#    'selling_type': 0,
#    'seq': 451455,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '[화곡역]초역세권 몸만 들어가는집',
#    'user_id': 'm8352@naver.com',
#    'view_count': 543},
#   {'_id': '56cea5bcc4f044594b816eb4',
#    'actived_time': '2016-02-25T06:57:00.877Z',
#    'address': '인천광역시 부평구 삼산동',
#    'agent_id': '52c0dbfde4b020f50fb6ad29',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 5500,
#    'favorite_count': 0,
#    'floor': '3층',
#    'hash_tags': ['#전세가능', '#주차'],
#    'heating': None,
#    'id': '56cea5bcc4f044594b816eb4',
#    'is_pano': False,
#    'location': [126.74824094424802, 37.515912626082866],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '이은경',
#    'options': ['에어컨', '세탁기', '인덕션', '냉장고', '신발장'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': 'e5e8b8dd-9f6e-496b-9b60-ec953613b417'},
#     {'desc': '', 'key': '6844317d-c1df-4352-88d5-558dc1df7f77'},
#     {'desc': '', 'key': '75cc3832-3e11-47ee-80c4-3d4e27b17cef'},
#     {'desc': '', 'key': '69c7a72f-ef43-4e0d-843f-d71af42be806'},
#     {'desc': '', 'key': '4cd197f4-0d10-4e58-b12d-9ed5dc9f1173'},
#     {'desc': '', 'key': 'b12e5cc6-988e-4ae1-8623-c1de894c6764'},
#     {'desc': '', 'key': '4505e1da-4ff4-4d1d-bd51-aa72df1b01a9'},
#     {'desc': '', 'key': '450c8fc3-7343-4e66-a8a1-e6e85cbb03a4'}],
#    'photos': ['e5e8b8dd-9f6e-496b-9b60-ec953613b417',
#     '6844317d-c1df-4352-88d5-558dc1df7f77',
#     '75cc3832-3e11-47ee-80c4-3d4e27b17cef',
#     '69c7a72f-ef43-4e0d-843f-d71af42be806',
#     '4cd197f4-0d10-4e58-b12d-9ed5dc9f1173',
#     'b12e5cc6-988e-4ae1-8623-c1de894c6764',
#     '4505e1da-4ff4-4d1d-bd51-aa72df1b01a9',
#     '450c8fc3-7343-4e66-a8a1-e6e85cbb03a4'],
#    'price': 0,
#    'price-title': '5500',
#    'price_info': [[5500, 0]],
#    'price_title': '5500',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 23,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '원룸 전세',
#    'room_desc': '원룸 | 3층 | 19.8m² | 관리비 5만원',
#    'room_floor': 3,
#    'room_options': [0, 1, 9, 7, 6],
#    'room_size': 19.8,
#    'room_title': '원룸 전세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2016-02-25T06:57:00.877Z',
#    'saved_time': '2016-02-25T06:57:00.877Z',
#    'selling_type': 1,
#    'seq': 771890,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개', '전세가능'],
#    'title': '부천상동역 7분거리! 전세가능 풀옵션 원룸!!',
#    'user_id': 'ylk011@naver.com',
#    'view_count': 68},
#   {'_id': '5660fcd119851c268915b7c2',
#    'actived_time': '2016-02-24T02:53:02.163Z',
#    'address': '서울특별시 강서구 화곡동',
#    'agent_id': '55e901b7a0e57c6312354c04',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 1000,
#    'favorite_count': 0,
#    'floor': '12층',
#    'hash_tags': [],
#    'heating': None,
#    'id': '5660fcd119851c268915b7c2',
#    'is_pano': False,
#    'location': [126.8458688621669, 37.530352237856924],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '정동기',
#    'options': ['에어컨', '세탁기', '신발장', '냉장고', '인덕션', '전자도어락'],
#    'pano': None,
#    'parking': False,
#    'photo': [{'desc': '', 'key': '4a881e5d-c0a2-4082-8fe0-10deef689b88'},
#     {'desc': '', 'key': '09981979-d4ac-4454-9b55-5422daa2afa2'},
#     {'desc': '', 'key': '4203c965-6c1d-44e3-9b40-a857435e88ac'},
#     {'desc': '', 'key': '190aeb61-3712-4623-8e3a-5afdf061cab1'},
#     {'desc': '', 'key': 'ceec8dfb-aea5-4a91-a16f-bc597d0c4f33'},
#     {'desc': '', 'key': '39268ac3-d0a5-4871-aeff-5fc7e2593ec1'},
#     {'desc': '', 'key': 'e736c85b-c14c-456f-bb19-2ab055fccf15'},
#     {'desc': '', 'key': 'f69120b9-d9eb-4260-a502-4411b27343ff'}],
#    'photos': ['4a881e5d-c0a2-4082-8fe0-10deef689b88',
#     '09981979-d4ac-4454-9b55-5422daa2afa2',
#     '4203c965-6c1d-44e3-9b40-a857435e88ac',
#     '190aeb61-3712-4623-8e3a-5afdf061cab1',
#     'ceec8dfb-aea5-4a91-a16f-bc597d0c4f33',
#     '39268ac3-d0a5-4871-aeff-5fc7e2593ec1',
#     'e736c85b-c14c-456f-bb19-2ab055fccf15',
#     'f69120b9-d9eb-4260-a502-4411b27343ff'],
#    'price': 45,
#    'price-title': '1000/45',
#    'price_info': [[1000, 45], [2000, 38], [500, 50]],
#    'price_title': '1000/45',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 22,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.8,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 12층 | 19.8m² | 관리비 5만원',
#    'room_floor': 12,
#    'room_options': [0, 1, 6, 7, 9, 11],
#    'room_size': 19.8,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-12-04T02:39:13.163Z',
#    'saved_time': '2015-12-04T02:39:13.163Z',
#    'selling_type': 0,
#    'seq': 574181,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '💖 풀옵션 원룸 * 까치산역 도보 2~3분',
#    'user_id': 'motive1225@naver.com',
#    'view_count': 127},
#   {'_id': '56d6514403fbca0d8772b989',
#    'actived_time': '2016-03-02T02:34:44.644Z',
#    'address': '서울특별시 영등포구 양평동',
#    'agent_id': '5264ba64e4b0a23a4d9d5e2e',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 12000,
#    'favorite_count': 0,
#    'floor': '5층',
#    'hash_tags': ['#전세가능', '#주차'],
#    'heating': None,
#    'id': '56d6514403fbca0d8772b989',
#    'is_pano': False,
#    'location': [126.88890782237809, 37.544074141328245],
#    'maintenance_cost': 2.0,
#    'maintenance_items_str': [],
#    'name': '류영권',
#    'options': [],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '14deea61-d812-41bb-ae32-02824802967e'},
#     {'desc': '', 'key': '51d861f7-7116-4bf9-9fae-cf66ad8b5d73'},
#     {'desc': '', 'key': 'f144f88d-554a-4e33-a66c-76679fa7fe60'},
#     {'desc': '', 'key': 'cb4fc7ea-f7e2-4ce6-a758-6958ceab0ccc'},
#     {'desc': '', 'key': '11c3d3cc-6eeb-4652-88cd-a1465800a98c'},
#     {'desc': '', 'key': 'd32deab5-7d83-432c-a568-fec6a2693318'},
#     {'desc': '', 'key': 'd5e03878-6827-4c20-a817-502363322227'}],
#    'photos': ['14deea61-d812-41bb-ae32-02824802967e',
#     '51d861f7-7116-4bf9-9fae-cf66ad8b5d73',
#     'f144f88d-554a-4e33-a66c-76679fa7fe60',
#     'cb4fc7ea-f7e2-4ce6-a758-6958ceab0ccc',
#     '11c3d3cc-6eeb-4652-88cd-a1465800a98c',
#     'd32deab5-7d83-432c-a568-fec6a2693318',
#     'd5e03878-6827-4c20-a817-502363322227'],
#    'price': 0,
#    'price-title': '1억2000',
#    'price_info': [[12000, 0]],
#    'price_title': '1억2000',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 29,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 29.7,
#    'room-title': '1.5룸 전세',
#    'room_desc': '1.5룸 | 5층 | 29.7m² | 관리비 2만원',
#    'room_floor': 5,
#    'room_options': [],
#    'room_size': 29.7,
#    'room_title': '1.5룸 전세',
#    'room_type': 5,
#    'room_type_str': '1.5룸',
#    'saved-time': '2016-03-02T02:34:44.644Z',
#    'saved_time': '2016-03-02T02:34:44.644Z',
#    'selling_type': 1,
#    'seq': 784241,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개', '전세가능'],
#    'title': '방1개,거실,전세',
#    'user_id': 'jininsa@hanmail.net',
#    'view_count': 32},
#   {'_id': '555af982e4b041a9a119ce05',
#    'actived_time': '2016-02-05T01:23:25.149Z',
#    'address': '서울특별시 강서구 화곡동',
#    'agent_id': '53ba22a2e4b0102e6fb94891',
#    'animal': False,
#    'building_floor_str': '',
#    'deposit': 1000,
#    'favorite_count': 0,
#    'floor': '2층',
#    'hash_tags': [],
#    'heating': None,
#    'id': '555af982e4b041a9a119ce05',
#    'is_pano': False,
#    'location': [126.846500542, 37.5312684772],
#    'maintenance_cost': 6,
#    'maintenance_items_str': [],
#    'name': '이정세',
#    'options': ['에어컨', '세탁기', '옷장', '신발장', '냉장고', '인덕션', '전자레인지', '전자도어락'],
#    'pano': None,
#    'parking': False,
#    'photo': [{'desc': '', 'key': 'fd3f8499-059b-30e2-3061-f49fd912b9f6'},
#     {'desc': '', 'key': 'b5e4665d-b311-fad2-cb38-c3a43c6065ac'},
#     {'desc': '', 'key': 'e8ca5350-bc53-76e1-5da1-95b9a05ebc2b'},
#     {'desc': '', 'key': 'af32dac6-8dd5-09b5-f65e-d1de5121396c'},
#     {'desc': '', 'key': 'f9b2e14b-eddf-9019-854b-215bf1340cca'},
#     {'desc': '', 'key': '99623519-9435-6a72-fa96-94085953500b'}],
#    'photos': ['fd3f8499-059b-30e2-3061-f49fd912b9f6',
#     'b5e4665d-b311-fad2-cb38-c3a43c6065ac',
#     'e8ca5350-bc53-76e1-5da1-95b9a05ebc2b',
#     'af32dac6-8dd5-09b5-f65e-d1de5121396c',
#     'f9b2e14b-eddf-9019-854b-215bf1340cca',
#     '99623519-9435-6a72-fa96-94085953500b'],
#    'price': 50,
#    'price-title': '1000/50',
#    'price_info': [[1000, 50], [500, 45]],
#    'price_title': '1000/50',
#    'private-memo': None,
#    'processing': False,
#    'refresh': True,
#    'remaining_days': 3,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 19.799999999999997,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 2층 | 19.8m² | 관리비 6만원',
#    'room_floor': 2,
#    'room_options': [0, 1, 4, 6, 7, 9, 10, 11],
#    'room_size': 19.799999999999997,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-06-19T15:01:00.000Z',
#    'saved_time': '2015-06-19T15:01:00.000Z',
#    'selling_type': 0,
#    'seq': 258395,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '지하철 1분 초역세권에 있는 아늑한 풀옵션 원룸',
#    'user_id': 'delight286@naver.com',
#    'view_count': 311},
#   {'_id': '55597d45e4b05b8e70c03d8a',
#    'actived_time': '2016-03-02T08:07:43.677Z',
#    'address': '서울특별시 강서구 화곡동',
#    'agent_id': '543639e8e4b05b7ebc491a32',
#    'animal': True,
#    'building_floor_str': '',
#    'deposit': 65,
#    'favorite_count': 6,
#    'floor': '3층',
#    'hash_tags': ['#주차', '#반려동물'],
#    'heating': None,
#    'id': '55597d45e4b05b8e70c03d8a',
#    'is_pano': False,
#    'location': [126.84262489217545, 37.52999476736596],
#    'maintenance_cost': 5.0,
#    'maintenance_items_str': [],
#    'name': '김원진',
#    'options': ['에어컨',
#     '세탁기',
#     '책상',
#     '옷장',
#     '신발장',
#     '냉장고',
#     '인덕션',
#     '전자레인지',
#     '전자도어락'],
#    'pano': None,
#    'parking': True,
#    'photo': [{'desc': '', 'key': '787074d8-65f2-1a21-5c3a-841c8567a09a'},
#     {'desc': '', 'key': '90bf8010-8eb2-1fb7-d1e4-90b1cbcc8176'},
#     {'desc': '', 'key': '8fa23cac-416c-b519-b8bd-4108544398ae'},
#     {'desc': '', 'key': '23a30455-2454-9549-255c-5e9acc736570'},
#     {'desc': '', 'key': 'e195d86c-c477-30ac-27f5-36aa040a8756'},
#     {'desc': '', 'key': '157eb692-64a5-8f20-5b70-11809e28ea00'},
#     {'desc': '', 'key': 'cacc2aa1-8ef9-90b8-a665-4536aefbe4e4'},
#     {'desc': '', 'key': '94d145ea-2f7d-a8f2-d10c-49a2291f3994'},
#     {'desc': '', 'key': '0c4f1ce7-98a5-bcd9-a53c-9bbc803df30e'}],
#    'photos': ['787074d8-65f2-1a21-5c3a-841c8567a09a',
#     '90bf8010-8eb2-1fb7-d1e4-90b1cbcc8176',
#     '8fa23cac-416c-b519-b8bd-4108544398ae',
#     '23a30455-2454-9549-255c-5e9acc736570',
#     'e195d86c-c477-30ac-27f5-36aa040a8756',
#     '157eb692-64a5-8f20-5b70-11809e28ea00',
#     'cacc2aa1-8ef9-90b8-a665-4536aefbe4e4',
#     '94d145ea-2f7d-a8f2-d10c-49a2291f3994',
#     '0c4f1ce7-98a5-bcd9-a53c-9bbc803df30e'],
#    'price': 60,
#    'price-title': '65/60',
#    'price_info': [[65, 60]],
#    'price_title': '65/60',
#    'private-memo': None,
#    'processing': False,
#    'refresh': False,
#    'remaining_days': 29,
#    'report_check_comment': None,
#    'report_check_saved_time': None,
#    'room-size-m2': 23.099999999999998,
#    'room-title': '원룸 월세',
#    'room_desc': '원룸 | 3층 | 23.1m² | 관리비 5만원',
#    'room_floor': 3,
#    'room_options': [0, 1, 3, 4, 6, 7, 9, 10, 11],
#    'room_size': 23.099999999999998,
#    'room_title': '원룸 월세',
#    'room_type': 0,
#    'room_type_str': '원룸',
#    'saved-time': '2015-06-18T15:01:00.000Z',
#    'saved_time': '2015-06-18T15:01:00.000Z',
#    'selling_type': 0,
#    'seq': 256168,
#    'short_lease': False,
#    'status': 1,
#    'tags': ['중개'],
#    'title': '◈까치산 거의 유일한 단기임대-!',
#    'user_id': 'hayato1201@nate.com',
#    'view_count': 584}],
#  'total': 500,
#  'total-str': '500+'}

# %%
df
# Out:
#       name  deposit  rent           address floor
# 0      고유정      300    45  서울특별시 영등포구 양평동3가    5층
# 1      김종철    16500     0     서울특별시 강서구 화곡동    3층
# 2      권혁일    16800     0    서울특별시 강서구 화곡동     9층
# 3      이정세     1000    50     서울특별시 강서구 화곡동    7층
# 4       구정      250    35    인천광역시 부평구 갈산1동    2층
# 5      서혜정     2000    50    서울특별시 영등포구 당산동    3층
# 6      박성배     1000    40  서울특별시 영등포구 양평동5가    3층
# 7      채영민      500    45     서울특별시 강서구 등촌동    6층
# 8      이상열     4500     0     서울특별시 강서구 화곡동    2층
# 9      신한인      500    45  서울특별시 영등포구 당산동4가    5층
# 10     류승현      300    25     인천광역시 부평구 부평동   반지층
# 11     이부형     1000    41     서울특별시 강서구 화곡동    5층
# 12     이은우     3000    40    서울특별시 영등포구 당산동    8층
# 13     김미란      100    60     서울특별시 강서구 화곡동    9층
# 14     조성훈     1000    35    서울특별시 영등포구 문래동    8층
# 15     김해성     1000    60     서울특별시 강서구 화곡동    7층
# 16     조범진     1000    60       서울특별시 구로구 구   12층
# 17     이연진     1000    45    서울특별시 강서구 화곡1동   11층
# 18     윤경섭      500    40    서울특별시 강서구 화곡동    12층
# 19     박상돈     1000    50    서울특별시 마포구 망원2동    2층
# 20   이정관대리       30    30     인천광역시 계양구 계산동    2층
# 21      김갑     1000    50     서울특별시 양천구 신월동    4층
# 22     김윤준     7500     0   서울특별시 영등포구 영등포동    3층
# 23     조인선     3000    35    서울특별시 영등포구 문래동    2층
# 24     이민주    17300     0     서울특별시 강서구 화곡동    2층
# 25     조은하        0    22    서울특별시 양천구 신정4동    2층
# 26     김정식     4500     0     서울특별시 강서구 화곡동    5층
# 27   전윤미실장      500    45      인천광역시 서구 경서동    3층
# 28     유상훈     1000    62    서울특별시 영등포구 양평동    7층
# 29     이동현     2000    35     서울특별시 양천구 신정동    3층
# ..     ...      ...   ...               ...   ...
# 210    진영훈     6500     0   서울특별시 영등포구 영등포동    3층
# 211    고유정     1000    55  서울특별시 영등포구 당산동6가    5층
# 212    고유정     4000    15  서울특별시 영등포구 문래동4가    7층
# 213    김현규    16500     0     서울특별시 양천구 신월동    4층
# 214    조연환     1000    60  서울특별시 영등포구 양평동4가    6층
# 215    김용현       80    55     서울특별시 강서구 화곡동    6층
# 216    신동철      300    40    서울특별시 영등포구 도림동    4층
# 217    이연진      300    41    서울특별시 강서구 화곡본동    2층
# 218    김경락    15000     0    서울특별시 강서구 화곡동     3층
# 219    이동욱     3000    30       서울특별시 영등포구     5층
# 220   김경민♥     2000    60          경기도 부천시     4층
# 221    심경분      500    30      서울특별시 양천구 목동   반지층
# 222    구기복    18000     0     서울특별시 강서구 화곡동    2층
# 223    김대웅      500    45    서울특별시 강서구 화곡동     6층
# 224    탁준수    18000     0       서울특별시 영등포구     3층
# 225    신한인      500    45  서울특별시 영등포구 양평동5가    5층
# 226  전윤미실장      500    43      인천광역시 서구 경서동    1층
# 227    김원진     6000    10     서울특별시 강서구 화곡동   12층
# 228    윤경섭     2000    55    서울특별시 강서구 화곡동    11층
# 229    박장식     1000    53     서울특별시 강서구 등촌동    7층
# 230    김대웅      350    47    서울특별시 강서구 공항동     3층
# 231    고유정      500    65  서울특별시 영등포구 당산동6가   10층
# 232    김현우     3000    30        서울특별시 영등포구    2층
# 233    정태근     4000    40     서울특별시 강서구 염창동    9층
# 234    조현룡      300    57     서울특별시 양천구 신정동    4층
# 235    최민희     7000    70    서울특별시 강서구 등촌동     3층
# 236    문규선    17000     0      서울특별시 양천구 목동    4층
# 237     서준      500    60    서울특별시 강서구 화곡6동    5층
# 238    박성진     8000    60      서울특별시 양천구 목동    5층
# 239    김정식      500    47    서울특별시 강서구 화곡1동    2층
#
# [240 rows x 5 columns]

# %% [markdown]
# ### db에 넣기

# %%
import MySQLdb

db = MySQLdb.connect(
    "db.fastcamp.us",
    "root",
    "dkstncks",
    "jkeun_sample",
    charset='utf8',
)

cursor = db.cursor()

# %%
# dabang 테이블 생성
SQL_QUERY = """
    CREATE TABLE dabang (
    name VARCHAR(255),
    deposit INT,
    rent INT,
    address VARCHAR(255),
    floor VARCHAR(255)
    )
;
"""

cursor.execute(SQL_QUERY)
db.
# Out:
# 0

# %%
SQL_QUERY = """
    INSERT INTO dabang (
        name,
        deposit,
        rent,
        address,
        floor
        )
    VALUES (
        '{name}',
        '{deposit}',
        '{rent}',
        '{address}',
        '{floor}'
        )
    ;
    """.format(
    name = name,
    deposit = deposit,
    rent = rent,
    address = address,
    floor = floor,
)

# %%
for index, row in df.iterrows():
    name = row.get('name')
    deposit = row.get('deposit')
    rent = row.get('rent')
    address = row.get('address')
    floor = row.get('floor')
    
    SQL_QUERY = """
    INSERT INTO dabang (
        name,
        deposit,
        rent,
        address,
        floor
        )
    VALUES (
        '{name}',
        '{deposit}',
        '{rent}',
        '{address}',
        '{floor}'
        )
    ;
    """.format(
    name = name,
    deposit = deposit,
    rent = rent,
    address = address,
    floor = floor,
)
    cursor.execute(SQL_QUERY)
    db.commit()
